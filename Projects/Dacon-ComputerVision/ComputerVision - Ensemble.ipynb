# %%
# !nvidia-smi
# Out:
# Sun Sep 13 06:27:29 2020
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 450.66       Driver Version: 418.67       CUDA Version: 10.1     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla P100-PCIE...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   41C    P0    29W / 250W |      0MiB / 16280MiB |      0%      Default |
# |                               |                      |                 ERR! |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
from google.colab import drive
drive.mount('/content/gdrive',force_remount=True)
# Out:
# Mounted at /content/gdrive

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import sys
import math
from sklearn.model_selection import train_test_split
# %tensorflow_version 2.x
import tensorflow as tf
from tensorflow.image import resize
from tensorflow import keras
from tensorflow.keras.utils import to_categorical, Sequence
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras import layers
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
import string

path = '/content/gdrive/My Drive/Dacon/ComputerVision/'
path_train = path + 'train.csv'
path_test = path + 'test.csv'
path_submission = path + 'submission.csv'

device_name = tf.test.gpu_device_name()
if device_name != '/device:GPU:0':
    raise SystemError('GPU device not found')
print('Found GPU at: {}'.format(device_name))
# Out:
# Found GPU at: /device:GPU:0

# %%
## Global Variables ##
ImageGen_coeff = 10
N_dim = 224
epochs_num = 80
verbose = 2
batch_size = 32
train_val_ratio = 0.9
def get_progressbar_str(progress):
    MAX_LEN = 30
    BAR_LEN = int(MAX_LEN * progress)
    return ('Progress:[' + '=' * BAR_LEN +
            ('>' if BAR_LEN < MAX_LEN else '') +
            ' ' * (MAX_LEN - BAR_LEN) +
            '] %.1f%%' % (progress * 100.))

# %%
def prepare_datasets():
    '''
    ImageGen_coeff (Global Variable) : number of ImageDataGenerator generation per image
    N_dim (Global Variable) : we'll change the size of the image from (28,28) to (N_dim,N_dim)

    Since we don't have enough RAM for the resized image of test_pixel, we just return non-resized, non-standardized image.
    When we generate each batchs by making use of the tf.utils.Sequential class, we'll resize and standardize test_pixel.
    '''
    train_raw = pd.read_csv(path_train)

    letter_hash = dict(zip(string.ascii_uppercase, [[1 if i == j else 0 for j in range(26)] for i in range(26)]))
    letter_hash_func = lambda letter : letter_hash[letter]

    ### only for validation 
    point_to = int(len(train_raw) * train_val_ratio)
    train_raw = train_raw.sample(frac=1)
    validation_raw = train_raw.iloc[point_to:,:]
    train_raw = train_raw.iloc[:point_to,:]
    
    with tf.device('/device:GPU:0'):
        validation_pixel = resize(validation_raw.iloc[:,3:].values.astype('int32').reshape(-1,28,28,1), [N_dim,N_dim], method = tf.image.ResizeMethod.BICUBIC).numpy()
    validation_pixel = validation_pixel / 255.0
    validation_fix = validation_raw.iloc[:,1:3].values
    datagenerator = ImageDataGenerator(rotation_range=10, zoom_range=0.10, width_shift_range=0.1,height_shift_range=0.1)
    gen = datagenerator.flow(validation_pixel, validation_fix, shuffle=False, batch_size=32)
    pixel, fixed, batch_index, limit = [], [], 0, int((len(validation_pixel) / 32) * ImageGen_coeff)
    while batch_index <= limit:
        try:
            data = gen.next()
            pixel += list(data[0])
            fixed += list(data[1])
            batch_index += 1
        except:
            print("ImageGeneratorError")
            break

    validation_pixel = np.asarray(pixel)
    validation_label = np.asarray(list(map(letter_hash_func, np.asarray(fixed)[:,1])))
    validation_answer = to_categorical(np.asarray(fixed)[:,0], 10)
    ###

    pix = train_raw.iloc[:,3:].values.astype('int32').reshape(-1,28,28,1)
    with tf.device('/device:GPU:0'):
        pix = resize(pix, [N_dim,N_dim], method = tf.image.ResizeMethod.BICUBIC).numpy()
    pix = pix / 255.0
    fix = train_raw.iloc[:,1:3].values
    datagenerator = ImageDataGenerator(rotation_range=10, zoom_range=0.10, width_shift_range=0.1,height_shift_range=0.1)
    gen = datagenerator.flow(pix, fix, shuffle=False, batch_size=32)
    pixel, fixed, batch_index, limit = [], [], 0, int((len(pix) / 32) * ImageGen_coeff)
    while batch_index <= limit:
        try:
            data = gen.next()
            pixel += list(data[0])
            fixed += list(data[1])
            batch_index += 1
        except:
            print("ImageGeneratorError")
            break

    train_pixel = np.asarray(pixel)
    train_label = np.asarray(list(map(letter_hash_func, np.asarray(fixed)[:,1])))
    train_answer = to_categorical(np.asarray(fixed)[:,0], 10)

    return train_pixel, train_label, train_answer, validation_pixel, validation_label, validation_answer

def prepare_testset():
    letter_hash = dict(zip(string.ascii_uppercase, [[1 if i == j else 0 for j in range(26)] for i in range(26)]))
    letter_hash_func = lambda letter : letter_hash[letter]

    test_raw = pd.read_csv(path_test)
    test_pixel = test_raw.iloc[:,2:].values.astype('int32').reshape(-1,28,28,1)
    test_label = np.asarray(list(map(letter_hash_func, test_raw.iloc[:,1].values))).astype('float32')
    return test_pixel, test_label

test_pixel, test_label = prepare_testset()
print(test_pixel.shape, test_label.shape)
# Out:
# (20480, 28, 28, 1) (20480, 26)

# %%
def train_test_model(i):
    tf.keras.backend.clear_session()
    '''
    I shuffled dataset every time since i wanted to get enoughly distributed models.
    '''
    train_pixel, train_label, train_answer, valid_pixel, valid_label, valid_answer = prepare_datasets()
    callbacks1 = [tf.keras.callbacks.EarlyStopping(monitor = 'val_accuracy', patience = 15, restore_best_weights = True), ReduceLROnPlateau(monitor = 'loss', patience = 5)]
    ModelName = 'InceptionResnetV2_bicubic224_val'
    print(ModelName + '  ' + str(i))
    with tf.device('/device:GPU:0'):
        cnn = tf.keras.applications.InceptionResNetV2(include_top=False, weights=None, input_tensor=None, input_shape=(N_dim,N_dim,1),pooling=None)
        cnn_mid = layers.GlobalAveragePooling2D()(cnn.output)
        cnn_out = layers.Dense(128, activation = 'relu')(cnn_mid)

        dense_input = layers.Input(shape=(26,))
        dense_mid = layers.Dense(52, activation = 'relu')(dense_input)
        dense_output = layers.Dense(52, activation = 'relu')(dense_mid)
        dense_model = tf.keras.Model(inputs=dense_input, outputs=dense_output)

        concatenated = layers.concatenate([cnn_out, dense_model.output])
        concatenated = layers.Dense(32, activation='relu')(concatenated)
        concat_output = layers.Dense(10, activation='softmax')(concatenated)
        concat_model = tf.keras.models.Model([cnn.input, dense_input], concat_output)
        concat_model.compile(optimizer="adam", loss="categorical_crossentropy", metrics=["accuracy"])
        history = concat_model.fit([train_pixel, train_label], train_answer, validation_data=([valid_pixel, valid_label], valid_answer), epochs=epochs_num, verbose=verbose, callbacks = callbacks1)
    print(
        f"Train accuracy={max(history.history['accuracy']):.5f}, " +
        f"Validation accuracy={max(history.history['val_accuracy']):.5f}"
    )
    with tf.device('/device:GPU:0'):
        concat_model.fit([valid_pixel, valid_label], valid_answer, epochs=5, verbose=verbose)
    concat_model.save(path + ModelName + '_' + str(i) + '.h5')

for i in range(5):
    train_test_model(i)
# Out:
# InceptionResnetV2_bicubic224_val  0
# Epoch 1/80
# 573/573 - 126s - loss: 0.7789 - accuracy: 0.7397 - val_loss: 2.3420 - val_accuracy: 0.3965
# Epoch 2/80
# 573/573 - 122s - loss: 0.2694 - accuracy: 0.9127 - val_loss: 0.7520 - val_accuracy: 0.7800
# Epoch 3/80
# 573/573 - 122s - loss: 0.1549 - accuracy: 0.9483 - val_loss: 0.6956 - val_accuracy: 0.7805
# Epoch 4/80
# 573/573 - 122s - loss: 0.1128 - accuracy: 0.9630 - val_loss: 0.3771 - val_accuracy: 0.8900
# Epoch 5/80
# 573/573 - 122s - loss: 0.0930 - accuracy: 0.9698 - val_loss: 0.4955 - val_accuracy: 0.8806
# Epoch 6/80
# 573/573 - 122s - loss: 0.0737 - accuracy: 0.9761 - val_loss: 0.6902 - val_accuracy: 0.8434
# Epoch 7/80
# 573/573 - 122s - loss: 0.0515 - accuracy: 0.9824 - val_loss: 0.9045 - val_accuracy: 0.8140
# Epoch 8/80
# 573/573 - 122s - loss: 0.0575 - accuracy: 0.9821 - val_loss: 0.6825 - val_accuracy: 0.8434
# Epoch 9/80
# 573/573 - 122s - loss: 0.0428 - accuracy: 0.9862 - val_loss: 0.7333 - val_accuracy: 0.8318
# Epoch 10/80
# 573/573 - 122s - loss: 0.0354 - accuracy: 0.9891 - val_loss: 0.5291 - val_accuracy: 0.8916
# Epoch 11/80
# 573/573 - 123s - loss: 0.0394 - accuracy: 0.9876 - val_loss: 0.4958 - val_accuracy: 0.8842
# Epoch 12/80
# 573/573 - 123s - loss: 0.0306 - accuracy: 0.9911 - val_loss: 0.6848 - val_accuracy: 0.8345
# Epoch 13/80
# 573/573 - 122s - loss: 0.0354 - accuracy: 0.9877 - val_loss: 0.5290 - val_accuracy: 0.8889
# Epoch 14/80
# 573/573 - 123s - loss: 0.0294 - accuracy: 0.9909 - val_loss: 1.2078 - val_accuracy: 0.7727
# Epoch 15/80
# 573/573 - 122s - loss: 0.0219 - accuracy: 0.9932 - val_loss: 0.6906 - val_accuracy: 0.8518
# Epoch 16/80
# 573/573 - 123s - loss: 0.0195 - accuracy: 0.9944 - val_loss: 0.5297 - val_accuracy: 0.9036
# Epoch 17/80
# 573/573 - 123s - loss: 0.0329 - accuracy: 0.9903 - val_loss: 0.5385 - val_accuracy: 0.8811
# Epoch 18/80
# 573/573 - 123s - loss: 0.0277 - accuracy: 0.9917 - val_loss: 0.5007 - val_accuracy: 0.8874
# Epoch 19/80
# 573/573 - 123s - loss: 0.0216 - accuracy: 0.9939 - val_loss: 0.7148 - val_accuracy: 0.8811
# Epoch 20/80
# 573/573 - 122s - loss: 0.0119 - accuracy: 0.9966 - val_loss: 0.5775 - val_accuracy: 0.8790
# Epoch 21/80
# 573/573 - 122s - loss: 0.0283 - accuracy: 0.9914 - val_loss: 0.6569 - val_accuracy: 0.8622
# Epoch 22/80
# 573/573 - 122s - loss: 0.0153 - accuracy: 0.9957 - val_loss: 0.6038 - val_accuracy: 0.8910
# Epoch 23/80
# 573/573 - 122s - loss: 0.0233 - accuracy: 0.9939 - val_loss: 0.5274 - val_accuracy: 0.8931
# Epoch 24/80
# 573/573 - 122s - loss: 0.0066 - accuracy: 0.9981 - val_loss: 0.3989 - val_accuracy: 0.9109
# Epoch 25/80
# 573/573 - 122s - loss: 0.0308 - accuracy: 0.9913 - val_loss: 0.7829 - val_accuracy: 0.8554
# Epoch 26/80
# 573/573 - 122s - loss: 0.0153 - accuracy: 0.9955 - val_loss: 0.3620 - val_accuracy: 0.9146
# Epoch 27/80
# 573/573 - 121s - loss: 0.0064 - accuracy: 0.9983 - val_loss: 0.6636 - val_accuracy: 0.8701
# Epoch 28/80
# 573/573 - 121s - loss: 0.0228 - accuracy: 0.9937 - val_loss: 0.5196 - val_accuracy: 0.9020
# Epoch 29/80
# 573/573 - 121s - loss: 0.0120 - accuracy: 0.9967 - val_loss: 0.6776 - val_accuracy: 0.8643
# Epoch 30/80
# 573/573 - 121s - loss: 0.0156 - accuracy: 0.9955 - val_loss: 0.5876 - val_accuracy: 0.8821
# Epoch 31/80
# 573/573 - 121s - loss: 0.0159 - accuracy: 0.9960 - val_loss: 0.4428 - val_accuracy: 0.9052
# Epoch 32/80
# 573/573 - 121s - loss: 0.0220 - accuracy: 0.9936 - val_loss: 0.5639 - val_accuracy: 0.8963
# Epoch 33/80
# 573/573 - 122s - loss: 0.0026 - accuracy: 0.9996 - val_loss: 0.4497 - val_accuracy: 0.9136
# Epoch 34/80
# 573/573 - 122s - loss: 6.8980e-04 - accuracy: 0.9999 - val_loss: 0.4539 - val_accuracy: 0.9146
# Epoch 35/80
# 573/573 - 122s - loss: 7.2314e-04 - accuracy: 0.9999 - val_loss: 0.4420 - val_accuracy: 0.9157
# Epoch 36/80
# 573/573 - 122s - loss: 3.5656e-04 - accuracy: 0.9999 - val_loss: 0.4567 - val_accuracy: 0.9141
# Epoch 37/80
# 573/573 - 122s - loss: 3.0182e-04 - accuracy: 1.0000 - val_loss: 0.4549 - val_accuracy: 0.9172
# Epoch 38/80
# 573/573 - 122s - loss: 2.3097e-04 - accuracy: 1.0000 - val_loss: 0.4591 - val_accuracy: 0.9188
# Epoch 39/80
# 573/573 - 122s - loss: 4.3032e-04 - accuracy: 0.9999 - val_loss: 0.4694 - val_accuracy: 0.9172
# Epoch 40/80
# 573/573 - 122s - loss: 1.6942e-04 - accuracy: 0.9999 - val_loss: 0.4751 - val_accuracy: 0.9193
# Epoch 41/80
# 573/573 - 122s - loss: 2.1705e-04 - accuracy: 0.9999 - val_loss: 0.5181 - val_accuracy: 0.9109
# Epoch 42/80
# 573/573 - 121s - loss: 1.0482e-04 - accuracy: 1.0000 - val_loss: 0.5018 - val_accuracy: 0.9167
# Epoch 43/80
# 573/573 - 121s - loss: 5.1043e-05 - accuracy: 1.0000 - val_loss: 0.5051 - val_accuracy: 0.9162
# Epoch 44/80
# 573/573 - 121s - loss: 4.6541e-05 - accuracy: 1.0000 - val_loss: 0.4855 - val_accuracy: 0.9172
# Epoch 45/80
# 573/573 - 121s - loss: 7.1206e-05 - accuracy: 1.0000 - val_loss: 0.5161 - val_accuracy: 0.9120
# Epoch 46/80
# 573/573 - 121s - loss: 5.2177e-05 - accuracy: 1.0000 - val_loss: 0.5045 - val_accuracy: 0.9167
# Epoch 47/80
# 573/573 - 121s - loss: 2.4169e-05 - accuracy: 1.0000 - val_loss: 0.5033 - val_accuracy: 0.9204
# Epoch 48/80
# 573/573 - 121s - loss: 2.0496e-05 - accuracy: 1.0000 - val_loss: 0.5075 - val_accuracy: 0.9193
# Epoch 49/80
# 573/573 - 121s - loss: 2.3049e-05 - accuracy: 1.0000 - val_loss: 0.5097 - val_accuracy: 0.9193
# Epoch 50/80
# 573/573 - 121s - loss: 1.3003e-05 - accuracy: 1.0000 - val_loss: 0.5141 - val_accuracy: 0.9167
# Epoch 51/80
# 573/573 - 121s - loss: 2.9855e-05 - accuracy: 1.0000 - val_loss: 0.5120 - val_accuracy: 0.9183
# Epoch 52/80
# 573/573 - 121s - loss: 1.3873e-05 - accuracy: 1.0000 - val_loss: 0.5202 - val_accuracy: 0.9172
# Epoch 53/80
# 573/573 - 121s - loss: 4.4493e-05 - accuracy: 1.0000 - val_loss: 0.5153 - val_accuracy: 0.9172
# Epoch 54/80
# 573/573 - 121s - loss: 1.2787e-05 - accuracy: 1.0000 - val_loss: 0.5113 - val_accuracy: 0.9178
# Epoch 55/80
# 573/573 - 121s - loss: 3.5432e-05 - accuracy: 1.0000 - val_loss: 0.5131 - val_accuracy: 0.9183
# Epoch 56/80
# 573/573 - 121s - loss: 1.6315e-05 - accuracy: 1.0000 - val_loss: 0.5161 - val_accuracy: 0.9188
# Epoch 57/80
# 573/573 - 121s - loss: 1.9240e-05 - accuracy: 1.0000 - val_loss: 0.5161 - val_accuracy: 0.9188
# Epoch 58/80
# 573/573 - 121s - loss: 3.5729e-05 - accuracy: 1.0000 - val_loss: 0.5177 - val_accuracy: 0.9188
# Epoch 59/80
# 573/573 - 121s - loss: 1.2179e-05 - accuracy: 1.0000 - val_loss: 0.5148 - val_accuracy: 0.9178
# Epoch 60/80
# 573/573 - 121s - loss: 3.5192e-05 - accuracy: 1.0000 - val_loss: 0.5153 - val_accuracy: 0.9188
# Epoch 61/80
# 573/573 - 121s - loss: 1.0276e-05 - accuracy: 1.0000 - val_loss: 0.5150 - val_accuracy: 0.9188
# Epoch 62/80
# 573/573 - 122s - loss: 1.1194e-05 - accuracy: 1.0000 - val_loss: 0.5122 - val_accuracy: 0.9183
# Train accuracy=1.00000, Validation accuracy=0.92038
# Epoch 1/5
# 60/60 - 12s - loss: 0.5457 - accuracy: 0.9125
# Epoch 2/5
# 60/60 - 12s - loss: 0.5762 - accuracy: 0.9130
# Epoch 3/5
# 60/60 - 12s - loss: 0.5544 - accuracy: 0.9183
# Epoch 4/5
# 60/60 - 12s - loss: 0.5698 - accuracy: 0.9115
# Epoch 5/5
# 60/60 - 12s - loss: 0.5671 - accuracy: 0.9125
# InceptionResnetV2_bicubic224_val  1
# Epoch 1/80
# 573/573 - 125s - loss: 0.9150 - accuracy: 0.6847 - val_loss: 3.1108 - val_accuracy: 0.1917
# Epoch 2/80
# 573/573 - 121s - loss: 0.2790 - accuracy: 0.9079 - val_loss: 3.7721 - val_accuracy: 0.4159
# Epoch 3/80
# 573/573 - 121s - loss: 0.1615 - accuracy: 0.9467 - val_loss: 0.4785 - val_accuracy: 0.8628
# Epoch 4/80
# 573/573 - 121s - loss: 0.1100 - accuracy: 0.9637 - val_loss: 0.6070 - val_accuracy: 0.8324
# Epoch 5/80
# 573/573 - 121s - loss: 0.0863 - accuracy: 0.9708 - val_loss: 0.8613 - val_accuracy: 0.8140
# Epoch 6/80
# 573/573 - 121s - loss: 0.0727 - accuracy: 0.9762 - val_loss: 0.5494 - val_accuracy: 0.8491
# Epoch 7/80
# 573/573 - 121s - loss: 0.0523 - accuracy: 0.9824 - val_loss: 1.2252 - val_accuracy: 0.7716
# Epoch 8/80
# 573/573 - 121s - loss: 0.0528 - accuracy: 0.9832 - val_loss: 0.6370 - val_accuracy: 0.8649
# Epoch 9/80
# 573/573 - 121s - loss: 0.0480 - accuracy: 0.9836 - val_loss: 0.7442 - val_accuracy: 0.8402
# Epoch 10/80
# 573/573 - 121s - loss: 0.0333 - accuracy: 0.9897 - val_loss: 0.8759 - val_accuracy: 0.8523
# Epoch 11/80
# 573/573 - 121s - loss: 0.0416 - accuracy: 0.9867 - val_loss: 0.5803 - val_accuracy: 0.8743
# Epoch 12/80
# 573/573 - 121s - loss: 0.0447 - accuracy: 0.9861 - val_loss: 0.5408 - val_accuracy: 0.8743
# Epoch 13/80
# 573/573 - 121s - loss: 0.0240 - accuracy: 0.9927 - val_loss: 0.9216 - val_accuracy: 0.8324
# Epoch 14/80
# 573/573 - 121s - loss: 0.0369 - accuracy: 0.9883 - val_loss: 0.6264 - val_accuracy: 0.8743
# Epoch 15/80
# 573/573 - 121s - loss: 0.0165 - accuracy: 0.9952 - val_loss: 0.8545 - val_accuracy: 0.8397
# Epoch 16/80
# 573/573 - 121s - loss: 0.0392 - accuracy: 0.9886 - val_loss: 0.7106 - val_accuracy: 0.8628
# Epoch 17/80
# 573/573 - 121s - loss: 0.0175 - accuracy: 0.9947 - val_loss: 0.6197 - val_accuracy: 0.8779
# Epoch 18/80
# 573/573 - 121s - loss: 0.0304 - accuracy: 0.9913 - val_loss: 0.4666 - val_accuracy: 0.8994
# Epoch 19/80
# 573/573 - 121s - loss: 0.0175 - accuracy: 0.9951 - val_loss: 0.4702 - val_accuracy: 0.9015
# Epoch 20/80
# 573/573 - 121s - loss: 0.0153 - accuracy: 0.9963 - val_loss: 0.8181 - val_accuracy: 0.8434
# Epoch 21/80
# 573/573 - 121s - loss: 0.0296 - accuracy: 0.9917 - val_loss: 1.0389 - val_accuracy: 0.8062
# Epoch 22/80
# 573/573 - 121s - loss: 0.0173 - accuracy: 0.9950 - val_loss: 0.7870 - val_accuracy: 0.8638
# Epoch 23/80
# 573/573 - 121s - loss: 0.0239 - accuracy: 0.9933 - val_loss: 1.4412 - val_accuracy: 0.7805
# Epoch 24/80
# 573/573 - 121s - loss: 0.0228 - accuracy: 0.9939 - val_loss: 0.9370 - val_accuracy: 0.8444
# Epoch 25/80
# 573/573 - 121s - loss: 0.0215 - accuracy: 0.9941 - val_loss: 0.8265 - val_accuracy: 0.8460
# Epoch 26/80
# 573/573 - 121s - loss: 0.0047 - accuracy: 0.9986 - val_loss: 0.5872 - val_accuracy: 0.8937
# Epoch 27/80
# 573/573 - 121s - loss: 0.0011 - accuracy: 0.9998 - val_loss: 0.5873 - val_accuracy: 0.8963
# Epoch 28/80
# 573/573 - 121s - loss: 6.5127e-04 - accuracy: 0.9999 - val_loss: 0.6029 - val_accuracy: 0.8921
# Epoch 29/80
# 573/573 - 121s - loss: 5.2319e-04 - accuracy: 0.9999 - val_loss: 0.5857 - val_accuracy: 0.9005
# Epoch 30/80
# 573/573 - 121s - loss: 2.8661e-04 - accuracy: 1.0000 - val_loss: 0.5975 - val_accuracy: 0.8999
# Epoch 31/80
# 573/573 - 121s - loss: 2.1922e-04 - accuracy: 1.0000 - val_loss: 0.6258 - val_accuracy: 0.8994
# Epoch 32/80
# 573/573 - 121s - loss: 1.7520e-04 - accuracy: 1.0000 - val_loss: 0.6181 - val_accuracy: 0.8999
# Epoch 33/80
# 573/573 - 121s - loss: 3.1299e-04 - accuracy: 0.9999 - val_loss: 0.6683 - val_accuracy: 0.8979
# Epoch 34/80
# 573/573 - 121s - loss: 2.3898e-04 - accuracy: 0.9999 - val_loss: 0.6402 - val_accuracy: 0.9026
# Epoch 35/80
# 573/573 - 121s - loss: 2.7732e-04 - accuracy: 0.9999 - val_loss: 0.6344 - val_accuracy: 0.9026
# Epoch 36/80
# 573/573 - 121s - loss: 1.3919e-04 - accuracy: 1.0000 - val_loss: 0.6021 - val_accuracy: 0.9062
# Epoch 37/80
# 573/573 - 121s - loss: 5.7318e-05 - accuracy: 1.0000 - val_loss: 0.6226 - val_accuracy: 0.9047
# Epoch 38/80
# 573/573 - 122s - loss: 1.3379e-04 - accuracy: 0.9999 - val_loss: 0.6774 - val_accuracy: 0.9031
# Epoch 39/80
# 573/573 - 122s - loss: 6.5183e-05 - accuracy: 1.0000 - val_loss: 0.6713 - val_accuracy: 0.9015
# Epoch 40/80
# 573/573 - 122s - loss: 3.6501e-05 - accuracy: 1.0000 - val_loss: 0.6672 - val_accuracy: 0.9031
# Epoch 41/80
# 573/573 - 122s - loss: 5.4868e-05 - accuracy: 1.0000 - val_loss: 0.6958 - val_accuracy: 0.9005
# Epoch 42/80
# 573/573 - 122s - loss: 5.1701e-05 - accuracy: 1.0000 - val_loss: 0.7106 - val_accuracy: 0.9052
# Epoch 43/80
# 573/573 - 122s - loss: 5.8262e-05 - accuracy: 0.9999 - val_loss: 0.7086 - val_accuracy: 0.9036
# Epoch 44/80
# 573/573 - 122s - loss: 2.1748e-05 - accuracy: 1.0000 - val_loss: 0.7069 - val_accuracy: 0.9036
# Epoch 45/80
# 573/573 - 122s - loss: 4.6017e-05 - accuracy: 1.0000 - val_loss: 0.7090 - val_accuracy: 0.9047
# Epoch 46/80
# 573/573 - 122s - loss: 3.5607e-05 - accuracy: 1.0000 - val_loss: 0.7040 - val_accuracy: 0.9031
# Epoch 47/80
# 573/573 - 121s - loss: 1.1362e-05 - accuracy: 1.0000 - val_loss: 0.7086 - val_accuracy: 0.9041
# Epoch 48/80
# 573/573 - 121s - loss: 1.3657e-05 - accuracy: 1.0000 - val_loss: 0.7069 - val_accuracy: 0.9031
# Epoch 49/80
# 573/573 - 121s - loss: 1.1775e-05 - accuracy: 1.0000 - val_loss: 0.7112 - val_accuracy: 0.9036
# Epoch 50/80
# 573/573 - 121s - loss: 1.6521e-05 - accuracy: 1.0000 - val_loss: 0.7067 - val_accuracy: 0.9047
# Epoch 51/80
# 573/573 - 121s - loss: 3.4907e-05 - accuracy: 1.0000 - val_loss: 0.7092 - val_accuracy: 0.9041
# Train accuracy=1.00000, Validation accuracy=0.90623
# Epoch 1/5
# 60/60 - 12s - loss: 0.6615 - accuracy: 0.8910
# Epoch 2/5
# 60/60 - 12s - loss: 0.6167 - accuracy: 0.8989
# Epoch 3/5
# 60/60 - 12s - loss: 0.6229 - accuracy: 0.8984
# Epoch 4/5
# 60/60 - 12s - loss: 0.5868 - accuracy: 0.9041
# Epoch 5/5
# 60/60 - 12s - loss: 0.5708 - accuracy: 0.9062
# InceptionResnetV2_bicubic224_val  2
# Epoch 1/80
# 573/573 - 125s - loss: 0.7748 - accuracy: 0.7360 - val_loss: 2.9760 - val_accuracy: 0.3483
# Epoch 2/80
# 573/573 - 122s - loss: 0.2669 - accuracy: 0.9114 - val_loss: 0.5576 - val_accuracy: 0.8460
# Epoch 3/80
# 573/573 - 122s - loss: 0.1554 - accuracy: 0.9488 - val_loss: 0.8818 - val_accuracy: 0.7674
# Epoch 4/80
# 573/573 - 122s - loss: 0.1135 - accuracy: 0.9625 - val_loss: 0.6872 - val_accuracy: 0.8214
# Epoch 5/80
# 573/573 - 122s - loss: 0.0704 - accuracy: 0.9774 - val_loss: 0.4771 - val_accuracy: 0.8806
# Epoch 6/80
# 573/573 - 122s - loss: 0.0686 - accuracy: 0.9781 - val_loss: 0.8934 - val_accuracy: 0.8266
# Epoch 7/80
# 573/573 - 122s - loss: 0.0647 - accuracy: 0.9797 - val_loss: 0.8018 - val_accuracy: 0.8502
# Epoch 8/80
# 573/573 - 122s - loss: 0.0568 - accuracy: 0.9815 - val_loss: 0.8865 - val_accuracy: 0.8083
# Epoch 9/80
# 573/573 - 122s - loss: 0.0411 - accuracy: 0.9863 - val_loss: 0.6041 - val_accuracy: 0.8455
# Epoch 10/80
# 573/573 - 122s - loss: 0.0513 - accuracy: 0.9854 - val_loss: 0.7130 - val_accuracy: 0.8465
# Epoch 11/80
# 573/573 - 122s - loss: 0.0338 - accuracy: 0.9898 - val_loss: 0.5846 - val_accuracy: 0.8596
# Epoch 12/80
# 573/573 - 122s - loss: 0.0383 - accuracy: 0.9880 - val_loss: 0.4487 - val_accuracy: 0.8821
# Epoch 13/80
# 573/573 - 122s - loss: 0.0324 - accuracy: 0.9908 - val_loss: 1.0482 - val_accuracy: 0.7905
# Epoch 14/80
# 573/573 - 122s - loss: 0.0246 - accuracy: 0.9925 - val_loss: 0.5833 - val_accuracy: 0.8717
# Epoch 15/80
# 573/573 - 122s - loss: 0.0361 - accuracy: 0.9901 - val_loss: 0.4623 - val_accuracy: 0.8816
# Epoch 16/80
# 573/573 - 122s - loss: 0.0259 - accuracy: 0.9916 - val_loss: 0.4616 - val_accuracy: 0.8916
# Epoch 17/80
# 573/573 - 122s - loss: 0.0207 - accuracy: 0.9937 - val_loss: 0.6649 - val_accuracy: 0.8491
# Epoch 18/80
# 573/573 - 122s - loss: 0.0273 - accuracy: 0.9917 - val_loss: 0.6191 - val_accuracy: 0.8680
# Epoch 19/80
# 573/573 - 122s - loss: 0.0254 - accuracy: 0.9926 - val_loss: 0.8613 - val_accuracy: 0.8428
# Epoch 20/80
# 573/573 - 122s - loss: 0.0280 - accuracy: 0.9925 - val_loss: 0.4943 - val_accuracy: 0.8968
# Epoch 21/80
# 573/573 - 122s - loss: 0.0139 - accuracy: 0.9960 - val_loss: 0.4231 - val_accuracy: 0.9167
# Epoch 22/80
# 573/573 - 122s - loss: 0.0239 - accuracy: 0.9924 - val_loss: 0.4208 - val_accuracy: 0.9157
# Epoch 23/80
# 573/573 - 122s - loss: 0.0070 - accuracy: 0.9979 - val_loss: 0.8455 - val_accuracy: 0.8559
# Epoch 24/80
# 573/573 - 122s - loss: 0.0276 - accuracy: 0.9916 - val_loss: 0.7367 - val_accuracy: 0.8675
# Epoch 25/80
# 573/573 - 122s - loss: 0.0181 - accuracy: 0.9951 - val_loss: 0.4258 - val_accuracy: 0.9104
# Epoch 26/80
# 573/573 - 122s - loss: 0.0071 - accuracy: 0.9982 - val_loss: 0.8999 - val_accuracy: 0.8371
# Epoch 27/80
# 573/573 - 122s - loss: 0.0262 - accuracy: 0.9928 - val_loss: 0.3890 - val_accuracy: 0.9094
# Epoch 28/80
# 573/573 - 122s - loss: 0.0147 - accuracy: 0.9964 - val_loss: 0.5704 - val_accuracy: 0.8774
# Epoch 29/80
# 573/573 - 122s - loss: 9.5335e-04 - accuracy: 0.9997 - val_loss: 0.5088 - val_accuracy: 0.8994
# Epoch 30/80
# 573/573 - 122s - loss: 4.3069e-04 - accuracy: 0.9999 - val_loss: 0.4775 - val_accuracy: 0.9041
# Epoch 31/80
# 573/573 - 123s - loss: 4.2423e-04 - accuracy: 0.9998 - val_loss: 0.4572 - val_accuracy: 0.9115
# Epoch 32/80
# 573/573 - 123s - loss: 1.9247e-04 - accuracy: 1.0000 - val_loss: 0.4563 - val_accuracy: 0.9104
# Epoch 33/80
# 573/573 - 123s - loss: 1.5166e-04 - accuracy: 1.0000 - val_loss: 0.4627 - val_accuracy: 0.9130
# Epoch 34/80
# 573/573 - 123s - loss: 1.5681e-04 - accuracy: 1.0000 - val_loss: 0.4476 - val_accuracy: 0.9172
# Epoch 35/80
# 573/573 - 123s - loss: 3.1922e-04 - accuracy: 0.9999 - val_loss: 0.4614 - val_accuracy: 0.9099
# Epoch 36/80
# 573/573 - 123s - loss: 2.1245e-04 - accuracy: 0.9999 - val_loss: 0.4268 - val_accuracy: 0.9172
# Epoch 37/80
# 573/573 - 123s - loss: 2.0674e-04 - accuracy: 0.9999 - val_loss: 0.4294 - val_accuracy: 0.9146
# Epoch 38/80
# 573/573 - 123s - loss: 1.8588e-04 - accuracy: 0.9999 - val_loss: 0.4317 - val_accuracy: 0.9183
# Epoch 39/80
# 573/573 - 123s - loss: 1.5032e-04 - accuracy: 0.9999 - val_loss: 0.4264 - val_accuracy: 0.9167
# Epoch 40/80
# 573/573 - 122s - loss: 7.0369e-05 - accuracy: 1.0000 - val_loss: 0.4260 - val_accuracy: 0.9167
# Epoch 41/80
# 573/573 - 122s - loss: 9.0490e-05 - accuracy: 1.0000 - val_loss: 0.4266 - val_accuracy: 0.9162
# Epoch 42/80
# 573/573 - 122s - loss: 7.7109e-05 - accuracy: 1.0000 - val_loss: 0.4270 - val_accuracy: 0.9183
# Epoch 43/80
# 573/573 - 122s - loss: 5.8984e-05 - accuracy: 1.0000 - val_loss: 0.4270 - val_accuracy: 0.9204
# Epoch 44/80
# 573/573 - 122s - loss: 5.1591e-05 - accuracy: 1.0000 - val_loss: 0.4326 - val_accuracy: 0.9204
# Epoch 45/80
# 573/573 - 122s - loss: 4.8122e-05 - accuracy: 1.0000 - val_loss: 0.4330 - val_accuracy: 0.9209
# Epoch 46/80
# 573/573 - 122s - loss: 3.2160e-05 - accuracy: 1.0000 - val_loss: 0.4291 - val_accuracy: 0.9225
# Epoch 47/80
# 573/573 - 122s - loss: 5.1928e-05 - accuracy: 1.0000 - val_loss: 0.4327 - val_accuracy: 0.9209
# Epoch 48/80
# 573/573 - 122s - loss: 6.6034e-05 - accuracy: 1.0000 - val_loss: 0.4356 - val_accuracy: 0.9204
# Epoch 49/80
# 573/573 - 122s - loss: 3.8195e-05 - accuracy: 1.0000 - val_loss: 0.4335 - val_accuracy: 0.9219
# Epoch 50/80
# 573/573 - 122s - loss: 5.7261e-05 - accuracy: 1.0000 - val_loss: 0.4316 - val_accuracy: 0.9209
# Epoch 51/80
# 573/573 - 122s - loss: 3.7803e-05 - accuracy: 1.0000 - val_loss: 0.4344 - val_accuracy: 0.9188
# Epoch 52/80
# 573/573 - 122s - loss: 4.8393e-05 - accuracy: 1.0000 - val_loss: 0.4370 - val_accuracy: 0.9193
# Epoch 53/80
# 573/573 - 122s - loss: 8.6692e-05 - accuracy: 0.9999 - val_loss: 0.4343 - val_accuracy: 0.9214
# Epoch 54/80
# 573/573 - 122s - loss: 3.7601e-05 - accuracy: 1.0000 - val_loss: 0.4363 - val_accuracy: 0.9188
# Epoch 55/80
# 573/573 - 122s - loss: 3.9814e-05 - accuracy: 1.0000 - val_loss: 0.4372 - val_accuracy: 0.9209
# Epoch 56/80
# 573/573 - 122s - loss: 6.1849e-05 - accuracy: 1.0000 - val_loss: 0.4362 - val_accuracy: 0.9199
# Epoch 57/80
# 573/573 - 122s - loss: 4.6586e-05 - accuracy: 1.0000 - val_loss: 0.4324 - val_accuracy: 0.9214
# Epoch 58/80
# 573/573 - 122s - loss: 4.0816e-05 - accuracy: 1.0000 - val_loss: 0.4317 - val_accuracy: 0.9209
# Epoch 59/80
# 573/573 - 122s - loss: 4.2904e-05 - accuracy: 1.0000 - val_loss: 0.4347 - val_accuracy: 0.9193
# Epoch 60/80
# 573/573 - 122s - loss: 7.7708e-05 - accuracy: 1.0000 - val_loss: 0.4368 - val_accuracy: 0.9209
# Epoch 61/80
# 573/573 - 122s - loss: 4.2563e-05 - accuracy: 1.0000 - val_loss: 0.4314 - val_accuracy: 0.9225
# Train accuracy=1.00000, Validation accuracy=0.92247
# Epoch 1/5
# 60/60 - 12s - loss: 0.5090 - accuracy: 0.9052
# Epoch 2/5
# 60/60 - 12s - loss: 0.5003 - accuracy: 0.9104
# Epoch 3/5
# 60/60 - 12s - loss: 0.5158 - accuracy: 0.9062
# Epoch 4/5
# 60/60 - 12s - loss: 0.5036 - accuracy: 0.9083
# Epoch 5/5
# 60/60 - 12s - loss: 0.5064 - accuracy: 0.9094
# InceptionResnetV2_bicubic224_val  3
# Epoch 1/80
# 573/573 - 125s - loss: 0.8254 - accuracy: 0.7168 - val_loss: 3.7629 - val_accuracy: 0.3049
# Epoch 2/80
# 573/573 - 122s - loss: 0.2779 - accuracy: 0.9072 - val_loss: 0.8737 - val_accuracy: 0.7658
# Epoch 3/80
# 573/573 - 122s - loss: 0.1732 - accuracy: 0.9426 - val_loss: 0.5811 - val_accuracy: 0.8413
# Epoch 4/80
# 573/573 - 122s - loss: 0.1091 - accuracy: 0.9641 - val_loss: 0.6663 - val_accuracy: 0.8329
# Epoch 5/80
# 573/573 - 122s - loss: 0.0922 - accuracy: 0.9708 - val_loss: 0.6418 - val_accuracy: 0.8497
# Epoch 6/80
# 573/573 - 122s - loss: 0.0755 - accuracy: 0.9756 - val_loss: 0.5917 - val_accuracy: 0.8465
# Epoch 7/80
# 573/573 - 122s - loss: 0.0558 - accuracy: 0.9829 - val_loss: 0.6853 - val_accuracy: 0.8360
# Epoch 8/80
# 573/573 - 122s - loss: 0.0589 - accuracy: 0.9814 - val_loss: 0.5452 - val_accuracy: 0.8612
# Epoch 9/80
# 573/573 - 122s - loss: 0.0450 - accuracy: 0.9850 - val_loss: 0.6733 - val_accuracy: 0.8544
# Epoch 10/80
# 573/573 - 122s - loss: 0.0417 - accuracy: 0.9876 - val_loss: 0.7029 - val_accuracy: 0.8360
# Epoch 11/80
# 573/573 - 122s - loss: 0.0368 - accuracy: 0.9892 - val_loss: 0.6915 - val_accuracy: 0.8486
# Epoch 12/80
# 573/573 - 121s - loss: 0.0468 - accuracy: 0.9851 - val_loss: 0.7921 - val_accuracy: 0.8376
# Epoch 13/80
# 573/573 - 122s - loss: 0.0332 - accuracy: 0.9901 - val_loss: 0.8832 - val_accuracy: 0.8245
# Epoch 14/80
# 573/573 - 122s - loss: 0.0209 - accuracy: 0.9940 - val_loss: 1.4588 - val_accuracy: 0.7648
# Epoch 15/80
# 573/573 - 122s - loss: 0.0473 - accuracy: 0.9850 - val_loss: 0.6648 - val_accuracy: 0.8376
# Epoch 16/80
# 573/573 - 122s - loss: 0.0165 - accuracy: 0.9945 - val_loss: 0.9498 - val_accuracy: 0.8156
# Epoch 17/80
# 573/573 - 122s - loss: 0.0339 - accuracy: 0.9893 - val_loss: 0.7401 - val_accuracy: 0.8366
# Epoch 18/80
# 573/573 - 122s - loss: 0.0308 - accuracy: 0.9908 - val_loss: 0.6635 - val_accuracy: 0.8664
# Epoch 19/80
# 573/573 - 122s - loss: 0.0075 - accuracy: 0.9979 - val_loss: 0.5519 - val_accuracy: 0.8916
# Epoch 20/80
# 573/573 - 122s - loss: 0.0288 - accuracy: 0.9913 - val_loss: 0.6032 - val_accuracy: 0.8738
# Epoch 21/80
# 573/573 - 122s - loss: 0.0094 - accuracy: 0.9971 - val_loss: 0.6307 - val_accuracy: 0.8727
# Epoch 22/80
# 573/573 - 121s - loss: 0.0286 - accuracy: 0.9917 - val_loss: 0.8297 - val_accuracy: 0.8486
# Epoch 23/80
# 573/573 - 121s - loss: 0.0179 - accuracy: 0.9944 - val_loss: 0.5713 - val_accuracy: 0.8743
# Epoch 24/80
# 573/573 - 121s - loss: 0.0184 - accuracy: 0.9950 - val_loss: 0.8599 - val_accuracy: 0.8392
# Epoch 25/80
# 573/573 - 121s - loss: 0.0040 - accuracy: 0.9990 - val_loss: 0.4795 - val_accuracy: 0.8994
# Epoch 26/80
# 573/573 - 121s - loss: 9.7581e-04 - accuracy: 0.9998 - val_loss: 0.4955 - val_accuracy: 0.8999
# Epoch 27/80
# 573/573 - 121s - loss: 7.3083e-04 - accuracy: 0.9998 - val_loss: 0.4865 - val_accuracy: 0.9015
# Epoch 28/80
# 573/573 - 121s - loss: 3.4160e-04 - accuracy: 1.0000 - val_loss: 0.4857 - val_accuracy: 0.9020
# Epoch 29/80
# 573/573 - 121s - loss: 2.8707e-04 - accuracy: 0.9999 - val_loss: 0.4945 - val_accuracy: 0.9005
# Epoch 30/80
# 573/573 - 121s - loss: 1.8919e-04 - accuracy: 1.0000 - val_loss: 0.4969 - val_accuracy: 0.9010
# Epoch 31/80
# 573/573 - 121s - loss: 1.7551e-04 - accuracy: 1.0000 - val_loss: 0.5180 - val_accuracy: 0.8963
# Epoch 32/80
# 573/573 - 121s - loss: 1.3861e-04 - accuracy: 1.0000 - val_loss: 0.5332 - val_accuracy: 0.9005
# Epoch 33/80
# 573/573 - 121s - loss: 1.3209e-04 - accuracy: 1.0000 - val_loss: 0.5037 - val_accuracy: 0.9083
# Epoch 34/80
# 573/573 - 121s - loss: 4.9699e-04 - accuracy: 0.9999 - val_loss: 0.5527 - val_accuracy: 0.9047
# Epoch 35/80
# 573/573 - 121s - loss: 1.4051e-04 - accuracy: 1.0000 - val_loss: 0.6139 - val_accuracy: 0.8979
# Epoch 36/80
# 573/573 - 121s - loss: 6.7636e-05 - accuracy: 1.0000 - val_loss: 0.6151 - val_accuracy: 0.8979
# Epoch 37/80
# 573/573 - 121s - loss: 1.3452e-04 - accuracy: 1.0000 - val_loss: 0.6049 - val_accuracy: 0.9005
# Epoch 38/80
# 573/573 - 121s - loss: 1.0170e-04 - accuracy: 1.0000 - val_loss: 0.6076 - val_accuracy: 0.8979
# Epoch 39/80
# 573/573 - 121s - loss: 5.8091e-05 - accuracy: 1.0000 - val_loss: 0.6013 - val_accuracy: 0.8989
# Epoch 40/80
# 573/573 - 121s - loss: 6.1510e-05 - accuracy: 1.0000 - val_loss: 0.5958 - val_accuracy: 0.8994
# Epoch 41/80
# 573/573 - 121s - loss: 7.9926e-05 - accuracy: 1.0000 - val_loss: 0.5899 - val_accuracy: 0.8984
# Epoch 42/80
# 573/573 - 121s - loss: 1.6215e-04 - accuracy: 0.9999 - val_loss: 0.5875 - val_accuracy: 0.8984
# Epoch 43/80
# 573/573 - 121s - loss: 5.4484e-05 - accuracy: 1.0000 - val_loss: 0.5830 - val_accuracy: 0.8973
# Epoch 44/80
# 573/573 - 121s - loss: 8.0020e-05 - accuracy: 1.0000 - val_loss: 0.5861 - val_accuracy: 0.8984
# Epoch 45/80
# 573/573 - 121s - loss: 1.0139e-04 - accuracy: 1.0000 - val_loss: 0.5869 - val_accuracy: 0.8984
# Epoch 46/80
# 573/573 - 121s - loss: 4.5997e-05 - accuracy: 1.0000 - val_loss: 0.5807 - val_accuracy: 0.8984
# Epoch 47/80
# 573/573 - 121s - loss: 8.7873e-05 - accuracy: 1.0000 - val_loss: 0.5884 - val_accuracy: 0.8979
# Epoch 48/80
# 573/573 - 121s - loss: 6.4211e-05 - accuracy: 1.0000 - val_loss: 0.5931 - val_accuracy: 0.8973
# Train accuracy=1.00000, Validation accuracy=0.90833
# Epoch 1/5
# 60/60 - 12s - loss: 0.5829 - accuracy: 0.9005
# Epoch 2/5
# 60/60 - 12s - loss: 0.5582 - accuracy: 0.9068
# Epoch 3/5
# 60/60 - 12s - loss: 0.5933 - accuracy: 0.8984
# Epoch 4/5
# 60/60 - 12s - loss: 0.5826 - accuracy: 0.9031
# Epoch 5/5
# 60/60 - 12s - loss: 0.5787 - accuracy: 0.8999
# InceptionResnetV2_bicubic224_val  4
# Epoch 1/80
# 573/573 - 125s - loss: 0.9057 - accuracy: 0.6895 - val_loss: 2.0408 - val_accuracy: 0.3756
# Epoch 2/80
# 573/573 - 122s - loss: 0.2751 - accuracy: 0.9079 - val_loss: 1.0505 - val_accuracy: 0.7218
# Epoch 3/80
# 573/573 - 122s - loss: 0.1535 - accuracy: 0.9483 - val_loss: 0.7773 - val_accuracy: 0.8381
# Epoch 4/80
# 573/573 - 121s - loss: 0.1163 - accuracy: 0.9625 - val_loss: 0.6389 - val_accuracy: 0.8345
# Epoch 5/80
# 573/573 - 121s - loss: 0.0824 - accuracy: 0.9721 - val_loss: 1.1139 - val_accuracy: 0.7370
# Epoch 6/80
# 573/573 - 122s - loss: 0.0716 - accuracy: 0.9775 - val_loss: 0.6676 - val_accuracy: 0.8518
# Epoch 7/80
# 573/573 - 122s - loss: 0.0546 - accuracy: 0.9833 - val_loss: 0.5881 - val_accuracy: 0.8544
# Epoch 8/80
# 573/573 - 121s - loss: 0.0610 - accuracy: 0.9813 - val_loss: 0.8975 - val_accuracy: 0.7742
# Epoch 9/80
# 573/573 - 122s - loss: 0.0396 - accuracy: 0.9864 - val_loss: 0.7485 - val_accuracy: 0.8345
# Epoch 10/80
# 573/573 - 122s - loss: 0.0344 - accuracy: 0.9891 - val_loss: 0.5523 - val_accuracy: 0.8926
# Epoch 11/80
# 573/573 - 122s - loss: 0.0435 - accuracy: 0.9864 - val_loss: 0.8013 - val_accuracy: 0.8476
# Epoch 12/80
# 573/573 - 122s - loss: 0.0403 - accuracy: 0.9875 - val_loss: 0.5588 - val_accuracy: 0.8863
# Epoch 13/80
# 573/573 - 122s - loss: 0.0233 - accuracy: 0.9931 - val_loss: 0.7749 - val_accuracy: 0.8628
# Epoch 14/80
# 573/573 - 122s - loss: 0.0400 - accuracy: 0.9884 - val_loss: 0.6058 - val_accuracy: 0.8717
# Epoch 15/80
# 573/573 - 122s - loss: 0.0285 - accuracy: 0.9918 - val_loss: 0.8545 - val_accuracy: 0.8329
# Epoch 16/80
# 573/573 - 121s - loss: 0.0213 - accuracy: 0.9938 - val_loss: 0.4787 - val_accuracy: 0.8889
# Epoch 17/80
# 573/573 - 120s - loss: 0.0244 - accuracy: 0.9934 - val_loss: 0.7165 - val_accuracy: 0.8345
# Epoch 18/80
# 573/573 - 120s - loss: 0.0244 - accuracy: 0.9921 - val_loss: 0.7131 - val_accuracy: 0.8596
# Epoch 19/80
# 573/573 - 120s - loss: 0.0131 - accuracy: 0.9962 - val_loss: 0.7110 - val_accuracy: 0.8596
# Epoch 20/80
# 573/573 - 120s - loss: 0.0236 - accuracy: 0.9936 - val_loss: 0.6434 - val_accuracy: 0.8785
# Epoch 21/80
# 573/573 - 120s - loss: 0.0301 - accuracy: 0.9907 - val_loss: 0.7144 - val_accuracy: 0.8591
# Epoch 22/80
# 573/573 - 120s - loss: 0.0179 - accuracy: 0.9947 - val_loss: 0.5526 - val_accuracy: 0.8764
# Epoch 23/80
# 573/573 - 120s - loss: 0.0010 - accuracy: 0.9998 - val_loss: 0.6791 - val_accuracy: 0.8858
# Epoch 24/80
# 573/573 - 120s - loss: 0.0344 - accuracy: 0.9902 - val_loss: 0.8749 - val_accuracy: 0.8371
# Epoch 25/80
# 573/573 - 121s - loss: 0.0169 - accuracy: 0.9944 - val_loss: 0.7287 - val_accuracy: 0.8575
# Train accuracy=0.99978, Validation accuracy=0.89261
# Epoch 1/5
# 60/60 - 12s - loss: 0.2909 - accuracy: 0.9267
# Epoch 2/5
# 60/60 - 12s - loss: 0.0910 - accuracy: 0.9728
# Epoch 3/5
# 60/60 - 12s - loss: 0.0271 - accuracy: 0.9906
# Epoch 4/5
# 60/60 - 12s - loss: 0.0102 - accuracy: 0.9953
# Epoch 5/5
# 60/60 - 12s - loss: 0.0016 - accuracy: 1.0000

# %%
def train_test_model(i):
    tf.keras.backend.clear_session()
    '''
    I shuffled dataset every time since i wanted to get enoughly distributed models.
    '''
    train_pixel, train_label, train_answer, valid_pixel, valid_label, valid_answer = prepare_datasets()
    callbacks1 = [tf.keras.callbacks.EarlyStopping(monitor = 'val_accuracy', patience = 20, restore_best_weights = True), ReduceLROnPlateau(monitor = 'loss', patience = 5)]
    ModelName = 'EfficientNetB5_bicubic224_val'
    print(ModelName + '  ' + str(i))
    with tf.device('/device:GPU:0'):
        cnn = tf.keras.applications.EfficientNetB5(include_top=False, weights=None, input_tensor=None, input_shape=(N_dim,N_dim,1),pooling=None)
        cnn_mid = layers.GlobalAveragePooling2D()(cnn.output)
        cnn_out = layers.Dense(128, activation = 'relu')(cnn_mid)

        dense_input = layers.Input(shape=(26,))
        dense_mid = layers.Dense(52, activation = 'relu')(dense_input)
        dense_output = layers.Dense(52, activation = 'relu')(dense_mid)
        dense_model = tf.keras.Model(inputs=dense_input, outputs=dense_output)

        concatenated = layers.concatenate([cnn_out, dense_model.output])
        concatenated = layers.Dense(32, activation='relu')(concatenated)
        concat_output = layers.Dense(10, activation='softmax')(concatenated)
        concat_model = tf.keras.models.Model([cnn.input, dense_input], concat_output)
        concat_model.compile(optimizer="adam", loss="categorical_crossentropy", metrics=["accuracy"])
        history = concat_model.fit([train_pixel, train_label], train_answer, validation_data=([valid_pixel, valid_label], valid_answer), epochs=epochs_num, verbose=verbose, callbacks = callbacks1)
    print(
        f"Train accuracy={max(history.history['accuracy']):.5f}, " +
        f"Validation accuracy={max(history.history['val_accuracy']):.5f}"
    )
    with tf.device('/device:GPU:0'):
        concat_model.fit([valid_pixel, valid_label], valid_answer, epochs=5, verbose=verbose)
    concat_model.save(path + ModelName + '_' + str(i) + '.h5')

for i in range(5):
    train_test_model(i)

def get_progressbar_str(progress):
    MAX_LEN = 30
    BAR_LEN = int(MAX_LEN * progress)
    return ('Progress:[' + '=' * BAR_LEN +
            ('>' if BAR_LEN < MAX_LEN else '') +
            ' ' * (MAX_LEN - BAR_LEN) +
            '] %.1f%%' % (progress * 100.))

class ComputerVision_Data_test():
    def __init__(self, pixel, label, batch_size):
        self.pixel = pixel
        self.label =  label
        self.batch_size = batch_size
        self.length = math.ceil(len(label) // batch_size)

    def __getitem__(self, idx):
        i = idx * self.batch_size
        if i + self.batch_size > len(self.label):
            pixel = self.pixel[i:]
            label = self.label[i:]
        else:
            pixel = self.pixel[i:i+self.batch_size]
            label = self.label[i:i+self.batch_size]
        with tf.device('/device:GPU:0'):
            pixel = resize(pixel, [224,224], method=tf.image.ResizeMethod.BICUBIC).numpy()
            pixel = pixel / 255.0

        return [pixel, label]

    def __len__(self):
        return self.length


test_dataset = ComputerVision_Data_test(test_pixel, test_label, batch_size = 1000)

batch_idxs = [i for i in range(0, len(test_dataset))]
ModelNames = ['InceptionResnetV2_bicubic224_val_' + str(i) for i in range(5)] + ['EfficientNetB5_bicubic224_val_' + str(i) for i in range(5)]
batch_size = test_dataset.batch_size
submission = pd.read_csv(path_submission)
submission_temp = pd.DataFrame(columns = list(range(10)),index = list(range(len(submission)))).fillna(0)
inc = 0
L = len(batch_idxs) * len(ModelNames)
for ModelName in ModelNames:
    tf.keras.backend.clear_session()
    model = tf.keras.models.load_model(path+ModelName+'.h5')
    for batch_idx in batch_idxs:
        target = test_dataset[batch_idx]
        real_idxs = [i for i in range(batch_size * batch_idx, batch_size * batch_idx + len(target[0])) ]
        with tf.device('/device:GPU:0'):
            predicted = model.predict(target)
        for idx_temp, real in enumerate(real_idxs):
            submission_temp.iloc[real,:] += predicted[idx_temp]
        inc += 1
        sys.stderr.write('\r\033[K' + get_progressbar_str(inc/L))
        sys.stderr.flush()
sys.stderr.write('\n')
sys.stderr.flush()
submission.iloc[:,1] = submission_temp.apply(np.argmax,axis=1).apply(int).values
submission.to_csv(path+'submission_ensemble_'+str(len(ModelNames))+'.csv',index = False)
print('Done!')
# Out:
# EfficientNetB5_bicubic224_val  0
# Epoch 1/50
# WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.1660s vs `on_train_batch_end` time: 0.2803s). Check your callbacks.
# 573/573 - 258s - loss: 1.6866 - accuracy: 0.3872 - val_loss: 5.6478 - val_accuracy: 0.0786
# Epoch 2/50
# 573/573 - 252s - loss: 0.6351 - accuracy: 0.7963 - val_loss: 0.8901 - val_accuracy: 0.7575
# Epoch 3/50
# 573/573 - 253s - loss: 0.3701 - accuracy: 0.8801 - val_loss: 0.8070 - val_accuracy: 0.7753
# Epoch 4/50
# 573/573 - 254s - loss: 0.2073 - accuracy: 0.9316 - val_loss: 0.5552 - val_accuracy: 0.8481
# Epoch 5/50
# 573/573 - 252s - loss: 0.1553 - accuracy: 0.9497 - val_loss: 0.6600 - val_accuracy: 0.8371
# Epoch 6/50
# 573/573 - 253s - loss: 0.1168 - accuracy: 0.9622 - val_loss: 0.7120 - val_accuracy: 0.8130
# Epoch 7/50
# 573/573 - 253s - loss: 0.1034 - accuracy: 0.9669 - val_loss: 1.0728 - val_accuracy: 0.7664
# Epoch 8/50
# 573/573 - 252s - loss: 0.0787 - accuracy: 0.9746 - val_loss: 1.3748 - val_accuracy: 0.7135
# Epoch 9/50
# 573/573 - 253s - loss: 0.0848 - accuracy: 0.9732 - val_loss: 0.5624 - val_accuracy: 0.8565
# Epoch 10/50
# 573/573 - 252s - loss: 0.0718 - accuracy: 0.9768 - val_loss: 0.8295 - val_accuracy: 0.8078
# Epoch 11/50
# 573/573 - 253s - loss: 0.0649 - accuracy: 0.9797 - val_loss: 0.5944 - val_accuracy: 0.8649
# Epoch 12/50
# 573/573 - 253s - loss: 0.0519 - accuracy: 0.9837 - val_loss: 0.6340 - val_accuracy: 0.8507
# Epoch 13/50
# 573/573 - 253s - loss: 0.0538 - accuracy: 0.9824 - val_loss: 0.6891 - val_accuracy: 0.8533
# Epoch 14/50
# 573/573 - 252s - loss: 0.0519 - accuracy: 0.9836 - val_loss: 6.2097 - val_accuracy: 0.1383
# Epoch 15/50
# 573/573 - 253s - loss: 0.0388 - accuracy: 0.9884 - val_loss: 0.6403 - val_accuracy: 0.8617
# Epoch 16/50
# 573/573 - 253s - loss: 0.0448 - accuracy: 0.9862 - val_loss: 0.6927 - val_accuracy: 0.8418
# Epoch 17/50
# 573/573 - 253s - loss: 0.0426 - accuracy: 0.9870 - val_loss: 0.5534 - val_accuracy: 0.8837
# Epoch 18/50
# 573/573 - 253s - loss: 0.0294 - accuracy: 0.9912 - val_loss: 0.6516 - val_accuracy: 0.8633
# Epoch 19/50
# 573/573 - 253s - loss: 0.0387 - accuracy: 0.9881 - val_loss: 1.1544 - val_accuracy: 0.7768
# Epoch 20/50
# 573/573 - 253s - loss: 0.0316 - accuracy: 0.9905 - val_loss: 0.8079 - val_accuracy: 0.8601
# Epoch 21/50
# 573/573 - 253s - loss: 0.0360 - accuracy: 0.9892 - val_loss: 0.6153 - val_accuracy: 0.8743
# Epoch 22/50
# 573/573 - 254s - loss: 0.0335 - accuracy: 0.9896 - val_loss: 0.6127 - val_accuracy: 0.8753
# Epoch 23/50
# 573/573 - 254s - loss: 0.0181 - accuracy: 0.9946 - val_loss: 0.4778 - val_accuracy: 0.8999
# Epoch 24/50
# 573/573 - 253s - loss: 0.0294 - accuracy: 0.9913 - val_loss: 0.5245 - val_accuracy: 0.8769
# Epoch 25/50
# 573/573 - 254s - loss: 0.0222 - accuracy: 0.9939 - val_loss: 0.7642 - val_accuracy: 0.8539
# Epoch 26/50
# 573/573 - 253s - loss: 0.0379 - accuracy: 0.9884 - val_loss: 0.8620 - val_accuracy: 0.8245
# Epoch 27/50
# 573/573 - 253s - loss: 0.0158 - accuracy: 0.9948 - val_loss: 0.9124 - val_accuracy: 0.8308
# Epoch 28/50
# 573/573 - 253s - loss: 0.0262 - accuracy: 0.9925 - val_loss: 0.8836 - val_accuracy: 0.8502
# Epoch 29/50
# 573/573 - 253s - loss: 0.0296 - accuracy: 0.9931 - val_loss: 0.9694 - val_accuracy: 0.8266
# Epoch 30/50
# 573/573 - 253s - loss: 0.0128 - accuracy: 0.9963 - val_loss: 0.8274 - val_accuracy: 0.8664
# Epoch 31/50
# 573/573 - 253s - loss: 0.0327 - accuracy: 0.9903 - val_loss: 0.5309 - val_accuracy: 0.8628
# Epoch 32/50
# 573/573 - 254s - loss: 0.0194 - accuracy: 0.9936 - val_loss: 0.8238 - val_accuracy: 0.8266
# Epoch 33/50
# 573/573 - 254s - loss: 0.0251 - accuracy: 0.9928 - val_loss: 0.5479 - val_accuracy: 0.8827
# Epoch 34/50
# 573/573 - 253s - loss: 0.0093 - accuracy: 0.9977 - val_loss: 0.6970 - val_accuracy: 0.8827
# Epoch 35/50
# 573/573 - 253s - loss: 0.0348 - accuracy: 0.9900 - val_loss: 0.6728 - val_accuracy: 0.8842
# Epoch 36/50
# 573/573 - 254s - loss: 0.0151 - accuracy: 0.9954 - val_loss: 0.8342 - val_accuracy: 0.8570
# Epoch 37/50
# 573/573 - 253s - loss: 0.0145 - accuracy: 0.9954 - val_loss: 0.6307 - val_accuracy: 0.8785
# Epoch 38/50
# 573/573 - 253s - loss: 0.0219 - accuracy: 0.9932 - val_loss: 1.8576 - val_accuracy: 0.6763
# Epoch 39/50
# 573/573 - 254s - loss: 0.0092 - accuracy: 0.9975 - val_loss: 0.7898 - val_accuracy: 0.8449
# Epoch 40/50
# 573/573 - 254s - loss: 0.0155 - accuracy: 0.9954 - val_loss: 0.8683 - val_accuracy: 0.8455
# Epoch 41/50
# 573/573 - 254s - loss: 0.0186 - accuracy: 0.9946 - val_loss: 1.3189 - val_accuracy: 0.7748
# Epoch 42/50
# 573/573 - 254s - loss: 0.0149 - accuracy: 0.9959 - val_loss: 0.9414 - val_accuracy: 0.8533
# Epoch 43/50
# 573/573 - 254s - loss: 0.0215 - accuracy: 0.9936 - val_loss: 1.2444 - val_accuracy: 0.7847
# Train accuracy=0.99765, Validation accuracy=0.89995
# Epoch 1/5
# WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.1665s vs `on_train_batch_end` time: 0.2572s). Check your callbacks.
# 60/60 - 26s - loss: 0.3090 - accuracy: 0.9209
# Epoch 2/5
# 60/60 - 25s - loss: 0.0532 - accuracy: 0.9869
# Epoch 3/5
# 60/60 - 26s - loss: 0.0131 - accuracy: 0.9974
# Epoch 4/5
# 60/60 - 25s - loss: 0.0084 - accuracy: 0.9979
# Epoch 5/5
# 60/60 - 26s - loss: 0.0197 - accuracy: 0.9932
# EfficientNetB5_bicubic224_val  1
# Epoch 1/50
# WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.1673s vs `on_train_batch_end` time: 0.2813s). Check your callbacks.
# 573/573 - 256s - loss: 1.5569 - accuracy: 0.4433 - val_loss: 6.4797 - val_accuracy: 0.1189
# Epoch 2/50
# 573/573 - 253s - loss: 0.5586 - accuracy: 0.8232 - val_loss: 4.4058 - val_accuracy: 0.1975
# Epoch 3/50
# 573/573 - 253s - loss: 0.3196 - accuracy: 0.8970 - val_loss: 0.7469 - val_accuracy: 0.7899
# Epoch 4/50
# 573/573 - 253s - loss: 0.1983 - accuracy: 0.9374 - val_loss: 1.2676 - val_accuracy: 0.6679
# Epoch 5/50
# 573/573 - 253s - loss: 0.1534 - accuracy: 0.9526 - val_loss: 0.8930 - val_accuracy: 0.7538
# Epoch 6/50
# 573/573 - 252s - loss: 0.1105 - accuracy: 0.9640 - val_loss: 6.2303 - val_accuracy: 0.1331
# Epoch 7/50
# 573/573 - 253s - loss: 0.1097 - accuracy: 0.9649 - val_loss: 0.6408 - val_accuracy: 0.8580
# Epoch 8/50
# 573/573 - 252s - loss: 0.0857 - accuracy: 0.9720 - val_loss: 1.2306 - val_accuracy: 0.7245
# Epoch 9/50
# 573/573 - 253s - loss: 0.0666 - accuracy: 0.9793 - val_loss: 0.7430 - val_accuracy: 0.8685
# Epoch 10/50
# 573/573 - 252s - loss: 0.0630 - accuracy: 0.9801 - val_loss: 5.2488 - val_accuracy: 0.1891
# Epoch 11/50
# 573/573 - 252s - loss: 0.0545 - accuracy: 0.9826 - val_loss: 0.4758 - val_accuracy: 0.8947
# Epoch 12/50
# 573/573 - 252s - loss: 0.0632 - accuracy: 0.9813 - val_loss: 0.5644 - val_accuracy: 0.8863
# Epoch 13/50
# 573/573 - 252s - loss: 0.0478 - accuracy: 0.9856 - val_loss: 0.5220 - val_accuracy: 0.8989
# Epoch 14/50
# 573/573 - 252s - loss: 0.0512 - accuracy: 0.9844 - val_loss: 8.4669 - val_accuracy: 0.0870
# Epoch 15/50
# 573/573 - 251s - loss: 0.0411 - accuracy: 0.9875 - val_loss: 1.7808 - val_accuracy: 0.7318
# Epoch 16/50
# 573/573 - 252s - loss: 0.0399 - accuracy: 0.9872 - val_loss: 0.6072 - val_accuracy: 0.8921
# Epoch 17/50
# 573/573 - 252s - loss: 0.0468 - accuracy: 0.9855 - val_loss: 0.5665 - val_accuracy: 0.8963
# Epoch 18/50
# 573/573 - 251s - loss: 0.0369 - accuracy: 0.9884 - val_loss: 0.6980 - val_accuracy: 0.8586
# Epoch 19/50
# 573/573 - 252s - loss: 0.0320 - accuracy: 0.9900 - val_loss: 0.5652 - val_accuracy: 0.8696
# Epoch 20/50
# 573/573 - 252s - loss: 0.0289 - accuracy: 0.9912 - val_loss: 0.6616 - val_accuracy: 0.8685
# Epoch 21/50
# 573/573 - 253s - loss: 0.0314 - accuracy: 0.9901 - val_loss: 0.4671 - val_accuracy: 0.9172
# Epoch 22/50
# 573/573 - 252s - loss: 0.0274 - accuracy: 0.9912 - val_loss: 0.8911 - val_accuracy: 0.8428
# Epoch 23/50
# 573/573 - 252s - loss: 0.0312 - accuracy: 0.9902 - val_loss: 0.5065 - val_accuracy: 0.8916
# Epoch 24/50
# 573/573 - 253s - loss: 0.0212 - accuracy: 0.9930 - val_loss: 0.6426 - val_accuracy: 0.8769
# Epoch 25/50
# 573/573 - 252s - loss: 0.0231 - accuracy: 0.9931 - val_loss: 0.4720 - val_accuracy: 0.8963
# Epoch 26/50
# 573/573 - 252s - loss: 0.0227 - accuracy: 0.9934 - val_loss: 0.5502 - val_accuracy: 0.8869
# Epoch 27/50
# 573/573 - 251s - loss: 0.0268 - accuracy: 0.9919 - val_loss: 0.6156 - val_accuracy: 0.8942
# Epoch 28/50
# 573/573 - 252s - loss: 0.0181 - accuracy: 0.9948 - val_loss: 1.8057 - val_accuracy: 0.7590
# Epoch 29/50
# 573/573 - 252s - loss: 0.0231 - accuracy: 0.9926 - val_loss: 0.5530 - val_accuracy: 0.9199
# Epoch 30/50
# 573/573 - 253s - loss: 0.0208 - accuracy: 0.9943 - val_loss: 0.9880 - val_accuracy: 0.8779
# Epoch 31/50
# 573/573 - 252s - loss: 0.0228 - accuracy: 0.9933 - val_loss: 0.5231 - val_accuracy: 0.9031
# Epoch 32/50
# 573/573 - 253s - loss: 0.0162 - accuracy: 0.9959 - val_loss: 1.7086 - val_accuracy: 0.7742
# Epoch 33/50
# 573/573 - 252s - loss: 0.0236 - accuracy: 0.9935 - val_loss: 0.4504 - val_accuracy: 0.9094
# Epoch 34/50
# 573/573 - 252s - loss: 0.0125 - accuracy: 0.9965 - val_loss: 0.5158 - val_accuracy: 0.9109
# Epoch 35/50
# 573/573 - 253s - loss: 0.0205 - accuracy: 0.9937 - val_loss: 1.2978 - val_accuracy: 0.7690
# Epoch 36/50
# 573/573 - 252s - loss: 0.0172 - accuracy: 0.9947 - val_loss: 0.4866 - val_accuracy: 0.9193
# Epoch 37/50
# 573/573 - 252s - loss: 0.0201 - accuracy: 0.9939 - val_loss: 4.2396 - val_accuracy: 0.3897
# Epoch 38/50
# 573/573 - 253s - loss: 0.0188 - accuracy: 0.9952 - val_loss: 0.4108 - val_accuracy: 0.9162
# Epoch 39/50
# 573/573 - 253s - loss: 0.0070 - accuracy: 0.9979 - val_loss: 0.6489 - val_accuracy: 0.9073
# Epoch 40/50
# 573/573 - 253s - loss: 0.0226 - accuracy: 0.9940 - val_loss: 0.4954 - val_accuracy: 0.9020
# Epoch 41/50
# 573/573 - 253s - loss: 0.0140 - accuracy: 0.9961 - val_loss: 3.2519 - val_accuracy: 0.4510
# Epoch 42/50
# 573/573 - 253s - loss: 0.0163 - accuracy: 0.9951 - val_loss: 1.0025 - val_accuracy: 0.8596
# Epoch 43/50
# 573/573 - 253s - loss: 0.0164 - accuracy: 0.9957 - val_loss: 0.5151 - val_accuracy: 0.9188
# Epoch 44/50
# 573/573 - 252s - loss: 0.0190 - accuracy: 0.9946 - val_loss: 0.5380 - val_accuracy: 0.9047
# Epoch 45/50
# 573/573 - 253s - loss: 0.0041 - accuracy: 0.9990 - val_loss: 0.3899 - val_accuracy: 0.9282
# Epoch 46/50
# 573/573 - 252s - loss: 0.0013 - accuracy: 0.9998 - val_loss: 0.4083 - val_accuracy: 0.9277
# Epoch 47/50
# 573/573 - 250s - loss: 8.1680e-04 - accuracy: 0.9998 - val_loss: 0.4284 - val_accuracy: 0.9288
# Epoch 48/50
# 573/573 - 252s - loss: 7.7633e-04 - accuracy: 0.9998 - val_loss: 0.4449 - val_accuracy: 0.9277
# Epoch 49/50
# 573/573 - 253s - loss: 6.1610e-04 - accuracy: 0.9998 - val_loss: 0.4665 - val_accuracy: 0.9230
# Epoch 50/50
# 573/573 - 253s - loss: 2.8510e-04 - accuracy: 1.0000 - val_loss: 0.4701 - val_accuracy: 0.9246
# Train accuracy=1.00000, Validation accuracy=0.92876
# Epoch 1/5
# WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.1662s vs `on_train_batch_end` time: 0.2587s). Check your callbacks.
# 60/60 - 26s - loss: 0.2390 - accuracy: 0.9529
# Epoch 2/5
# 60/60 - 26s - loss: 0.0355 - accuracy: 0.9890
# Epoch 3/5
# 60/60 - 26s - loss: 0.0177 - accuracy: 0.9937
# Epoch 4/5
# 60/60 - 26s - loss: 0.0073 - accuracy: 0.9974
# Epoch 5/5
# 60/60 - 26s - loss: 0.0088 - accuracy: 0.9974
# EfficientNetB5_bicubic224_val  2
# Epoch 1/50
# WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.1670s vs `on_train_batch_end` time: 0.2795s). Check your callbacks.
# 573/573 - 258s - loss: 1.7362 - accuracy: 0.3706 - val_loss: 5.8199 - val_accuracy: 0.1221
# Epoch 2/50
# 573/573 - 255s - loss: 0.6821 - accuracy: 0.7761 - val_loss: 0.5727 - val_accuracy: 0.8156
# Epoch 3/50
# 573/573 - 255s - loss: 0.3715 - accuracy: 0.8748 - val_loss: 0.5022 - val_accuracy: 0.8544
# Epoch 4/50
# 573/573 - 256s - loss: 0.3236 - accuracy: 0.8940 - val_loss: 0.5033 - val_accuracy: 0.8413
# Epoch 5/50
# 573/573 - 256s - loss: 0.3475 - accuracy: 0.8832 - val_loss: 1.5430 - val_accuracy: 0.6108
# Epoch 6/50
# 573/573 - 256s - loss: 0.2387 - accuracy: 0.9183 - val_loss: 1.0809 - val_accuracy: 0.7156
# Epoch 7/50
# 573/573 - 256s - loss: 0.3593 - accuracy: 0.8860 - val_loss: 0.4849 - val_accuracy: 0.8549
# Epoch 8/50
# 573/573 - 253s - loss: 0.1144 - accuracy: 0.9623 - val_loss: 0.3994 - val_accuracy: 0.8900
# Epoch 9/50
# 573/573 - 256s - loss: 0.0688 - accuracy: 0.9788 - val_loss: 0.5364 - val_accuracy: 0.8533
# Epoch 10/50
# 573/573 - 256s - loss: 0.0664 - accuracy: 0.9789 - val_loss: 0.5054 - val_accuracy: 0.8848
# Epoch 11/50
# 573/573 - 255s - loss: 0.0605 - accuracy: 0.9809 - val_loss: 0.5172 - val_accuracy: 0.8806
# Epoch 12/50
# 573/573 - 256s - loss: 0.0545 - accuracy: 0.9831 - val_loss: 0.5449 - val_accuracy: 0.8738
# Epoch 13/50
# 573/573 - 253s - loss: 0.0515 - accuracy: 0.9841 - val_loss: 0.5510 - val_accuracy: 0.8816
# Epoch 14/50
# 573/573 - 256s - loss: 0.0579 - accuracy: 0.9815 - val_loss: 0.6002 - val_accuracy: 0.8701
# Epoch 15/50
# 573/573 - 255s - loss: 0.0526 - accuracy: 0.9841 - val_loss: 0.6184 - val_accuracy: 0.8544
# Epoch 16/50
# 573/573 - 255s - loss: 0.0412 - accuracy: 0.9863 - val_loss: 0.4597 - val_accuracy: 0.9026
# Epoch 17/50
# 573/573 - 256s - loss: 0.0518 - accuracy: 0.9837 - val_loss: 0.8027 - val_accuracy: 0.8397
# Epoch 18/50
# 573/573 - 255s - loss: 0.0367 - accuracy: 0.9884 - val_loss: 0.6165 - val_accuracy: 0.8722
# Epoch 19/50
# 573/573 - 256s - loss: 0.0506 - accuracy: 0.9860 - val_loss: 0.7935 - val_accuracy: 0.8266
# Epoch 20/50
# 573/573 - 256s - loss: 0.0391 - accuracy: 0.9879 - val_loss: 0.4778 - val_accuracy: 0.8968
# Epoch 21/50
# 573/573 - 257s - loss: 0.0326 - accuracy: 0.9894 - val_loss: 0.4835 - val_accuracy: 0.8973
# Epoch 22/50
# 573/573 - 257s - loss: 0.0304 - accuracy: 0.9911 - val_loss: 0.4543 - val_accuracy: 0.9005
# Epoch 23/50
# 573/573 - 255s - loss: 0.0258 - accuracy: 0.9920 - val_loss: 0.5794 - val_accuracy: 0.8832
# Epoch 24/50
# 573/573 - 254s - loss: 0.0316 - accuracy: 0.9904 - val_loss: 1.1806 - val_accuracy: 0.7522
# Epoch 25/50
# 573/573 - 256s - loss: 0.0330 - accuracy: 0.9904 - val_loss: 0.5829 - val_accuracy: 0.8842
# Epoch 26/50
# 573/573 - 256s - loss: 0.0241 - accuracy: 0.9924 - val_loss: 0.5607 - val_accuracy: 0.8937
# Epoch 27/50
# 573/573 - 253s - loss: 0.0307 - accuracy: 0.9900 - val_loss: 1.0227 - val_accuracy: 0.8182
# Epoch 28/50
# 573/573 - 256s - loss: 0.0212 - accuracy: 0.9945 - val_loss: 0.5460 - val_accuracy: 0.9015
# Epoch 29/50
# 573/573 - 255s - loss: 0.0303 - accuracy: 0.9911 - val_loss: 0.6103 - val_accuracy: 0.8785
# Epoch 30/50
# 573/573 - 254s - loss: 0.0281 - accuracy: 0.9916 - val_loss: 0.5469 - val_accuracy: 0.8947
# Epoch 31/50
# 573/573 - 255s - loss: 0.0203 - accuracy: 0.9938 - val_loss: 0.5908 - val_accuracy: 0.8869
# Epoch 32/50
# 573/573 - 256s - loss: 0.0159 - accuracy: 0.9948 - val_loss: 0.5388 - val_accuracy: 0.9099
# Epoch 33/50
# 573/573 - 255s - loss: 0.0223 - accuracy: 0.9931 - val_loss: 0.6022 - val_accuracy: 0.9120
# Epoch 34/50
# 573/573 - 254s - loss: 0.0146 - accuracy: 0.9962 - val_loss: 0.6200 - val_accuracy: 0.9120
# Epoch 35/50
# 573/573 - 257s - loss: 0.0175 - accuracy: 0.9943 - val_loss: 0.6625 - val_accuracy: 0.8706
# Epoch 36/50
# 573/573 - 256s - loss: 0.0225 - accuracy: 0.9937 - val_loss: 0.8218 - val_accuracy: 0.8790
# Epoch 37/50
# 573/573 - 255s - loss: 0.0154 - accuracy: 0.9956 - val_loss: 0.6297 - val_accuracy: 0.8816
# Epoch 38/50
# 573/573 - 256s - loss: 0.0166 - accuracy: 0.9947 - val_loss: 0.6795 - val_accuracy: 0.8869
# Epoch 39/50
# 573/573 - 256s - loss: 0.0148 - accuracy: 0.9961 - val_loss: 0.4814 - val_accuracy: 0.9125
# Epoch 40/50
# 573/573 - 254s - loss: 0.0032 - accuracy: 0.9990 - val_loss: 0.4262 - val_accuracy: 0.9199
# Epoch 41/50
# 573/573 - 257s - loss: 0.0013 - accuracy: 0.9996 - val_loss: 0.4370 - val_accuracy: 0.9199
# Epoch 42/50
# 573/573 - 256s - loss: 6.3376e-04 - accuracy: 0.9998 - val_loss: 0.4206 - val_accuracy: 0.9204
# Epoch 43/50
# 573/573 - 256s - loss: 9.8761e-04 - accuracy: 0.9997 - val_loss: 0.4153 - val_accuracy: 0.9261
# Epoch 44/50
# 573/573 - 256s - loss: 4.6650e-04 - accuracy: 0.9999 - val_loss: 0.4437 - val_accuracy: 0.9204
# Epoch 45/50
# 573/573 - 254s - loss: 8.7658e-04 - accuracy: 0.9998 - val_loss: 0.5524 - val_accuracy: 0.9162
# Epoch 46/50
# 573/573 - 254s - loss: 3.1450e-04 - accuracy: 0.9999 - val_loss: 0.5686 - val_accuracy: 0.9151
# Epoch 47/50
# 573/573 - 252s - loss: 7.2259e-04 - accuracy: 0.9997 - val_loss: 0.5939 - val_accuracy: 0.9078
# Epoch 48/50
# 573/573 - 255s - loss: 2.3358e-04 - accuracy: 1.0000 - val_loss: 0.5927 - val_accuracy: 0.9099
# Epoch 49/50
# 573/573 - 255s - loss: 0.0011 - accuracy: 0.9997 - val_loss: 0.5803 - val_accuracy: 0.9068
# Epoch 50/50
# 573/573 - 249s - loss: 8.5405e-04 - accuracy: 0.9997 - val_loss: 0.5353 - val_accuracy: 0.9178
# Train accuracy=1.00000, Validation accuracy=0.92614
# Epoch 1/5
# WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.1658s vs `on_train_batch_end` time: 0.2810s). Check your callbacks.
# 60/60 - 26s - loss: 0.2016 - accuracy: 0.9560
# Epoch 2/5
# 60/60 - 26s - loss: 0.0313 - accuracy: 0.9906
# Epoch 3/5
# 60/60 - 26s - loss: 0.0229 - accuracy: 0.9953
# Epoch 4/5
# 60/60 - 26s - loss: 0.0104 - accuracy: 0.9963
# Epoch 5/5
# 60/60 - 26s - loss: 0.0063 - accuracy: 0.9990
# EfficientNetB5_bicubic224_val  3
# Epoch 1/50
# 573/573 - 253s - loss: 2.1601 - accuracy: 0.1795 - val_loss: 6.6068 - val_accuracy: 0.1111
# Epoch 2/50
# 573/573 - 254s - loss: 1.1380 - accuracy: 0.5953 - val_loss: 0.9239 - val_accuracy: 0.7391
# Epoch 3/50
# 573/573 - 255s - loss: 0.4951 - accuracy: 0.8418 - val_loss: 0.6016 - val_accuracy: 0.8240
# Epoch 4/50
# 573/573 - 253s - loss: 0.2906 - accuracy: 0.9080 - val_loss: 0.7939 - val_accuracy: 0.7957
# Epoch 5/50
# 573/573 - 254s - loss: 0.2106 - accuracy: 0.9338 - val_loss: 0.4624 - val_accuracy: 0.8696
# Epoch 6/50
# 573/573 - 255s - loss: 0.1371 - accuracy: 0.9564 - val_loss: 0.4470 - val_accuracy: 0.8895
# Epoch 7/50
# 573/573 - 254s - loss: 0.1261 - accuracy: 0.9606 - val_loss: 0.4497 - val_accuracy: 0.8963
# Epoch 8/50
# 573/573 - 255s - loss: 0.1053 - accuracy: 0.9669 - val_loss: 3.1596 - val_accuracy: 0.4348
# Epoch 9/50
# 573/573 - 254s - loss: 0.0867 - accuracy: 0.9714 - val_loss: 0.6482 - val_accuracy: 0.8544
# Epoch 10/50
# 573/573 - 249s - loss: 0.0756 - accuracy: 0.9775 - val_loss: 0.7258 - val_accuracy: 0.8408
# Epoch 11/50
# 573/573 - 249s - loss: 0.0634 - accuracy: 0.9809 - val_loss: 0.5417 - val_accuracy: 0.8821
# Epoch 12/50
# 573/573 - 254s - loss: 0.0642 - accuracy: 0.9816 - val_loss: 0.5806 - val_accuracy: 0.8832
# Epoch 13/50
# 573/573 - 254s - loss: 0.0564 - accuracy: 0.9817 - val_loss: 0.6805 - val_accuracy: 0.8685
# Epoch 14/50
# 573/573 - 250s - loss: 0.0470 - accuracy: 0.9845 - val_loss: 0.5921 - val_accuracy: 0.8774
# Epoch 15/50
# 573/573 - 254s - loss: 0.0484 - accuracy: 0.9849 - val_loss: 0.5044 - val_accuracy: 0.8884
# Epoch 16/50
# 573/573 - 249s - loss: 0.0391 - accuracy: 0.9887 - val_loss: 0.4655 - val_accuracy: 0.9031
# Epoch 17/50
# 573/573 - 254s - loss: 0.0347 - accuracy: 0.9898 - val_loss: 0.7604 - val_accuracy: 0.8732
# Epoch 18/50
# 573/573 - 254s - loss: 0.0448 - accuracy: 0.9861 - val_loss: 0.5681 - val_accuracy: 0.8848
# Epoch 19/50
# 573/573 - 250s - loss: 0.0337 - accuracy: 0.9899 - val_loss: 0.5003 - val_accuracy: 0.9068
# Epoch 20/50
# 573/573 - 250s - loss: 0.0468 - accuracy: 0.9865 - val_loss: 1.9661 - val_accuracy: 0.6160
# Epoch 21/50
# 573/573 - 250s - loss: 0.0364 - accuracy: 0.9890 - val_loss: 0.4300 - val_accuracy: 0.9136
# Epoch 22/50
# 573/573 - 255s - loss: 0.0365 - accuracy: 0.9894 - val_loss: 0.7323 - val_accuracy: 0.8439
# Epoch 23/50
# 573/573 - 254s - loss: 0.0353 - accuracy: 0.9894 - val_loss: 0.7206 - val_accuracy: 0.8669
# Epoch 24/50
# 573/573 - 249s - loss: 0.0255 - accuracy: 0.9922 - val_loss: 0.6430 - val_accuracy: 0.8711
# Epoch 25/50
# 573/573 - 248s - loss: 0.0259 - accuracy: 0.9922 - val_loss: 0.6118 - val_accuracy: 0.8848
# Epoch 26/50
# 573/573 - 250s - loss: 0.0308 - accuracy: 0.9916 - val_loss: 0.6618 - val_accuracy: 0.8963
# Epoch 27/50
# 573/573 - 249s - loss: 0.0232 - accuracy: 0.9938 - val_loss: 0.6560 - val_accuracy: 0.8863
# Epoch 28/50
# 573/573 - 250s - loss: 0.0310 - accuracy: 0.9910 - val_loss: 0.7241 - val_accuracy: 0.8675
# Epoch 29/50
# 573/573 - 254s - loss: 0.0235 - accuracy: 0.9924 - val_loss: 0.6443 - val_accuracy: 0.9094
# Epoch 30/50
# 573/573 - 252s - loss: 0.0245 - accuracy: 0.9930 - val_loss: 0.6570 - val_accuracy: 0.9005
# Epoch 31/50
# 573/573 - 255s - loss: 0.0278 - accuracy: 0.9924 - val_loss: 0.5917 - val_accuracy: 0.8968
# Epoch 32/50
# 573/573 - 249s - loss: 0.0321 - accuracy: 0.9907 - val_loss: 0.5417 - val_accuracy: 0.9099
# Epoch 33/50
# 573/573 - 250s - loss: 0.0043 - accuracy: 0.9991 - val_loss: 0.4954 - val_accuracy: 0.9199
# Epoch 34/50
# 573/573 - 248s - loss: 0.0020 - accuracy: 0.9995 - val_loss: 0.5278 - val_accuracy: 0.9141
# Epoch 35/50
# 573/573 - 248s - loss: 0.0012 - accuracy: 0.9998 - val_loss: 0.5267 - val_accuracy: 0.9204
# Epoch 36/50
# 573/573 - 249s - loss: 8.0681e-04 - accuracy: 0.9999 - val_loss: 0.5766 - val_accuracy: 0.9183
# Epoch 37/50
# 573/573 - 249s - loss: 7.3807e-04 - accuracy: 0.9998 - val_loss: 0.6212 - val_accuracy: 0.9109
# Epoch 38/50
# 573/573 - 249s - loss: 0.0010 - accuracy: 0.9997 - val_loss: 0.6283 - val_accuracy: 0.9219
# Epoch 39/50
# 573/573 - 250s - loss: 7.6971e-04 - accuracy: 0.9998 - val_loss: 0.6545 - val_accuracy: 0.9199
# Epoch 40/50
# 573/573 - 248s - loss: 8.0412e-04 - accuracy: 0.9997 - val_loss: 0.7022 - val_accuracy: 0.9125
# Epoch 41/50
# 573/573 - 248s - loss: 6.2812e-04 - accuracy: 0.9998 - val_loss: 0.7169 - val_accuracy: 0.9214
# Epoch 42/50
# 573/573 - 249s - loss: 3.0215e-04 - accuracy: 0.9999 - val_loss: 0.7004 - val_accuracy: 0.9199
# Epoch 43/50
# 573/573 - 249s - loss: 8.3237e-04 - accuracy: 0.9998 - val_loss: 0.7552 - val_accuracy: 0.9151
# Epoch 44/50
# 573/573 - 247s - loss: 0.0016 - accuracy: 0.9996 - val_loss: 0.7363 - val_accuracy: 0.9130
# Epoch 45/50
# 573/573 - 249s - loss: 3.7939e-04 - accuracy: 0.9998 - val_loss: 0.7680 - val_accuracy: 0.9089
# Epoch 46/50
# 573/573 - 250s - loss: 6.2220e-04 - accuracy: 0.9999 - val_loss: 0.7743 - val_accuracy: 0.9162
# Epoch 47/50
# 573/573 - 248s - loss: 2.3502e-04 - accuracy: 0.9999 - val_loss: 0.7881 - val_accuracy: 0.9151
# Epoch 48/50
# 573/573 - 250s - loss: 1.1656e-04 - accuracy: 1.0000 - val_loss: 0.7792 - val_accuracy: 0.9146
# Epoch 49/50
# 573/573 - 249s - loss: 1.9200e-04 - accuracy: 0.9999 - val_loss: 0.7863 - val_accuracy: 0.9146
# Epoch 50/50
# 573/573 - 250s - loss: 9.7194e-05 - accuracy: 1.0000 - val_loss: 0.7937 - val_accuracy: 0.9136
# Train accuracy=1.00000, Validation accuracy=0.92195
# Epoch 1/5
# WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.1667s vs `on_train_batch_end` time: 0.2807s). Check your callbacks.
# 60/60 - 26s - loss: 0.5938 - accuracy: 0.9136
# Epoch 2/5
# 60/60 - 25s - loss: 0.4185 - accuracy: 0.9288
# Epoch 3/5
# 60/60 - 25s - loss: 0.3023 - accuracy: 0.9392
# Epoch 4/5
# 60/60 - 26s - loss: 0.2651 - accuracy: 0.9460
# Epoch 5/5
# 60/60 - 26s - loss: 0.2268 - accuracy: 0.9534
# EfficientNetB5_bicubic224_val  4
# Epoch 1/50
# WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.1663s vs `on_train_batch_end` time: 0.2794s). Check your callbacks.
# 573/573 - 254s - loss: 1.6276 - accuracy: 0.4171 - val_loss: 6.2864 - val_accuracy: 0.0629
# Epoch 2/50
# 573/573 - 255s - loss: 0.5466 - accuracy: 0.8265 - val_loss: 0.5292 - val_accuracy: 0.8512
# Epoch 3/50
# 573/573 - 251s - loss: 0.3010 - accuracy: 0.9041 - val_loss: 0.5781 - val_accuracy: 0.8397
# Epoch 4/50
# 573/573 - 252s - loss: 0.2007 - accuracy: 0.9351 - val_loss: 3.1859 - val_accuracy: 0.3279
# Epoch 5/50
# 573/573 - 255s - loss: 0.1526 - accuracy: 0.9511 - val_loss: 1.4075 - val_accuracy: 0.7098
# Epoch 6/50
# 573/573 - 253s - loss: 0.1212 - accuracy: 0.9619 - val_loss: 2.0080 - val_accuracy: 0.5458
# Epoch 7/50
# 573/573 - 250s - loss: 0.1118 - accuracy: 0.9651 - val_loss: 2.5068 - val_accuracy: 0.4845
# Epoch 8/50
# 573/573 - 252s - loss: 0.0919 - accuracy: 0.9719 - val_loss: 3.8576 - val_accuracy: 0.3976
# Epoch 9/50
# 573/573 - 254s - loss: 0.0733 - accuracy: 0.9770 - val_loss: 0.7721 - val_accuracy: 0.8287
# Epoch 10/50
# 573/573 - 249s - loss: 0.0658 - accuracy: 0.9793 - val_loss: 0.6284 - val_accuracy: 0.8580
# Epoch 11/50
# 573/573 - 249s - loss: 0.0724 - accuracy: 0.9773 - val_loss: 0.5316 - val_accuracy: 0.8779
# Epoch 12/50
# 573/573 - 258s - loss: 0.0549 - accuracy: 0.9833 - val_loss: 0.5441 - val_accuracy: 0.8811
# Epoch 13/50
# 573/573 - 254s - loss: 0.0523 - accuracy: 0.9844 - val_loss: 0.6522 - val_accuracy: 0.8675
# Epoch 14/50
# 573/573 - 251s - loss: 0.0546 - accuracy: 0.9829 - val_loss: 5.7023 - val_accuracy: 0.1833
# Epoch 15/50
# 573/573 - 251s - loss: 0.0456 - accuracy: 0.9860 - val_loss: 0.5234 - val_accuracy: 0.8968
# Epoch 16/50
# 573/573 - 251s - loss: 0.0443 - accuracy: 0.9865 - val_loss: 0.4818 - val_accuracy: 0.8937
# Epoch 17/50
# 573/573 - 249s - loss: 0.0449 - accuracy: 0.9867 - val_loss: 0.9949 - val_accuracy: 0.8062
# Epoch 18/50
# 573/573 - 251s - loss: 0.0341 - accuracy: 0.9901 - val_loss: 0.5176 - val_accuracy: 0.8926
# Epoch 19/50
# 573/573 - 251s - loss: 0.0384 - accuracy: 0.9892 - val_loss: 0.5385 - val_accuracy: 0.8947
# Epoch 20/50
# 573/573 - 252s - loss: 0.0308 - accuracy: 0.9907 - val_loss: 0.4977 - val_accuracy: 0.8989
# Epoch 21/50
# 573/573 - 252s - loss: 0.0301 - accuracy: 0.9913 - val_loss: 1.0418 - val_accuracy: 0.8214
# Epoch 22/50
# 573/573 - 252s - loss: 0.0446 - accuracy: 0.9876 - val_loss: 0.6312 - val_accuracy: 0.8963
# Epoch 23/50
# 573/573 - 253s - loss: 0.0246 - accuracy: 0.9927 - val_loss: 1.1007 - val_accuracy: 0.8109
# Epoch 24/50
# 573/573 - 251s - loss: 0.0319 - accuracy: 0.9908 - val_loss: 1.2954 - val_accuracy: 0.7370
# Epoch 25/50
# 573/573 - 254s - loss: 0.0221 - accuracy: 0.9932 - val_loss: 0.6481 - val_accuracy: 0.8586
# Epoch 26/50
# 573/573 - 251s - loss: 0.0245 - accuracy: 0.9923 - val_loss: 0.6047 - val_accuracy: 0.8916
# Epoch 27/50
# 573/573 - 251s - loss: 0.0331 - accuracy: 0.9903 - val_loss: 0.6122 - val_accuracy: 0.8989
# Epoch 28/50
# 573/573 - 250s - loss: 0.0204 - accuracy: 0.9947 - val_loss: 0.6290 - val_accuracy: 0.8916
# Epoch 29/50
# 573/573 - 255s - loss: 0.0254 - accuracy: 0.9930 - val_loss: 0.4792 - val_accuracy: 0.9026
# Epoch 30/50
# 573/573 - 251s - loss: 0.0240 - accuracy: 0.9930 - val_loss: 2.2259 - val_accuracy: 0.5762
# Epoch 31/50
# 573/573 - 251s - loss: 0.0191 - accuracy: 0.9947 - val_loss: 0.6357 - val_accuracy: 0.8958
# Epoch 32/50
# 573/573 - 254s - loss: 0.0090 - accuracy: 0.9970 - val_loss: 0.6360 - val_accuracy: 0.8952
# Epoch 33/50
# 573/573 - 251s - loss: 0.0236 - accuracy: 0.9924 - val_loss: 0.7811 - val_accuracy: 0.8711
# Epoch 34/50
# 573/573 - 254s - loss: 0.0277 - accuracy: 0.9928 - val_loss: 0.5483 - val_accuracy: 0.8921
# Epoch 35/50
# 573/573 - 249s - loss: 0.0195 - accuracy: 0.9949 - val_loss: 0.6721 - val_accuracy: 0.8821
# Epoch 36/50
# 573/573 - 251s - loss: 0.0182 - accuracy: 0.9948 - val_loss: 0.5465 - val_accuracy: 0.9047
# Epoch 37/50
# 573/573 - 251s - loss: 0.0263 - accuracy: 0.9928 - val_loss: 0.4080 - val_accuracy: 0.9141
# Epoch 38/50
# 573/573 - 254s - loss: 0.0053 - accuracy: 0.9982 - val_loss: 0.3809 - val_accuracy: 0.9235
# Epoch 39/50
# 573/573 - 252s - loss: 0.0013 - accuracy: 0.9998 - val_loss: 0.3748 - val_accuracy: 0.9240
# Epoch 40/50
# 573/573 - 249s - loss: 0.0014 - accuracy: 0.9999 - val_loss: 0.3737 - val_accuracy: 0.9214
# Epoch 41/50
# 573/573 - 251s - loss: 5.9211e-04 - accuracy: 0.9999 - val_loss: 0.3859 - val_accuracy: 0.9230
# Epoch 42/50
# 573/573 - 250s - loss: 8.8993e-04 - accuracy: 0.9997 - val_loss: 0.4225 - val_accuracy: 0.9214
# Epoch 43/50
# 573/573 - 253s - loss: 7.5313e-04 - accuracy: 0.9998 - val_loss: 0.4248 - val_accuracy: 0.9235
# Epoch 44/50
# 573/573 - 251s - loss: 4.1089e-04 - accuracy: 0.9999 - val_loss: 0.4196 - val_accuracy: 0.9293
# Epoch 45/50
# 573/573 - 249s - loss: 3.8545e-04 - accuracy: 0.9999 - val_loss: 0.3816 - val_accuracy: 0.9356
# Epoch 46/50
# 573/573 - 248s - loss: 6.6229e-04 - accuracy: 0.9997 - val_loss: 0.4788 - val_accuracy: 0.9240
# Epoch 47/50
# 573/573 - 254s - loss: 8.0304e-04 - accuracy: 0.9997 - val_loss: 0.4457 - val_accuracy: 0.9251
# Epoch 48/50
# 573/573 - 255s - loss: 4.0076e-04 - accuracy: 0.9999 - val_loss: 0.4120 - val_accuracy: 0.9282
# Epoch 49/50
# 573/573 - 253s - loss: 5.3367e-04 - accuracy: 0.9999 - val_loss: 0.4335 - val_accuracy: 0.9277
# Epoch 50/50
# 573/573 - 253s - loss: 2.3473e-04 - accuracy: 0.9999 - val_loss: 0.4250 - val_accuracy: 0.9282
# Train accuracy=0.99995, Validation accuracy=0.93557
# Epoch 1/5
# 60/60 - 26s - loss: 0.3622 - accuracy: 0.9335
# Epoch 2/5
# 60/60 - 26s - loss: 0.2191 - accuracy: 0.9492
# Epoch 3/5
# 60/60 - 26s - loss: 0.1919 - accuracy: 0.9523
# Epoch 4/5
# 60/60 - 26s - loss: 0.1364 - accuracy: 0.9591
# Epoch 5/5
# 60/60 - 26s - loss: 0.1098 - accuracy: 0.9618
# Progress:[==============================] 100.0%
# Done!

# %%
def get_progressbar_str(progress):
    MAX_LEN = 30
    BAR_LEN = int(MAX_LEN * progress)
    return ('Progress:[' + '=' * BAR_LEN +
            ('>' if BAR_LEN < MAX_LEN else '') +
            ' ' * (MAX_LEN - BAR_LEN) +
            '] %.1f%%' % (progress * 100.))

class ComputerVision_Data_test():
    def __init__(self, pixel, label, batch_size):
        self.pixel = pixel
        self.label =  label
        self.batch_size = batch_size
        self.length = math.ceil(len(label) // batch_size)

    def __getitem__(self, idx):
        i = idx * self.batch_size
        if i + self.batch_size > len(self.label):
            pixel = self.pixel[i:]
            label = self.label[i:]
        else:
            pixel = self.pixel[i:i+self.batch_size]
            label = self.label[i:i+self.batch_size]
        with tf.device('/device:GPU:0'):
            pixel = resize(pixel, [224,224], method=tf.image.ResizeMethod.BICUBIC).numpy()
            pixel = pixel / 255.0

        return [pixel, label]

    def __len__(self):
        return self.length


test_dataset = ComputerVision_Data_test(test_pixel, test_label, batch_size = 1000)

batch_idxs = [i for i in range(0, len(test_dataset))]
ModelNames = ['InceptionResnetV2_bicubic224_val_' + str(i) for i in range(5)]
batch_size = test_dataset.batch_size
submission = pd.read_csv(path_submission)
submission_temp = pd.DataFrame(columns = list(range(10)),index = list(range(len(submission)))).fillna(0)
inc = 0
L = len(batch_idxs) * len(ModelNames)
for ModelName in ModelNames:
    tf.keras.backend.clear_session()
    model = tf.keras.models.load_model(path+ModelName+'.h5')
    for batch_idx in batch_idxs:
        target = test_dataset[batch_idx]
        real_idxs = [i for i in range(batch_size * batch_idx, batch_size * batch_idx + len(target[0])) ]
        with tf.device('/device:GPU:0'):
            predicted = model.predict(target)
        for idx_temp, real in enumerate(real_idxs):
            submission_temp.iloc[real,:] += predicted[idx_temp]
        inc += 1
        sys.stderr.write('\r\033[K' + get_progressbar_str(inc/L))
        sys.stderr.flush()
sys.stderr.write('\n')
sys.stderr.flush()
submission.iloc[:,1] = submission_temp.apply(np.argmax,axis=1).apply(int).values
submission.to_csv(path+'submission_ensemble_'+str(len(ModelNames))+'.csv',index = False)
print('Done!')
# Out:
# Progress:[==============================] 100.0%
# Done!

# %% [markdown]
# 가장 좋은넘인 effi-4 만 써보자.
# ---------

# %%
def get_progressbar_str(progress):
    MAX_LEN = 30
    BAR_LEN = int(MAX_LEN * progress)
    return ('Progress:[' + '=' * BAR_LEN +
            ('>' if BAR_LEN < MAX_LEN else '') +
            ' ' * (MAX_LEN - BAR_LEN) +
            '] %.1f%%' % (progress * 100.))

class ComputerVision_Data_test():
    def __init__(self, pixel, label, batch_size):
        self.pixel = pixel
        self.label =  label
        self.batch_size = batch_size
        self.length = math.ceil(len(label) // batch_size)

    def __getitem__(self, idx):
        i = idx * self.batch_size
        if i + self.batch_size > len(self.label):
            pixel = self.pixel[i:]
            label = self.label[i:]
        else:
            pixel = self.pixel[i:i+self.batch_size]
            label = self.label[i:i+self.batch_size]
        with tf.device('/device:GPU:0'):
            pixel = resize(pixel, [224,224], method=tf.image.ResizeMethod.BICUBIC).numpy()
            pixel = pixel / 255.0

        return [pixel, label]

    def __len__(self):
        return self.length


test_dataset = ComputerVision_Data_test(test_pixel, test_label, batch_size = 1000)

batch_idxs = [i for i in range(0, len(test_dataset))]
ModelNames = ['EfficientNetB5_bicubic224_val_' + str(i) for i in range(4,5)]
batch_size = test_dataset.batch_size
submission = pd.read_csv(path_submission)
submission_temp = pd.DataFrame(columns = list(range(10)),index = list(range(len(submission)))).fillna(0)
inc = 0
L = len(batch_idxs) * len(ModelNames)
for ModelName in ModelNames:
    tf.keras.backend.clear_session()
    model = tf.keras.models.load_model(path+ModelName+'.h5')
    for batch_idx in batch_idxs:
        target = test_dataset[batch_idx]
        real_idxs = [i for i in range(batch_size * batch_idx, batch_size * batch_idx + len(target[0])) ]
        with tf.device('/device:GPU:0'):
            predicted = model.predict(target)
        for idx_temp, real in enumerate(real_idxs):
            submission_temp.iloc[real,:] += predicted[idx_temp]
        inc += 1
        sys.stderr.write('\r\033[K' + get_progressbar_str(inc/L))
        sys.stderr.flush()
sys.stderr.write('\n')
sys.stderr.flush()
submission.iloc[:,1] = submission_temp.apply(np.argmax,axis=1).apply(int).values
submission.to_csv(path+'submission_ensemble_'+str(len(ModelNames))+'.csv',index = False)
print('Done!')
# Out:
# Progress:[==============================] 100.0%
# Done!

# %% [markdown]
# 93.1...ensemble 7
# --------

# %%
def get_progressbar_str(progress):
    MAX_LEN = 30
    BAR_LEN = int(MAX_LEN * progress)
    return ('Progress:[' + '=' * BAR_LEN +
            ('>' if BAR_LEN < MAX_LEN else '') +
            ' ' * (MAX_LEN - BAR_LEN) +
            '] %.1f%%' % (progress * 100.))

class ComputerVision_Data_test():
    def __init__(self, pixel, label, batch_size):
        self.pixel = pixel
        self.label =  label
        self.batch_size = batch_size
        self.length = math.ceil(len(label) // batch_size)

    def __getitem__(self, idx):
        i = idx * self.batch_size
        if i + self.batch_size > len(self.label):
            pixel = self.pixel[i:]
            label = self.label[i:]
        else:
            pixel = self.pixel[i:i+self.batch_size]
            label = self.label[i:i+self.batch_size]
        with tf.device('/device:GPU:0'):
            pixel = resize(pixel, [224,224], method=tf.image.ResizeMethod.BICUBIC).numpy()
            pixel = pixel / 255.0

        return [pixel, label]

    def __len__(self):
        return self.length


test_dataset = ComputerVision_Data_test(test_pixel, test_label, batch_size = 1000)

batch_idxs = [i for i in range(0, len(test_dataset))]
ModelNames = ['InceptionResnetV2_bicubic224_val_' + str(i) for i in [0,2,3]] + ['EfficientNetB5_bicubic224_val_' + str(i) for i in [1,2,3,4]]
batch_size = test_dataset.batch_size
submission = pd.read_csv(path_submission)
submission_temp = pd.DataFrame(columns = list(range(10)),index = list(range(len(submission)))).fillna(0)
inc = 0
L = len(batch_idxs) * len(ModelNames)
for ModelName in ModelNames:
    tf.keras.backend.clear_session()
    model = tf.keras.models.load_model(path+ModelName+'.h5')
    for batch_idx in batch_idxs:
        target = test_dataset[batch_idx]
        real_idxs = [i for i in range(batch_size * batch_idx, batch_size * batch_idx + len(target[0])) ]
        with tf.device('/device:GPU:0'):
            predicted = model.predict(target)
        for idx_temp, real in enumerate(real_idxs):
            submission_temp.iloc[real,:] += predicted[idx_temp]
        inc += 1
        sys.stderr.write('\r\033[K' + get_progressbar_str(inc/L))
        sys.stderr.flush()
sys.stderr.write('\n')
sys.stderr.flush()
submission.iloc[:,1] = submission_temp.apply(np.argmax,axis=1).apply(int).values
submission.to_csv(path+'submission_ensemble_'+str(len(ModelNames))+'.csv',index = False)
print('Done!')
# Out:
# Progress:[==============================] 100.0%
# Done!

# %% [markdown]
# ensemble 6
# ---------

# %%
def get_progressbar_str(progress):
    MAX_LEN = 30
    BAR_LEN = int(MAX_LEN * progress)
    return ('Progress:[' + '=' * BAR_LEN +
            ('>' if BAR_LEN < MAX_LEN else '') +
            ' ' * (MAX_LEN - BAR_LEN) +
            '] %.1f%%' % (progress * 100.))

class ComputerVision_Data_test():
    def __init__(self, pixel, label, batch_size):
        self.pixel = pixel
        self.label =  label
        self.batch_size = batch_size
        self.length = math.ceil(len(label) // batch_size)

    def __getitem__(self, idx):
        i = idx * self.batch_size
        if i + self.batch_size > len(self.label):
            pixel = self.pixel[i:]
            label = self.label[i:]
        else:
            pixel = self.pixel[i:i+self.batch_size]
            label = self.label[i:i+self.batch_size]
        with tf.device('/device:GPU:0'):
            pixel = resize(pixel, [224,224], method=tf.image.ResizeMethod.BICUBIC).numpy()
            pixel = pixel / 255.0

        return [pixel, label]

    def __len__(self):
        return self.length


test_dataset = ComputerVision_Data_test(test_pixel, test_label, batch_size = 1000)

batch_idxs = [i for i in range(0, len(test_dataset))]
ModelNames = ['InceptionResnetV2_bicubic224_val_' + str(i) for i in [0,2]] + ['EfficientNetB5_bicubic224_val_' + str(i) for i in [1,2,3,4]]
batch_size = test_dataset.batch_size
submission = pd.read_csv(path_submission)
submission_temp = pd.DataFrame(columns = list(range(10)),index = list(range(len(submission)))).fillna(0)
inc = 0
L = len(batch_idxs) * len(ModelNames)
for ModelName in ModelNames:
    tf.keras.backend.clear_session()
    model = tf.keras.models.load_model(path+ModelName+'.h5')
    for batch_idx in batch_idxs:
        target = test_dataset[batch_idx]
        real_idxs = [i for i in range(batch_size * batch_idx, batch_size * batch_idx + len(target[0])) ]
        with tf.device('/device:GPU:0'):
            predicted = model.predict(target)
        for idx_temp, real in enumerate(real_idxs):
            submission_temp.iloc[real,:] += predicted[idx_temp]
        inc += 1
        sys.stderr.write('\r\033[K' + get_progressbar_str(inc/L))
        sys.stderr.flush()
sys.stderr.write('\n')
sys.stderr.flush()
submission.iloc[:,1] = submission_temp.apply(np.argmax,axis=1).apply(int).values
submission.to_csv(path+'submission_ensemble_'+str(len(ModelNames))+'.csv',index = False)
print('Done!')
# Out:
# Progress:[==============================] 100.0%
# Done!

# %% [markdown]
# k-mean

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import sys
import math
from sklearn.model_selection import train_test_split
from sklearn import cluster
from skimage import feature
# %tensorflow_version 2.x
import tensorflow as tf
from tensorflow.image import resize
from tensorflow import keras
from tensorflow.keras.utils import to_categorical, Sequence
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras import layers
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
import string

path = '/content/gdrive/My Drive/Dacon/ComputerVision/'
path_train = path + 'train.csv'
path_test = path + 'test.csv'
path_submission = path + 'submission.csv'

device_name = tf.test.gpu_device_name()
if device_name != '/device:GPU:0':
    raise SystemError('GPU device not found')
print('Found GPU at: {}'.format(device_name))
# Out:
# Found GPU at: /device:GPU:0

# %%
## Global Variables ##
ImageGen_coeff = 10
N_dim = 224
epochs_num = 80
verbose = 2
batch_size = 32
train_val_ratio = 0.9
def get_progressbar_str(progress):
    MAX_LEN = 30
    BAR_LEN = int(MAX_LEN * progress)
    return ('Progress:[' + '=' * BAR_LEN +
            ('>' if BAR_LEN < MAX_LEN else '') +
            ' ' * (MAX_LEN - BAR_LEN) +
            '] %.1f%%' % (progress * 100.))

# %%
def image_updown_clustering(df1, df2):
    for alphabet_large in string.ascii_uppercase:
        alphabet_small = alphabet_large.lower()
        img_converted = []
        images_alphabet1 = df1[df1.iloc[:,2] == alphabet_large].iloc[:,3:]
        images_alphabet2 = df2[df2.iloc[:,1] == alphabet_large].iloc[:,2:]
        real_idxs1 = list(images_alphabet1.index)
        real_idxs2 = list(images_alphabet2.index)
        pixels = np.concatenate((images_alphabet1.values.reshape(-1,28,28), images_alphabet2.values.reshape(-1,28,28)), axis=0) 
        for pixel in pixels:
            img_converted.append(feature.hog(pixel))
        k_means = cluster.KMeans(n_clusters = 2)
        k_means.fit(np.asarray(img_converted))

        for idx, new_label in zip(real_idxs1, k_means.labels_[:len(real_idxs1)]):
            if new_label == 0:
                df1.loc[idx,'letter'] = alphabet_small
        for idx, new_label in zip(real_idxs2, k_means.labels_[len(real_idxs1):]):
            if new_label == 0:
                df2.loc[idx,'letter'] = alphabet_small
        
    return df1, df2

train_raw, test_raw = pd.read_csv(path_train), pd.read_csv(path_test)
train_raw, test_raw = image_updown_clustering(train_raw, test_raw)

def prepare_datasets(train_raw):
    '''
    ImageGen_coeff (Global Variable) : number of ImageDataGenerator generation per image
    N_dim (Global Variable) : we'll change the size of the image from (28,28) to (N_dim,N_dim)

    Since we don't have enough RAM for the resized image of test_pixel, we just return non-resized, non-standardized image.
    When we generate each batchs by making use of the tf.utils.Sequential class, we'll resize and standardize test_pixel.
    '''

    letter_hash = dict(zip(string.ascii_uppercase + string.ascii_lowercase, [[1 if i == j else 0 for j in range(52)] for i in range(52)]))
    letter_hash_func = lambda letter : letter_hash[letter]

    ### only for validation 
    point_to = int(len(train_raw) * train_val_ratio)
    train_raw = train_raw.sample(frac=1)
    validation_raw = train_raw.iloc[point_to:,:]
    train_raw = train_raw.iloc[:point_to,:]
    
    with tf.device('/device:GPU:0'):
        validation_pixel = resize(validation_raw.iloc[:,3:].values.astype('int32').reshape(-1,28,28,1), [N_dim,N_dim], method = tf.image.ResizeMethod.BICUBIC).numpy()
    validation_pixel = validation_pixel / 255.0
    validation_fix = validation_raw.iloc[:,1:3].values
    datagenerator = ImageDataGenerator(rotation_range=10, zoom_range=0.10, width_shift_range=0.1,height_shift_range=0.1)
    gen = datagenerator.flow(validation_pixel, validation_fix, shuffle=False, batch_size=32)
    pixel, fixed, batch_index, limit = [], [], 0, int((len(validation_pixel) / 32) * ImageGen_coeff)
    while batch_index <= limit:
        try:
            data = gen.next()
            pixel += list(data[0])
            fixed += list(data[1])
            batch_index += 1
        except:
            print("ImageGeneratorError")
            break

    validation_pixel = np.asarray(pixel)
    validation_label = np.asarray(list(map(letter_hash_func, np.asarray(fixed)[:,1])))
    validation_answer = to_categorical(np.asarray(fixed)[:,0], 10)
    ###

    pix = train_raw.iloc[:,3:].values.astype('int32').reshape(-1,28,28,1)
    with tf.device('/device:GPU:0'):
        pix = resize(pix, [N_dim,N_dim], method = tf.image.ResizeMethod.BICUBIC).numpy()
    pix = pix / 255.0
    fix = train_raw.iloc[:,1:3].values
    datagenerator = ImageDataGenerator(rotation_range=10, zoom_range=0.10, width_shift_range=0.1,height_shift_range=0.1)
    gen = datagenerator.flow(pix, fix, shuffle=False, batch_size=32)
    pixel, fixed, batch_index, limit = [], [], 0, int((len(pix) / 32) * ImageGen_coeff)
    while batch_index <= limit:
        try:
            data = gen.next()
            pixel += list(data[0])
            fixed += list(data[1])
            batch_index += 1
        except:
            print("ImageGeneratorError")
            break

    train_pixel = np.asarray(pixel)
    train_label = np.asarray(list(map(letter_hash_func, np.asarray(fixed)[:,1])))
    train_answer = to_categorical(np.asarray(fixed)[:,0], 10)

    return train_pixel, train_label, train_answer, validation_pixel, validation_label, validation_answer

def prepare_testset(test_raw):
    letter_hash = dict(zip(string.ascii_uppercase + string.ascii_lowercase, [[1 if i == j else 0 for j in range(52)] for i in range(52)]))
    letter_hash_func = lambda letter : letter_hash[letter]

    test_pixel = test_raw.iloc[:,2:].values.astype('int32').reshape(-1,28,28,1)
    test_label = np.asarray(list(map(letter_hash_func, test_raw.iloc[:,1].values))).astype('float32')
    return test_pixel, test_label

test_pixel, test_label = prepare_testset(test_raw)
print(test_pixel.shape, test_label.shape)
# Out:
# (20480, 28, 28, 1) (20480, 52)

# %%
def train_test_model(i):
    tf.keras.backend.clear_session()
    '''
    I shuffled dataset every time since i wanted to get enoughly distributed models.
    '''
    train_pixel, train_label, train_answer, valid_pixel, valid_label, valid_answer = prepare_datasets(train_raw)
    callbacks1 = [tf.keras.callbacks.EarlyStopping(monitor = 'val_accuracy', patience = 15, restore_best_weights = True), ReduceLROnPlateau(monitor = 'loss', patience = 5)]
    ModelName = 'InceptionResnetV2_bicubic224_val_kmean'
    print(ModelName + '  ' + str(i))
    with tf.device('/device:GPU:0'):
        cnn = tf.keras.applications.InceptionResNetV2(include_top=False, weights=None, input_tensor=None, input_shape=(N_dim,N_dim,1),pooling=None)
        cnn_mid = layers.GlobalAveragePooling2D()(cnn.output)
        cnn_out = layers.Dense(256, activation = 'relu')(cnn_mid)

        dense_input = layers.Input(shape=(52,))
        dense_mid = layers.Dense(104, activation = 'relu')(dense_input)
        dense_output = layers.Dense(104, activation = 'relu')(dense_mid)
        dense_model = tf.keras.Model(inputs=dense_input, outputs=dense_output)

        concatenated = layers.concatenate([cnn_out, dense_model.output])
        concatenated = layers.Dense(32, activation='relu')(concatenated)
        concat_output = layers.Dense(10, activation='softmax')(concatenated)
        concat_model = tf.keras.models.Model([cnn.input, dense_input], concat_output)
        concat_model.compile(optimizer="adam", loss="categorical_crossentropy", metrics=["accuracy"])
        history = concat_model.fit([train_pixel, train_label], train_answer, validation_data=([valid_pixel, valid_label], valid_answer), epochs=epochs_num, verbose=verbose, callbacks = callbacks1)
    print(
        f"Train accuracy={max(history.history['accuracy']):.5f}, " +
        f"Validation accuracy={max(history.history['val_accuracy']):.5f}"
    )
    with tf.device('/device:GPU:0'):
        concat_model.fit([valid_pixel, valid_label], valid_answer, epochs=5, verbose=verbose)
    concat_model.save(path + ModelName + '_' + str(i) + '.h5')

for i in range(5):
    train_test_model(i)

def train_test_model(i):
    tf.keras.backend.clear_session()
    '''
    I shuffled dataset every time since i wanted to get enoughly distributed models.
    '''
    train_pixel, train_label, train_answer, valid_pixel, valid_label, valid_answer = prepare_datasets(train_raw)
    callbacks1 = [tf.keras.callbacks.EarlyStopping(monitor = 'val_accuracy', patience = 20, restore_best_weights = True), ReduceLROnPlateau(monitor = 'loss', patience = 5)]
    ModelName = 'EfficientNetB5_bicubic224_val_kmean'
    print(ModelName + '  ' + str(i))
    with tf.device('/device:GPU:0'):
        cnn = tf.keras.applications.EfficientNetB5(include_top=False, weights=None, input_tensor=None, input_shape=(N_dim,N_dim,1),pooling=None)
        cnn_mid = layers.GlobalAveragePooling2D()(cnn.output)
        cnn_out = layers.Dense(256, activation = 'relu')(cnn_mid)

        dense_input = layers.Input(shape=(52,))
        dense_mid = layers.Dense(104, activation = 'relu')(dense_input)
        dense_output = layers.Dense(104, activation = 'relu')(dense_mid)
        dense_model = tf.keras.Model(inputs=dense_input, outputs=dense_output)

        concatenated = layers.concatenate([cnn_out, dense_model.output])
        concatenated = layers.Dense(32, activation='relu')(concatenated)
        concat_output = layers.Dense(10, activation='softmax')(concatenated)
        concat_model = tf.keras.models.Model([cnn.input, dense_input], concat_output)
        concat_model.compile(optimizer="adam", loss="categorical_crossentropy", metrics=["accuracy"])
        history = concat_model.fit([train_pixel, train_label], train_answer, validation_data=([valid_pixel, valid_label], valid_answer), epochs=epochs_num, verbose=verbose, callbacks = callbacks1)
    print(
        f"Train accuracy={max(history.history['accuracy']):.5f}, " +
        f"Validation accuracy={max(history.history['val_accuracy']):.5f}"
    )
    with tf.device('/device:GPU:0'):
        concat_model.fit([valid_pixel, valid_label], valid_answer, epochs=5, verbose=verbose)
    concat_model.save(path + ModelName + '_' + str(i) + '.h5')

for i in range(5):
    train_test_model(i)
# Out:
# InceptionResnetV2_bicubic224_val_kmean  0
# Epoch 1/80
# 573/573 - 124s - loss: 1.4260 - accuracy: 0.4862 - val_loss: 3.6134 - val_accuracy: 0.2708
# Epoch 2/80
# 573/573 - 121s - loss: 0.3741 - accuracy: 0.8763 - val_loss: 0.5375 - val_accuracy: 0.8539
# Epoch 3/80
# 573/573 - 120s - loss: 0.1860 - accuracy: 0.9366 - val_loss: 4.8396 - val_accuracy: 0.4133
# Epoch 4/80
# 573/573 - 121s - loss: 0.1153 - accuracy: 0.9614 - val_loss: 0.6092 - val_accuracy: 0.8523
# Epoch 5/80
# 573/573 - 121s - loss: 0.0890 - accuracy: 0.9709 - val_loss: 0.8589 - val_accuracy: 0.8324
# Epoch 6/80
# 573/573 - 121s - loss: 0.0763 - accuracy: 0.9757 - val_loss: 0.6781 - val_accuracy: 0.8439
# Epoch 7/80
# 573/573 - 121s - loss: 0.0685 - accuracy: 0.9797 - val_loss: 0.5578 - val_accuracy: 0.8654
# Epoch 8/80
# 573/573 - 121s - loss: 0.0540 - accuracy: 0.9832 - val_loss: 0.8265 - val_accuracy: 0.8465
# Epoch 9/80
# 573/573 - 120s - loss: 0.0454 - accuracy: 0.9860 - val_loss: 1.0220 - val_accuracy: 0.8172
# Epoch 10/80
# 573/573 - 120s - loss: 0.0490 - accuracy: 0.9845 - val_loss: 3.3979 - val_accuracy: 0.5526
# Epoch 11/80
# 573/573 - 120s - loss: 0.0375 - accuracy: 0.9878 - val_loss: 0.9462 - val_accuracy: 0.7774
# Epoch 12/80
# 573/573 - 121s - loss: 0.0412 - accuracy: 0.9883 - val_loss: 0.6207 - val_accuracy: 0.8816
# Epoch 13/80
# 573/573 - 120s - loss: 0.0372 - accuracy: 0.9887 - val_loss: 0.6457 - val_accuracy: 0.8586
# Epoch 14/80
# 573/573 - 120s - loss: 0.0312 - accuracy: 0.9907 - val_loss: 0.8101 - val_accuracy: 0.8580
# Epoch 15/80
# 573/573 - 120s - loss: 0.0287 - accuracy: 0.9915 - val_loss: 0.9346 - val_accuracy: 0.8355
# Epoch 16/80
# 573/573 - 120s - loss: 0.0353 - accuracy: 0.9897 - val_loss: 0.5386 - val_accuracy: 0.8999
# Epoch 17/80
# 573/573 - 120s - loss: 0.0201 - accuracy: 0.9942 - val_loss: 0.6579 - val_accuracy: 0.8759
# Epoch 18/80
# 573/573 - 120s - loss: 0.0298 - accuracy: 0.9920 - val_loss: 0.8483 - val_accuracy: 0.8570
# Epoch 19/80
# 573/573 - 120s - loss: 0.0299 - accuracy: 0.9909 - val_loss: 0.7985 - val_accuracy: 0.8512
# Epoch 20/80
# 573/573 - 120s - loss: 0.0141 - accuracy: 0.9959 - val_loss: 0.6146 - val_accuracy: 0.8727
# Epoch 21/80
# 573/573 - 120s - loss: 0.0259 - accuracy: 0.9923 - val_loss: 0.8089 - val_accuracy: 0.8460
# Epoch 22/80
# 573/573 - 120s - loss: 0.0167 - accuracy: 0.9956 - val_loss: 0.6529 - val_accuracy: 0.8617
# Epoch 23/80
# 573/573 - 120s - loss: 0.0192 - accuracy: 0.9948 - val_loss: 0.6497 - val_accuracy: 0.8549
# Epoch 24/80
# 573/573 - 120s - loss: 0.0227 - accuracy: 0.9939 - val_loss: 0.6331 - val_accuracy: 0.8748
# Epoch 25/80
# 573/573 - 121s - loss: 0.0198 - accuracy: 0.9942 - val_loss: 0.5993 - val_accuracy: 0.9020
# Epoch 26/80
# 573/573 - 121s - loss: 0.0047 - accuracy: 0.9989 - val_loss: 0.5048 - val_accuracy: 0.9052
# Epoch 27/80
# 573/573 - 121s - loss: 0.0012 - accuracy: 0.9998 - val_loss: 0.5056 - val_accuracy: 0.9078
# Epoch 28/80
# 573/573 - 121s - loss: 5.5243e-04 - accuracy: 1.0000 - val_loss: 0.5157 - val_accuracy: 0.9094
# Epoch 29/80
# 573/573 - 121s - loss: 6.4110e-04 - accuracy: 0.9998 - val_loss: 0.5145 - val_accuracy: 0.9068
# Epoch 30/80
# 573/573 - 121s - loss: 3.4935e-04 - accuracy: 1.0000 - val_loss: 0.5297 - val_accuracy: 0.9062
# Epoch 31/80
# 573/573 - 121s - loss: 3.5510e-04 - accuracy: 0.9999 - val_loss: 0.5360 - val_accuracy: 0.9062
# Epoch 32/80
# 573/573 - 121s - loss: 1.7000e-04 - accuracy: 1.0000 - val_loss: 0.5453 - val_accuracy: 0.9052
# Epoch 33/80
# 573/573 - 121s - loss: 7.0071e-04 - accuracy: 0.9998 - val_loss: 0.5775 - val_accuracy: 0.9036
# Epoch 34/80
# 573/573 - 121s - loss: 6.7275e-04 - accuracy: 0.9998 - val_loss: 0.5883 - val_accuracy: 0.9026
# Epoch 35/80
# 573/573 - 120s - loss: 2.8098e-04 - accuracy: 0.9999 - val_loss: 0.5862 - val_accuracy: 0.9062
# Epoch 36/80
# 573/573 - 121s - loss: 1.1989e-04 - accuracy: 1.0000 - val_loss: 0.5773 - val_accuracy: 0.9031
# Epoch 37/80
# 573/573 - 120s - loss: 6.5594e-04 - accuracy: 0.9999 - val_loss: 0.5708 - val_accuracy: 0.9005
# Epoch 38/80
# 573/573 - 121s - loss: 5.7716e-04 - accuracy: 0.9998 - val_loss: 0.5658 - val_accuracy: 0.9036
# Epoch 39/80
# 573/573 - 121s - loss: 1.8213e-04 - accuracy: 0.9999 - val_loss: 0.5646 - val_accuracy: 0.9036
# Epoch 40/80
# 573/573 - 121s - loss: 1.5410e-04 - accuracy: 1.0000 - val_loss: 0.5731 - val_accuracy: 0.9031
# Epoch 41/80
# 573/573 - 120s - loss: 1.8877e-04 - accuracy: 0.9999 - val_loss: 0.5799 - val_accuracy: 0.9015
# Epoch 42/80
# 573/573 - 121s - loss: 1.9020e-04 - accuracy: 0.9999 - val_loss: 0.5876 - val_accuracy: 0.9026
# Epoch 43/80
# 573/573 - 121s - loss: 8.8620e-05 - accuracy: 1.0000 - val_loss: 0.5861 - val_accuracy: 0.9010
# Train accuracy=1.00000, Validation accuracy=0.90938
# Epoch 1/5
# 60/60 - 12s - loss: 0.5588 - accuracy: 0.9010
# Epoch 2/5
# 60/60 - 12s - loss: 0.5259 - accuracy: 0.9031
# Epoch 3/5
# 60/60 - 12s - loss: 0.4963 - accuracy: 0.9073
# Epoch 4/5
# 60/60 - 12s - loss: 0.5054 - accuracy: 0.9073
# Epoch 5/5
# 60/60 - 12s - loss: 0.4711 - accuracy: 0.9094
# InceptionResnetV2_bicubic224_val_kmean  1
# Epoch 1/80
# 573/573 - 124s - loss: 0.9015 - accuracy: 0.6948 - val_loss: 2.7280 - val_accuracy: 0.3745
# Epoch 2/80
# 573/573 - 121s - loss: 0.2718 - accuracy: 0.9093 - val_loss: 0.6234 - val_accuracy: 0.8350
# Epoch 3/80
# 573/573 - 121s - loss: 0.1432 - accuracy: 0.9532 - val_loss: 0.5209 - val_accuracy: 0.8617
# Epoch 4/80
# 573/573 - 120s - loss: 0.1128 - accuracy: 0.9624 - val_loss: 0.8884 - val_accuracy: 0.8193
# Epoch 5/80
# 573/573 - 121s - loss: 0.0798 - accuracy: 0.9746 - val_loss: 0.5384 - val_accuracy: 0.8764
# Epoch 6/80
# 573/573 - 120s - loss: 0.0765 - accuracy: 0.9764 - val_loss: 0.5202 - val_accuracy: 0.8738
# Epoch 7/80
# 573/573 - 121s - loss: 0.0625 - accuracy: 0.9805 - val_loss: 0.4694 - val_accuracy: 0.8942
# Epoch 8/80
# 573/573 - 121s - loss: 0.0424 - accuracy: 0.9868 - val_loss: 0.5179 - val_accuracy: 0.8910
# Epoch 9/80
# 573/573 - 121s - loss: 0.0505 - accuracy: 0.9848 - val_loss: 0.4792 - val_accuracy: 0.8816
# Epoch 10/80
# 573/573 - 121s - loss: 0.0510 - accuracy: 0.9843 - val_loss: 0.9630 - val_accuracy: 0.7878
# Epoch 11/80
# 573/573 - 121s - loss: 0.0345 - accuracy: 0.9892 - val_loss: 0.6055 - val_accuracy: 0.8638
# Epoch 12/80
# 573/573 - 121s - loss: 0.0400 - accuracy: 0.9889 - val_loss: 0.7328 - val_accuracy: 0.8539
# Epoch 13/80
# 573/573 - 121s - loss: 0.0204 - accuracy: 0.9935 - val_loss: 0.4167 - val_accuracy: 0.9141
# Epoch 14/80
# 573/573 - 121s - loss: 0.0362 - accuracy: 0.9885 - val_loss: 0.5430 - val_accuracy: 0.8905
# Epoch 15/80
# 573/573 - 121s - loss: 0.0291 - accuracy: 0.9912 - val_loss: 0.6326 - val_accuracy: 0.8821
# Epoch 16/80
# 573/573 - 121s - loss: 0.0207 - accuracy: 0.9940 - val_loss: 0.7637 - val_accuracy: 0.8659
# Epoch 17/80
# 573/573 - 121s - loss: 0.0342 - accuracy: 0.9900 - val_loss: 0.5436 - val_accuracy: 0.8942
# Epoch 18/80
# 573/573 - 121s - loss: 0.0238 - accuracy: 0.9929 - val_loss: 0.8253 - val_accuracy: 0.8533
# Epoch 19/80
# 573/573 - 121s - loss: 0.0055 - accuracy: 0.9980 - val_loss: 0.4881 - val_accuracy: 0.9073
# Epoch 20/80
# 573/573 - 121s - loss: 0.0011 - accuracy: 0.9997 - val_loss: 0.4893 - val_accuracy: 0.9068
# Epoch 21/80
# 573/573 - 121s - loss: 6.1893e-04 - accuracy: 0.9999 - val_loss: 0.4884 - val_accuracy: 0.9062
# Epoch 22/80
# 573/573 - 121s - loss: 4.4948e-04 - accuracy: 1.0000 - val_loss: 0.5019 - val_accuracy: 0.9062
# Epoch 23/80
# 573/573 - 121s - loss: 2.9745e-04 - accuracy: 1.0000 - val_loss: 0.5080 - val_accuracy: 0.9068
# Epoch 24/80
# 573/573 - 121s - loss: 2.3559e-04 - accuracy: 1.0000 - val_loss: 0.5093 - val_accuracy: 0.9115
# Epoch 25/80
# 573/573 - 121s - loss: 1.6808e-04 - accuracy: 1.0000 - val_loss: 0.5128 - val_accuracy: 0.9109
# Epoch 26/80
# 573/573 - 121s - loss: 1.9670e-04 - accuracy: 1.0000 - val_loss: 0.5203 - val_accuracy: 0.9089
# Epoch 27/80
# 573/573 - 121s - loss: 1.4851e-04 - accuracy: 1.0000 - val_loss: 0.5383 - val_accuracy: 0.9073
# Epoch 28/80
# 573/573 - 121s - loss: 7.8248e-05 - accuracy: 1.0000 - val_loss: 0.5310 - val_accuracy: 0.9094
# Train accuracy=1.00000, Validation accuracy=0.91409
# Epoch 1/5
# 60/60 - 12s - loss: 0.1753 - accuracy: 0.9513
# Epoch 2/5
# 60/60 - 12s - loss: 0.0173 - accuracy: 0.9958
# Epoch 3/5
# 60/60 - 12s - loss: 0.0046 - accuracy: 1.0000
# Epoch 4/5
# 60/60 - 12s - loss: 0.0037 - accuracy: 0.9995
# Epoch 5/5
# 60/60 - 12s - loss: 0.0032 - accuracy: 1.0000
# InceptionResnetV2_bicubic224_val_kmean  2
# Epoch 1/80
# 573/573 - 124s - loss: 0.7980 - accuracy: 0.7255 - val_loss: 2.0669 - val_accuracy: 0.4521
# Epoch 2/80
# 573/573 - 121s - loss: 0.2820 - accuracy: 0.9057 - val_loss: 1.0497 - val_accuracy: 0.7208
# Epoch 3/80
# 573/573 - 121s - loss: 0.1530 - accuracy: 0.9478 - val_loss: 0.5192 - val_accuracy: 0.8601
# Epoch 4/80
# 573/573 - 121s - loss: 0.0989 - accuracy: 0.9676 - val_loss: 0.7828 - val_accuracy: 0.8387
# Epoch 5/80
# 573/573 - 121s - loss: 0.0830 - accuracy: 0.9725 - val_loss: 0.5431 - val_accuracy: 0.8596
# Epoch 6/80
# 573/573 - 121s - loss: 0.0660 - accuracy: 0.9791 - val_loss: 0.5471 - val_accuracy: 0.8717
# Epoch 7/80
# 573/573 - 121s - loss: 0.0627 - accuracy: 0.9793 - val_loss: 0.4422 - val_accuracy: 0.8759
# Epoch 8/80
# 573/573 - 121s - loss: 0.0567 - accuracy: 0.9829 - val_loss: 0.9390 - val_accuracy: 0.8098
# Epoch 9/80
# 573/573 - 120s - loss: 0.0392 - accuracy: 0.9876 - val_loss: 0.6469 - val_accuracy: 0.8617
# Epoch 10/80
# 573/573 - 121s - loss: 0.0497 - accuracy: 0.9854 - val_loss: 0.3746 - val_accuracy: 0.8937
# Epoch 11/80
# 573/573 - 121s - loss: 0.0250 - accuracy: 0.9914 - val_loss: 0.5541 - val_accuracy: 0.8968
# Epoch 12/80
# 573/573 - 121s - loss: 0.0440 - accuracy: 0.9861 - val_loss: 0.8626 - val_accuracy: 0.8125
# Epoch 13/80
# 573/573 - 120s - loss: 0.0267 - accuracy: 0.9918 - val_loss: 0.5667 - val_accuracy: 0.8837
# Epoch 14/80
# 573/573 - 120s - loss: 0.0364 - accuracy: 0.9888 - val_loss: 0.6175 - val_accuracy: 0.8638
# Epoch 15/80
# 573/573 - 121s - loss: 0.0198 - accuracy: 0.9939 - val_loss: 0.5043 - val_accuracy: 0.8916
# Epoch 16/80
# 573/573 - 120s - loss: 0.0263 - accuracy: 0.9919 - val_loss: 1.2632 - val_accuracy: 0.8256
# Epoch 17/80
# 573/573 - 121s - loss: 0.0330 - accuracy: 0.9907 - val_loss: 0.4101 - val_accuracy: 0.9199
# Epoch 18/80
# 573/573 - 121s - loss: 0.0284 - accuracy: 0.9919 - val_loss: 0.5546 - val_accuracy: 0.8910
# Epoch 19/80
# 573/573 - 121s - loss: 0.0131 - accuracy: 0.9959 - val_loss: 0.4546 - val_accuracy: 0.9178
# Epoch 20/80
# 573/573 - 120s - loss: 0.0142 - accuracy: 0.9954 - val_loss: 0.6724 - val_accuracy: 0.8816
# Epoch 21/80
# 573/573 - 120s - loss: 0.0362 - accuracy: 0.9897 - val_loss: 0.5217 - val_accuracy: 0.8874
# Epoch 22/80
# 573/573 - 120s - loss: 0.0108 - accuracy: 0.9972 - val_loss: 0.5362 - val_accuracy: 0.8685
# Epoch 23/80
# 573/573 - 121s - loss: 0.0284 - accuracy: 0.9927 - val_loss: 0.5065 - val_accuracy: 0.8979
# Epoch 24/80
# 573/573 - 120s - loss: 0.0133 - accuracy: 0.9960 - val_loss: 1.4661 - val_accuracy: 0.7732
# Epoch 25/80
# 573/573 - 120s - loss: 0.0230 - accuracy: 0.9937 - val_loss: 0.3632 - val_accuracy: 0.9162
# Epoch 26/80
# 573/573 - 120s - loss: 0.0068 - accuracy: 0.9978 - val_loss: 0.6939 - val_accuracy: 0.8680
# Epoch 27/80
# 573/573 - 120s - loss: 0.0231 - accuracy: 0.9936 - val_loss: 0.8980 - val_accuracy: 0.8586
# Epoch 28/80
# 573/573 - 121s - loss: 0.0059 - accuracy: 0.9985 - val_loss: 0.4468 - val_accuracy: 0.9251
# Epoch 29/80
# 573/573 - 120s - loss: 0.0298 - accuracy: 0.9922 - val_loss: 0.4989 - val_accuracy: 0.9104
# Epoch 30/80
# 573/573 - 120s - loss: 0.0014 - accuracy: 0.9997 - val_loss: 0.6028 - val_accuracy: 0.9214
# Epoch 31/80
# 573/573 - 120s - loss: 0.0254 - accuracy: 0.9928 - val_loss: 0.4694 - val_accuracy: 0.9141
# Epoch 32/80
# 573/573 - 120s - loss: 0.0124 - accuracy: 0.9965 - val_loss: 0.4940 - val_accuracy: 0.8952
# Epoch 33/80
# 573/573 - 120s - loss: 0.0081 - accuracy: 0.9975 - val_loss: 0.4892 - val_accuracy: 0.9157
# Epoch 34/80
# 573/573 - 121s - loss: 0.0135 - accuracy: 0.9965 - val_loss: 0.5071 - val_accuracy: 0.9078
# Epoch 35/80
# 573/573 - 120s - loss: 0.0060 - accuracy: 0.9988 - val_loss: 0.4093 - val_accuracy: 0.9172
# Epoch 36/80
# 573/573 - 121s - loss: 9.7975e-04 - accuracy: 0.9997 - val_loss: 0.3945 - val_accuracy: 0.9277
# Epoch 37/80
# 573/573 - 121s - loss: 3.0164e-04 - accuracy: 0.9999 - val_loss: 0.3951 - val_accuracy: 0.9288
# Epoch 38/80
# 573/573 - 121s - loss: 3.0904e-04 - accuracy: 0.9999 - val_loss: 0.3604 - val_accuracy: 0.9350
# Epoch 39/80
# 573/573 - 120s - loss: 2.0459e-04 - accuracy: 0.9999 - val_loss: 0.3793 - val_accuracy: 0.9329
# Epoch 40/80
# 573/573 - 121s - loss: 1.0124e-04 - accuracy: 1.0000 - val_loss: 0.3792 - val_accuracy: 0.9356
# Epoch 41/80
# 573/573 - 121s - loss: 3.5554e-04 - accuracy: 0.9998 - val_loss: 0.3695 - val_accuracy: 0.9356
# Epoch 42/80
# 573/573 - 120s - loss: 1.5305e-04 - accuracy: 0.9999 - val_loss: 0.3752 - val_accuracy: 0.9350
# Epoch 43/80
# 573/573 - 121s - loss: 6.4342e-05 - accuracy: 1.0000 - val_loss: 0.3785 - val_accuracy: 0.9382
# Epoch 44/80
# 573/573 - 121s - loss: 5.1503e-05 - accuracy: 1.0000 - val_loss: 0.3859 - val_accuracy: 0.9335
# Epoch 45/80
# 573/573 - 120s - loss: 4.0864e-05 - accuracy: 1.0000 - val_loss: 0.3894 - val_accuracy: 0.9361
# Epoch 46/80
# 573/573 - 120s - loss: 1.8068e-04 - accuracy: 0.9999 - val_loss: 0.3918 - val_accuracy: 0.9345
# Epoch 47/80
# 573/573 - 120s - loss: 2.8186e-05 - accuracy: 1.0000 - val_loss: 0.3912 - val_accuracy: 0.9361
# Epoch 48/80
# 573/573 - 121s - loss: 5.5850e-05 - accuracy: 1.0000 - val_loss: 0.3903 - val_accuracy: 0.9356
# Epoch 49/80
# 573/573 - 121s - loss: 2.7271e-05 - accuracy: 1.0000 - val_loss: 0.3943 - val_accuracy: 0.9361
# Epoch 50/80
# 573/573 - 121s - loss: 3.8078e-05 - accuracy: 1.0000 - val_loss: 0.3911 - val_accuracy: 0.9366
# Epoch 51/80
# 573/573 - 120s - loss: 2.1664e-05 - accuracy: 1.0000 - val_loss: 0.3954 - val_accuracy: 0.9356
# Epoch 52/80
# 573/573 - 120s - loss: 2.3502e-05 - accuracy: 1.0000 - val_loss: 0.3933 - val_accuracy: 0.9361
# Epoch 53/80
# 573/573 - 120s - loss: 2.5183e-05 - accuracy: 1.0000 - val_loss: 0.3965 - val_accuracy: 0.9356
# Epoch 54/80
# 573/573 - 120s - loss: 6.9098e-05 - accuracy: 0.9999 - val_loss: 0.3943 - val_accuracy: 0.9356
# Epoch 55/80
# 573/573 - 120s - loss: 2.2265e-05 - accuracy: 1.0000 - val_loss: 0.3908 - val_accuracy: 0.9356
# Epoch 56/80
# 573/573 - 120s - loss: 3.8560e-05 - accuracy: 1.0000 - val_loss: 0.3945 - val_accuracy: 0.9356
# Epoch 57/80
# 573/573 - 120s - loss: 2.5089e-05 - accuracy: 1.0000 - val_loss: 0.3969 - val_accuracy: 0.9350
# Epoch 58/80
# 573/573 - 121s - loss: 3.6098e-05 - accuracy: 1.0000 - val_loss: 0.3932 - val_accuracy: 0.9361
# Train accuracy=1.00000, Validation accuracy=0.93819
# Epoch 1/5
# 60/60 - 12s - loss: 0.4462 - accuracy: 0.9267
# Epoch 2/5
# 60/60 - 12s - loss: 0.4194 - accuracy: 0.9288
# Epoch 3/5
# 60/60 - 12s - loss: 0.4247 - accuracy: 0.9261
# Epoch 4/5
# 60/60 - 12s - loss: 0.4360 - accuracy: 0.9272
# Epoch 5/5
# 60/60 - 12s - loss: 0.4253 - accuracy: 0.9345
# InceptionResnetV2_bicubic224_val_kmean  3
# Epoch 1/80
# 573/573 - 124s - loss: 1.0049 - accuracy: 0.6525 - val_loss: 1.9785 - val_accuracy: 0.3834
# Epoch 2/80
# 573/573 - 121s - loss: 0.3068 - accuracy: 0.8999 - val_loss: 1.3965 - val_accuracy: 0.6925
# Epoch 3/80
# 573/573 - 121s - loss: 0.1877 - accuracy: 0.9369 - val_loss: 0.7424 - val_accuracy: 0.8104
# Epoch 4/80
# 573/573 - 121s - loss: 0.1278 - accuracy: 0.9592 - val_loss: 0.7675 - val_accuracy: 0.8298
# Epoch 5/80
# 573/573 - 121s - loss: 0.0895 - accuracy: 0.9713 - val_loss: 0.8212 - val_accuracy: 0.8287
# Epoch 6/80
# 573/573 - 121s - loss: 0.0679 - accuracy: 0.9777 - val_loss: 0.7365 - val_accuracy: 0.8476
# Epoch 7/80
# 573/573 - 120s - loss: 0.0712 - accuracy: 0.9790 - val_loss: 0.6877 - val_accuracy: 0.8366
# Epoch 8/80
# 573/573 - 121s - loss: 0.0568 - accuracy: 0.9823 - val_loss: 0.6344 - val_accuracy: 0.8539
# Epoch 9/80
# 573/573 - 121s - loss: 0.0527 - accuracy: 0.9836 - val_loss: 0.6294 - val_accuracy: 0.8743
# Epoch 10/80
# 573/573 - 120s - loss: 0.0355 - accuracy: 0.9892 - val_loss: 0.6134 - val_accuracy: 0.8696
# Epoch 11/80
# 573/573 - 121s - loss: 0.0472 - accuracy: 0.9857 - val_loss: 0.6637 - val_accuracy: 0.8800
# Epoch 12/80
# 573/573 - 120s - loss: 0.0372 - accuracy: 0.9889 - val_loss: 0.6809 - val_accuracy: 0.8612
# Epoch 13/80
# 573/573 - 120s - loss: 0.0391 - accuracy: 0.9884 - val_loss: 0.6743 - val_accuracy: 0.8722
# Epoch 14/80
# 573/573 - 120s - loss: 0.0320 - accuracy: 0.9904 - val_loss: 0.5802 - val_accuracy: 0.8879
# Epoch 15/80
# 573/573 - 120s - loss: 0.0222 - accuracy: 0.9932 - val_loss: 0.7548 - val_accuracy: 0.8607
# Epoch 16/80
# 573/573 - 120s - loss: 0.0284 - accuracy: 0.9915 - val_loss: 0.6146 - val_accuracy: 0.8821
# Epoch 17/80
# 573/573 - 120s - loss: 0.0377 - accuracy: 0.9898 - val_loss: 0.5518 - val_accuracy: 0.8732
# Epoch 18/80
# 573/573 - 120s - loss: 0.0224 - accuracy: 0.9933 - val_loss: 0.7049 - val_accuracy: 0.8638
# Epoch 19/80
# 573/573 - 120s - loss: 0.0303 - accuracy: 0.9911 - val_loss: 0.7125 - val_accuracy: 0.8575
# Epoch 20/80
# 573/573 - 121s - loss: 0.0143 - accuracy: 0.9963 - val_loss: 0.5994 - val_accuracy: 0.8979
# Epoch 21/80
# 573/573 - 120s - loss: 0.0245 - accuracy: 0.9930 - val_loss: 0.7138 - val_accuracy: 0.8649
# Epoch 22/80
# 573/573 - 120s - loss: 0.0194 - accuracy: 0.9948 - val_loss: 0.4619 - val_accuracy: 0.9047
# Epoch 23/80
# 573/573 - 120s - loss: 0.0249 - accuracy: 0.9940 - val_loss: 0.7620 - val_accuracy: 0.8654
# Epoch 24/80
# 573/573 - 120s - loss: 0.0214 - accuracy: 0.9943 - val_loss: 0.6370 - val_accuracy: 0.8680
# Epoch 25/80
# 573/573 - 120s - loss: 0.0153 - accuracy: 0.9960 - val_loss: 1.3004 - val_accuracy: 0.7941
# Epoch 26/80
# 573/573 - 120s - loss: 0.0130 - accuracy: 0.9961 - val_loss: 0.5877 - val_accuracy: 0.8905
# Epoch 27/80
# 573/573 - 120s - loss: 0.0023 - accuracy: 0.9995 - val_loss: 0.6153 - val_accuracy: 0.8879
# Epoch 28/80
# 573/573 - 120s - loss: 0.0013 - accuracy: 0.9997 - val_loss: 0.6275 - val_accuracy: 0.8879
# Epoch 29/80
# 573/573 - 120s - loss: 6.3235e-04 - accuracy: 0.9999 - val_loss: 0.6024 - val_accuracy: 0.8921
# Epoch 30/80
# 573/573 - 120s - loss: 5.1478e-04 - accuracy: 0.9998 - val_loss: 0.6216 - val_accuracy: 0.8900
# Epoch 31/80
# 573/573 - 120s - loss: 3.1875e-04 - accuracy: 1.0000 - val_loss: 0.6103 - val_accuracy: 0.8937
# Epoch 32/80
# 573/573 - 120s - loss: 3.0842e-04 - accuracy: 0.9999 - val_loss: 0.6231 - val_accuracy: 0.8963
# Epoch 33/80
# 573/573 - 120s - loss: 3.9846e-04 - accuracy: 0.9999 - val_loss: 0.6369 - val_accuracy: 0.8968
# Epoch 34/80
# 573/573 - 120s - loss: 2.1222e-04 - accuracy: 0.9999 - val_loss: 0.6622 - val_accuracy: 0.8889
# Epoch 35/80
# 573/573 - 121s - loss: 1.4205e-04 - accuracy: 1.0000 - val_loss: 0.6851 - val_accuracy: 0.8884
# Epoch 36/80
# 573/573 - 120s - loss: 1.8210e-04 - accuracy: 0.9999 - val_loss: 0.6879 - val_accuracy: 0.8869
# Epoch 37/80
# 573/573 - 121s - loss: 2.0384e-04 - accuracy: 0.9999 - val_loss: 0.7233 - val_accuracy: 0.8905
# Train accuracy=1.00000, Validation accuracy=0.90466
# Epoch 1/5
# 60/60 - 12s - loss: 0.1840 - accuracy: 0.9523
# Epoch 2/5
# 60/60 - 12s - loss: 0.0172 - accuracy: 0.9942
# Epoch 3/5
# 60/60 - 12s - loss: 0.0086 - accuracy: 0.9969
# Epoch 4/5
# 60/60 - 12s - loss: 0.0052 - accuracy: 0.9995
# Epoch 5/5
# 60/60 - 12s - loss: 0.0027 - accuracy: 1.0000
# InceptionResnetV2_bicubic224_val_kmean  4
# Epoch 1/80
# 573/573 - 124s - loss: 0.8369 - accuracy: 0.7122 - val_loss: 3.1616 - val_accuracy: 0.3038
# Epoch 2/80
# 573/573 - 121s - loss: 0.2511 - accuracy: 0.9153 - val_loss: 0.6926 - val_accuracy: 0.8104
# Epoch 3/80
# 573/573 - 121s - loss: 0.1510 - accuracy: 0.9500 - val_loss: 0.6801 - val_accuracy: 0.8402
# Epoch 4/80
# 573/573 - 121s - loss: 0.1013 - accuracy: 0.9657 - val_loss: 0.5440 - val_accuracy: 0.8722
# Epoch 5/80
# 573/573 - 121s - loss: 0.0752 - accuracy: 0.9752 - val_loss: 1.1390 - val_accuracy: 0.7648
# Epoch 6/80
# 573/573 - 121s - loss: 0.0644 - accuracy: 0.9795 - val_loss: 0.6927 - val_accuracy: 0.8675
# Epoch 7/80
# 573/573 - 121s - loss: 0.0740 - accuracy: 0.9777 - val_loss: 1.1247 - val_accuracy: 0.7826
# Epoch 8/80
# 573/573 - 121s - loss: 0.0365 - accuracy: 0.9891 - val_loss: 1.0177 - val_accuracy: 0.8109
# Epoch 9/80
# 573/573 - 120s - loss: 0.0422 - accuracy: 0.9861 - val_loss: 0.9024 - val_accuracy: 0.8413
# Epoch 10/80
# 573/573 - 120s - loss: 0.0461 - accuracy: 0.9844 - val_loss: 1.2813 - val_accuracy: 0.7878
# Epoch 11/80
# 573/573 - 120s - loss: 0.0423 - accuracy: 0.9860 - val_loss: 0.9266 - val_accuracy: 0.8114
# Epoch 12/80
# 573/573 - 121s - loss: 0.0456 - accuracy: 0.9850 - val_loss: 0.9565 - val_accuracy: 0.8046
# Epoch 13/80
# 573/573 - 120s - loss: 0.0161 - accuracy: 0.9960 - val_loss: 1.3125 - val_accuracy: 0.8093
# Epoch 14/80
# 573/573 - 121s - loss: 0.0322 - accuracy: 0.9903 - val_loss: 0.8801 - val_accuracy: 0.8523
# Epoch 15/80
# 573/573 - 120s - loss: 0.0203 - accuracy: 0.9946 - val_loss: 1.1166 - val_accuracy: 0.8104
# Epoch 16/80
# 573/573 - 121s - loss: 0.0329 - accuracy: 0.9907 - val_loss: 0.8372 - val_accuracy: 0.8591
# Epoch 17/80
# 573/573 - 120s - loss: 0.0320 - accuracy: 0.9900 - val_loss: 1.0666 - val_accuracy: 0.8408
# Epoch 18/80
# 573/573 - 120s - loss: 0.0131 - accuracy: 0.9962 - val_loss: 0.9439 - val_accuracy: 0.8423
# Epoch 19/80
# 573/573 - 121s - loss: 0.0288 - accuracy: 0.9918 - val_loss: 0.8394 - val_accuracy: 0.8664
# Train accuracy=0.99618, Validation accuracy=0.87218
# Epoch 1/5
# 60/60 - 12s - loss: 0.6105 - accuracy: 0.8146
# Epoch 2/5
# 60/60 - 12s - loss: 0.1506 - accuracy: 0.9529
# Epoch 3/5
# 60/60 - 12s - loss: 0.0785 - accuracy: 0.9759
# Epoch 4/5
# 60/60 - 12s - loss: 0.0322 - accuracy: 0.9906
# Epoch 5/5
# 60/60 - 12s - loss: 0.0127 - accuracy: 0.9969
# EfficientNetB5_bicubic224_val_kmean  0
# Epoch 1/80
# 573/573 - 257s - loss: 2.0615 - accuracy: 0.2354 - val_loss: 2.3044 - val_accuracy: 0.0896
# Epoch 2/80
# 573/573 - 251s - loss: 1.2113 - accuracy: 0.5822 - val_loss: 0.8558 - val_accuracy: 0.7433
# Epoch 3/80
# 573/573 - 253s - loss: 0.5013 - accuracy: 0.8437 - val_loss: 1.4747 - val_accuracy: 0.6380
# Epoch 4/80
# 573/573 - 254s - loss: 0.3000 - accuracy: 0.9044 - val_loss: 1.2877 - val_accuracy: 0.7245
# Epoch 5/80
# 573/573 - 252s - loss: 0.2021 - accuracy: 0.9348 - val_loss: 4.1665 - val_accuracy: 0.3939
# Epoch 6/80
# 573/573 - 252s - loss: 0.1511 - accuracy: 0.9524 - val_loss: 0.4815 - val_accuracy: 0.8685
# Epoch 7/80
# 573/573 - 249s - loss: 0.1428 - accuracy: 0.9545 - val_loss: 0.5591 - val_accuracy: 0.8580
# Epoch 8/80
# 573/573 - 252s - loss: 0.1030 - accuracy: 0.9670 - val_loss: 0.5782 - val_accuracy: 0.8779
# Epoch 9/80
# 573/573 - 252s - loss: 0.0987 - accuracy: 0.9683 - val_loss: 2.0986 - val_accuracy: 0.6406
# Epoch 10/80
# 573/573 - 252s - loss: 0.0797 - accuracy: 0.9766 - val_loss: 0.4299 - val_accuracy: 0.8884
# Epoch 11/80
# 573/573 - 251s - loss: 0.0721 - accuracy: 0.9768 - val_loss: 0.6097 - val_accuracy: 0.8690
# Epoch 12/80
# 573/573 - 254s - loss: 0.0675 - accuracy: 0.9790 - val_loss: 0.4463 - val_accuracy: 0.9005
# Epoch 13/80
# 573/573 - 254s - loss: 0.0711 - accuracy: 0.9782 - val_loss: 1.9097 - val_accuracy: 0.7150
# Epoch 14/80
# 573/573 - 254s - loss: 0.0480 - accuracy: 0.9844 - val_loss: 0.5015 - val_accuracy: 0.8905
# Epoch 15/80
# 573/573 - 254s - loss: 0.0521 - accuracy: 0.9843 - val_loss: 0.5299 - val_accuracy: 0.8669
# Epoch 16/80
# 573/573 - 252s - loss: 0.0432 - accuracy: 0.9870 - val_loss: 0.6343 - val_accuracy: 0.8633
# Epoch 17/80
# 573/573 - 253s - loss: 0.0470 - accuracy: 0.9859 - val_loss: 1.3335 - val_accuracy: 0.7664
# Epoch 18/80
# 573/573 - 254s - loss: 0.0433 - accuracy: 0.9876 - val_loss: 0.5841 - val_accuracy: 0.8832
# Epoch 19/80
# 573/573 - 250s - loss: 0.0371 - accuracy: 0.9894 - val_loss: 0.5567 - val_accuracy: 0.8753
# Epoch 20/80
# 573/573 - 250s - loss: 0.0282 - accuracy: 0.9912 - val_loss: 0.4123 - val_accuracy: 0.8926
# Epoch 21/80
# 573/573 - 248s - loss: 0.0386 - accuracy: 0.9888 - val_loss: 0.5557 - val_accuracy: 0.8895
# Epoch 22/80
# 573/573 - 251s - loss: 0.0335 - accuracy: 0.9905 - val_loss: 3.4382 - val_accuracy: 0.5579
# Epoch 23/80
# 573/573 - 252s - loss: 0.0402 - accuracy: 0.9891 - val_loss: 0.7347 - val_accuracy: 0.8649
# Epoch 24/80
# 573/573 - 253s - loss: 0.0266 - accuracy: 0.9925 - val_loss: 0.6615 - val_accuracy: 0.8711
# Epoch 25/80
# 573/573 - 252s - loss: 0.0298 - accuracy: 0.9914 - val_loss: 0.5434 - val_accuracy: 0.8832
# Epoch 26/80
# 573/573 - 252s - loss: 0.0386 - accuracy: 0.9887 - val_loss: 0.3504 - val_accuracy: 0.9041
# Epoch 27/80
# 573/573 - 252s - loss: 0.0213 - accuracy: 0.9943 - val_loss: 0.7957 - val_accuracy: 0.8539
# Epoch 28/80
# 573/573 - 251s - loss: 0.0278 - accuracy: 0.9924 - val_loss: 3.3333 - val_accuracy: 0.5348
# Epoch 29/80
# 573/573 - 251s - loss: 0.0294 - accuracy: 0.9913 - val_loss: 5.4418 - val_accuracy: 0.4264
# Epoch 30/80
# 573/573 - 250s - loss: 0.0276 - accuracy: 0.9918 - val_loss: 0.6089 - val_accuracy: 0.8863
# Epoch 31/80
# 573/573 - 248s - loss: 0.0155 - accuracy: 0.9954 - val_loss: 0.4976 - val_accuracy: 0.8984
# Epoch 32/80
# 573/573 - 249s - loss: 0.0273 - accuracy: 0.9930 - val_loss: 0.5573 - val_accuracy: 0.8905
# Epoch 33/80
# 573/573 - 251s - loss: 0.0192 - accuracy: 0.9948 - val_loss: 0.8208 - val_accuracy: 0.8601
# Epoch 34/80
# 573/573 - 252s - loss: 0.0265 - accuracy: 0.9927 - val_loss: 0.5935 - val_accuracy: 0.8947
# Epoch 35/80
# 573/573 - 254s - loss: 0.0166 - accuracy: 0.9959 - val_loss: 0.6780 - val_accuracy: 0.8785
# Epoch 36/80
# 573/573 - 252s - loss: 0.0235 - accuracy: 0.9944 - val_loss: 0.6037 - val_accuracy: 0.8937
# Epoch 37/80
# 573/573 - 254s - loss: 0.0054 - accuracy: 0.9984 - val_loss: 0.4991 - val_accuracy: 0.9036
# Epoch 38/80
# 573/573 - 253s - loss: 0.0020 - accuracy: 0.9995 - val_loss: 0.4881 - val_accuracy: 0.9089
# Epoch 39/80
# 573/573 - 251s - loss: 0.0012 - accuracy: 0.9998 - val_loss: 0.4627 - val_accuracy: 0.9078
# Epoch 40/80
# 573/573 - 253s - loss: 7.8436e-04 - accuracy: 0.9998 - val_loss: 0.4877 - val_accuracy: 0.9078
# Epoch 41/80
# 573/573 - 253s - loss: 7.5175e-04 - accuracy: 0.9998 - val_loss: 0.4860 - val_accuracy: 0.9130
# Epoch 42/80
# 573/573 - 254s - loss: 5.3062e-04 - accuracy: 0.9999 - val_loss: 0.5393 - val_accuracy: 0.9078
# Epoch 43/80
# 573/573 - 253s - loss: 4.7728e-04 - accuracy: 0.9998 - val_loss: 0.4983 - val_accuracy: 0.9089
# Epoch 44/80
# 573/573 - 254s - loss: 3.3649e-04 - accuracy: 1.0000 - val_loss: 0.5028 - val_accuracy: 0.9089
# Epoch 45/80
# 573/573 - 252s - loss: 3.5949e-04 - accuracy: 0.9999 - val_loss: 0.5526 - val_accuracy: 0.9109
# Epoch 46/80
# 573/573 - 253s - loss: 6.7217e-04 - accuracy: 0.9998 - val_loss: 0.5568 - val_accuracy: 0.9078
# Epoch 47/80
# 573/573 - 254s - loss: 4.4089e-04 - accuracy: 0.9997 - val_loss: 0.5834 - val_accuracy: 0.9078
# Epoch 48/80
# 573/573 - 252s - loss: 4.8700e-04 - accuracy: 0.9998 - val_loss: 0.5739 - val_accuracy: 0.9115
# Epoch 49/80
# 573/573 - 252s - loss: 3.1070e-04 - accuracy: 0.9999 - val_loss: 0.5537 - val_accuracy: 0.9125
# Epoch 50/80
# 573/573 - 252s - loss: 3.5485e-04 - accuracy: 0.9999 - val_loss: 0.5523 - val_accuracy: 0.9115
# Epoch 51/80
# 573/573 - 254s - loss: 1.5564e-04 - accuracy: 1.0000 - val_loss: 0.5575 - val_accuracy: 0.9130
# Epoch 52/80
# 573/573 - 253s - loss: 5.2581e-04 - accuracy: 0.9998 - val_loss: 0.5507 - val_accuracy: 0.9136
# Epoch 53/80
# 573/573 - 252s - loss: 2.2129e-04 - accuracy: 0.9999 - val_loss: 0.5496 - val_accuracy: 0.9141
# Epoch 54/80
# 573/573 - 253s - loss: 2.7772e-04 - accuracy: 0.9998 - val_loss: 0.5598 - val_accuracy: 0.9141
# Epoch 55/80
# 573/573 - 252s - loss: 1.0056e-04 - accuracy: 1.0000 - val_loss: 0.5521 - val_accuracy: 0.9167
# Epoch 56/80
# 573/573 - 255s - loss: 1.6473e-04 - accuracy: 0.9999 - val_loss: 0.5525 - val_accuracy: 0.9183
# Epoch 57/80
# 573/573 - 252s - loss: 1.9515e-04 - accuracy: 0.9999 - val_loss: 0.5576 - val_accuracy: 0.9167
# Epoch 58/80
# 573/573 - 253s - loss: 1.6469e-04 - accuracy: 0.9999 - val_loss: 0.5482 - val_accuracy: 0.9167
# Epoch 59/80
# 573/573 - 251s - loss: 8.6272e-05 - accuracy: 1.0000 - val_loss: 0.5597 - val_accuracy: 0.9172
# Epoch 60/80
# 573/573 - 252s - loss: 1.0996e-04 - accuracy: 1.0000 - val_loss: 0.5548 - val_accuracy: 0.9162
# Epoch 61/80
# 573/573 - 251s - loss: 1.2998e-04 - accuracy: 0.9999 - val_loss: 0.5550 - val_accuracy: 0.9151
# Epoch 62/80
# 573/573 - 253s - loss: 2.5863e-04 - accuracy: 0.9999 - val_loss: 0.5552 - val_accuracy: 0.9178
# Epoch 63/80
# 573/573 - 254s - loss: 1.6565e-04 - accuracy: 0.9999 - val_loss: 0.5610 - val_accuracy: 0.9157
# Epoch 64/80
# 573/573 - 254s - loss: 2.7726e-04 - accuracy: 0.9999 - val_loss: 0.5594 - val_accuracy: 0.9178
# Epoch 65/80
# 573/573 - 252s - loss: 2.3258e-04 - accuracy: 0.9999 - val_loss: 0.5541 - val_accuracy: 0.9167
# Epoch 66/80
# 573/573 - 252s - loss: 2.0375e-04 - accuracy: 0.9999 - val_loss: 0.5595 - val_accuracy: 0.9167
# Epoch 67/80
# 573/573 - 253s - loss: 4.1387e-04 - accuracy: 0.9998 - val_loss: 0.5553 - val_accuracy: 0.9172
# Epoch 68/80
# 573/573 - 253s - loss: 1.3626e-04 - accuracy: 1.0000 - val_loss: 0.5591 - val_accuracy: 0.9172
# Epoch 69/80
# 573/573 - 252s - loss: 5.5045e-04 - accuracy: 0.9998 - val_loss: 0.5532 - val_accuracy: 0.9167
# Epoch 70/80
# 573/573 - 251s - loss: 1.0075e-04 - accuracy: 0.9999 - val_loss: 0.5525 - val_accuracy: 0.9172
# Epoch 71/80
# 573/573 - 253s - loss: 3.0500e-04 - accuracy: 0.9999 - val_loss: 0.5601 - val_accuracy: 0.9162
# Epoch 72/80
# 573/573 - 251s - loss: 3.8155e-04 - accuracy: 0.9999 - val_loss: 0.5556 - val_accuracy: 0.9167
# Epoch 73/80
# 573/573 - 250s - loss: 8.5385e-05 - accuracy: 1.0000 - val_loss: 0.5596 - val_accuracy: 0.9178
# Epoch 74/80
# 573/573 - 250s - loss: 2.3313e-04 - accuracy: 0.9999 - val_loss: 0.5528 - val_accuracy: 0.9172
# Epoch 75/80
# 573/573 - 251s - loss: 1.4267e-04 - accuracy: 1.0000 - val_loss: 0.5575 - val_accuracy: 0.9178
# Epoch 76/80
# 573/573 - 251s - loss: 3.4040e-04 - accuracy: 0.9999 - val_loss: 0.5579 - val_accuracy: 0.9167
# Train accuracy=1.00000, Validation accuracy=0.91828
# Epoch 1/5
# WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.1665s vs `on_train_batch_end` time: 0.2807s). Check your callbacks.
# 60/60 - 26s - loss: 0.5816 - accuracy: 0.9130
# Epoch 2/5
# 60/60 - 26s - loss: 0.6326 - accuracy: 0.9068
# Epoch 3/5
# 60/60 - 26s - loss: 0.5975 - accuracy: 0.9089
# Epoch 4/5
# 60/60 - 26s - loss: 0.6291 - accuracy: 0.9036
# Epoch 5/5
# 60/60 - 26s - loss: 0.6144 - accuracy: 0.9036
# EfficientNetB5_bicubic224_val_kmean  1
# Epoch 1/80
# WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.1662s vs `on_train_batch_end` time: 0.2590s). Check your callbacks.
# 573/573 - 256s - loss: 1.9677 - accuracy: 0.2751 - val_loss: 2.7850 - val_accuracy: 0.0838
# Epoch 2/80
# 573/573 - 254s - loss: 1.0671 - accuracy: 0.6352 - val_loss: 3.5446 - val_accuracy: 0.3625
# Epoch 3/80
# 573/573 - 253s - loss: 0.5187 - accuracy: 0.8385 - val_loss: 0.5376 - val_accuracy: 0.8397
# Epoch 4/80
# 573/573 - 251s - loss: 0.2807 - accuracy: 0.9103 - val_loss: 0.5934 - val_accuracy: 0.8355
# Epoch 5/80
# 573/573 - 252s - loss: 0.2018 - accuracy: 0.9340 - val_loss: 0.5478 - val_accuracy: 0.8591
# Epoch 6/80
# 573/573 - 252s - loss: 0.1375 - accuracy: 0.9543 - val_loss: 0.5780 - val_accuracy: 0.8554
# Epoch 7/80
# 573/573 - 252s - loss: 0.1132 - accuracy: 0.9625 - val_loss: 0.7052 - val_accuracy: 0.8345
# Epoch 8/80
# 573/573 - 253s - loss: 0.0995 - accuracy: 0.9679 - val_loss: 0.9218 - val_accuracy: 0.7952
# Epoch 9/80
# 573/573 - 252s - loss: 0.0926 - accuracy: 0.9687 - val_loss: 0.7341 - val_accuracy: 0.8497
# Epoch 10/80
# 573/573 - 252s - loss: 0.0673 - accuracy: 0.9789 - val_loss: 5.2346 - val_accuracy: 0.1896
# Epoch 11/80
# 573/573 - 252s - loss: 0.0700 - accuracy: 0.9779 - val_loss: 0.9150 - val_accuracy: 0.8392
# Epoch 12/80
# 573/573 - 253s - loss: 0.0689 - accuracy: 0.9790 - val_loss: 0.7933 - val_accuracy: 0.8559
# Epoch 13/80
# 573/573 - 252s - loss: 0.0522 - accuracy: 0.9819 - val_loss: 0.4552 - val_accuracy: 0.9068
# Epoch 14/80
# 573/573 - 252s - loss: 0.0509 - accuracy: 0.9842 - val_loss: 0.6110 - val_accuracy: 0.8701
# Epoch 15/80
# 573/573 - 252s - loss: 0.0557 - accuracy: 0.9821 - val_loss: 2.3428 - val_accuracy: 0.6406
# Epoch 16/80
# 573/573 - 252s - loss: 0.0431 - accuracy: 0.9866 - val_loss: 0.4484 - val_accuracy: 0.9052
# Epoch 17/80
# 573/573 - 252s - loss: 0.0453 - accuracy: 0.9868 - val_loss: 1.1424 - val_accuracy: 0.8009
# Epoch 18/80
# 573/573 - 252s - loss: 0.0388 - accuracy: 0.9878 - val_loss: 0.6694 - val_accuracy: 0.8790
# Epoch 19/80
# 573/573 - 251s - loss: 0.0354 - accuracy: 0.9892 - val_loss: 0.6766 - val_accuracy: 0.8664
# Epoch 20/80
# 573/573 - 252s - loss: 0.0344 - accuracy: 0.9902 - val_loss: 0.6545 - val_accuracy: 0.8659
# Epoch 21/80
# 573/573 - 252s - loss: 0.0379 - accuracy: 0.9879 - val_loss: 0.6338 - val_accuracy: 0.8706
# Epoch 22/80
# 573/573 - 253s - loss: 0.0358 - accuracy: 0.9890 - val_loss: 0.6019 - val_accuracy: 0.8827
# Epoch 23/80
# 573/573 - 253s - loss: 0.0359 - accuracy: 0.9895 - val_loss: 0.6073 - val_accuracy: 0.8921
# Epoch 24/80
# 573/573 - 252s - loss: 0.0261 - accuracy: 0.9923 - val_loss: 0.5509 - val_accuracy: 0.8947
# Epoch 25/80
# 573/573 - 255s - loss: 0.0330 - accuracy: 0.9901 - val_loss: 0.7059 - val_accuracy: 0.8491
# Epoch 26/80
# 573/573 - 253s - loss: 0.0257 - accuracy: 0.9924 - val_loss: 0.6319 - val_accuracy: 0.8963
# Epoch 27/80
# 573/573 - 254s - loss: 0.0288 - accuracy: 0.9911 - val_loss: 0.5634 - val_accuracy: 0.8973
# Epoch 28/80
# 573/573 - 251s - loss: 0.0217 - accuracy: 0.9937 - val_loss: 0.5098 - val_accuracy: 0.8900
# Epoch 29/80
# 573/573 - 251s - loss: 0.0176 - accuracy: 0.9936 - val_loss: 4.9249 - val_accuracy: 0.3541
# Epoch 30/80
# 573/573 - 252s - loss: 0.0252 - accuracy: 0.9926 - val_loss: 0.6524 - val_accuracy: 0.8711
# Epoch 31/80
# 573/573 - 252s - loss: 0.0159 - accuracy: 0.9950 - val_loss: 0.7244 - val_accuracy: 0.8748
# Epoch 32/80
# 573/573 - 249s - loss: 0.0250 - accuracy: 0.9923 - val_loss: 0.8108 - val_accuracy: 0.8806
# Epoch 33/80
# 573/573 - 250s - loss: 0.0275 - accuracy: 0.9916 - val_loss: 0.5799 - val_accuracy: 0.8989
# Train accuracy=0.99498, Validation accuracy=0.90676
# Epoch 1/5
# 60/60 - 26s - loss: 0.3164 - accuracy: 0.9130
# Epoch 2/5
# 60/60 - 26s - loss: 0.1046 - accuracy: 0.9707
# Epoch 3/5
# 60/60 - 26s - loss: 0.0341 - accuracy: 0.9895
# Epoch 4/5
# 60/60 - 26s - loss: 0.0293 - accuracy: 0.9906
# Epoch 5/5
# 60/60 - 26s - loss: 0.0105 - accuracy: 0.9969
# EfficientNetB5_bicubic224_val_kmean  2
# Epoch 1/80
# WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.1665s vs `on_train_batch_end` time: 0.2811s). Check your callbacks.
# 573/573 - 252s - loss: 1.6809 - accuracy: 0.3973 - val_loss: 6.5896 - val_accuracy: 0.0733
# Epoch 2/80
# 573/573 - 249s - loss: 0.6737 - accuracy: 0.7786 - val_loss: 4.5693 - val_accuracy: 0.2190
# Epoch 3/80
# 573/573 - 249s - loss: 0.4888 - accuracy: 0.8395 - val_loss: 0.5078 - val_accuracy: 0.8455
# Epoch 4/80
# 573/573 - 249s - loss: 0.2527 - accuracy: 0.9155 - val_loss: 0.5962 - val_accuracy: 0.8308
# Epoch 5/80
# 573/573 - 251s - loss: 0.1461 - accuracy: 0.9534 - val_loss: 0.5926 - val_accuracy: 0.8465
# Epoch 6/80
# 573/573 - 250s - loss: 0.1162 - accuracy: 0.9628 - val_loss: 0.6804 - val_accuracy: 0.8491
# Epoch 7/80
# 573/573 - 248s - loss: 0.1075 - accuracy: 0.9671 - val_loss: 0.5461 - val_accuracy: 0.8738
# Epoch 8/80
# 573/573 - 248s - loss: 0.0917 - accuracy: 0.9718 - val_loss: 1.0528 - val_accuracy: 0.7716
# Epoch 9/80
# 573/573 - 249s - loss: 0.0916 - accuracy: 0.9705 - val_loss: 1.5801 - val_accuracy: 0.6904
# Epoch 10/80
# 573/573 - 248s - loss: 0.0850 - accuracy: 0.9734 - val_loss: 0.5541 - val_accuracy: 0.8779
# Epoch 11/80
# 573/573 - 251s - loss: 0.0524 - accuracy: 0.9834 - val_loss: 0.5222 - val_accuracy: 0.8863
# Epoch 12/80
# 573/573 - 248s - loss: 0.0606 - accuracy: 0.9809 - val_loss: 0.6261 - val_accuracy: 0.8612
# Epoch 13/80
# 573/573 - 249s - loss: 0.0534 - accuracy: 0.9850 - val_loss: 0.8604 - val_accuracy: 0.8486
# Epoch 14/80
# 573/573 - 245s - loss: 0.0530 - accuracy: 0.9827 - val_loss: 0.8253 - val_accuracy: 0.8580
# Epoch 15/80
# 573/573 - 249s - loss: 0.0583 - accuracy: 0.9809 - val_loss: 0.8453 - val_accuracy: 0.8109
# Epoch 16/80
# 573/573 - 249s - loss: 0.0319 - accuracy: 0.9901 - val_loss: 0.7870 - val_accuracy: 0.8324
# Epoch 17/80
# 573/573 - 248s - loss: 0.0510 - accuracy: 0.9838 - val_loss: 0.8429 - val_accuracy: 0.8324
# Epoch 18/80
# 573/573 - 250s - loss: 0.0311 - accuracy: 0.9909 - val_loss: 0.6089 - val_accuracy: 0.8942
# Epoch 19/80
# 573/573 - 248s - loss: 0.0258 - accuracy: 0.9918 - val_loss: 0.6629 - val_accuracy: 0.8675
# Epoch 20/80
# 573/573 - 250s - loss: 0.0478 - accuracy: 0.9850 - val_loss: 0.7776 - val_accuracy: 0.8554
# Epoch 21/80
# 573/573 - 249s - loss: 0.0310 - accuracy: 0.9901 - val_loss: 0.6909 - val_accuracy: 0.8743
# Epoch 22/80
# 573/573 - 252s - loss: 0.0312 - accuracy: 0.9908 - val_loss: 0.6280 - val_accuracy: 0.8958
# Epoch 23/80
# 573/573 - 250s - loss: 0.0242 - accuracy: 0.9932 - val_loss: 0.5650 - val_accuracy: 0.8968
# Epoch 24/80
# 573/573 - 248s - loss: 0.0274 - accuracy: 0.9916 - val_loss: 0.7144 - val_accuracy: 0.8617
# Epoch 25/80
# 573/573 - 250s - loss: 0.0328 - accuracy: 0.9906 - val_loss: 0.4832 - val_accuracy: 0.8958
# Epoch 26/80
# 573/573 - 248s - loss: 0.0256 - accuracy: 0.9925 - val_loss: 0.7054 - val_accuracy: 0.8669
# Epoch 27/80
# 573/573 - 249s - loss: 0.0254 - accuracy: 0.9924 - val_loss: 0.9047 - val_accuracy: 0.8654
# Epoch 28/80
# 573/573 - 249s - loss: 0.0259 - accuracy: 0.9929 - val_loss: 2.2274 - val_accuracy: 0.5705
# Epoch 29/80
# 573/573 - 249s - loss: 0.0102 - accuracy: 0.9974 - val_loss: 0.5814 - val_accuracy: 0.9109
# Epoch 30/80
# 573/573 - 249s - loss: 0.0029 - accuracy: 0.9990 - val_loss: 0.5763 - val_accuracy: 0.9094
# Epoch 31/80
# 573/573 - 250s - loss: 0.0015 - accuracy: 0.9997 - val_loss: 0.5867 - val_accuracy: 0.9120
# Epoch 32/80
# 573/573 - 248s - loss: 0.0013 - accuracy: 0.9996 - val_loss: 0.5975 - val_accuracy: 0.9136
# Epoch 33/80
# 573/573 - 249s - loss: 0.0011 - accuracy: 0.9998 - val_loss: 0.6041 - val_accuracy: 0.9125
# Epoch 34/80
# 573/573 - 249s - loss: 8.5371e-04 - accuracy: 0.9998 - val_loss: 0.5690 - val_accuracy: 0.9162
# Epoch 35/80
# 573/573 - 249s - loss: 5.6888e-04 - accuracy: 0.9999 - val_loss: 0.6003 - val_accuracy: 0.9146
# Epoch 36/80
# 573/573 - 248s - loss: 4.6984e-04 - accuracy: 0.9999 - val_loss: 0.6859 - val_accuracy: 0.9115
# Epoch 37/80
# 573/573 - 249s - loss: 0.0012 - accuracy: 0.9997 - val_loss: 0.6996 - val_accuracy: 0.9115
# Epoch 38/80
# 573/573 - 249s - loss: 0.0013 - accuracy: 0.9995 - val_loss: 0.6113 - val_accuracy: 0.9094
# Epoch 39/80
# 573/573 - 249s - loss: 9.7470e-04 - accuracy: 0.9998 - val_loss: 0.6627 - val_accuracy: 0.9130
# Epoch 40/80
# 573/573 - 249s - loss: 5.0120e-04 - accuracy: 0.9999 - val_loss: 0.6945 - val_accuracy: 0.9099
# Epoch 41/80
# 573/573 - 248s - loss: 2.5156e-04 - accuracy: 1.0000 - val_loss: 0.7056 - val_accuracy: 0.9089
# Epoch 42/80
# 573/573 - 249s - loss: 3.9079e-04 - accuracy: 0.9999 - val_loss: 0.6963 - val_accuracy: 0.9104
# Epoch 43/80
# 573/573 - 250s - loss: 3.3829e-04 - accuracy: 0.9999 - val_loss: 0.6888 - val_accuracy: 0.9115
# Epoch 44/80
# 573/573 - 249s - loss: 3.9905e-04 - accuracy: 0.9999 - val_loss: 0.6918 - val_accuracy: 0.9109
# Epoch 45/80
# 573/573 - 249s - loss: 2.3568e-04 - accuracy: 0.9999 - val_loss: 0.6914 - val_accuracy: 0.9094
# Epoch 46/80
# 573/573 - 250s - loss: 1.8713e-04 - accuracy: 1.0000 - val_loss: 0.6927 - val_accuracy: 0.9109
# Epoch 47/80
# 573/573 - 249s - loss: 5.2002e-04 - accuracy: 0.9998 - val_loss: 0.6930 - val_accuracy: 0.9104
# Epoch 48/80
# 573/573 - 248s - loss: 2.5464e-04 - accuracy: 0.9999 - val_loss: 0.6900 - val_accuracy: 0.9109
# Epoch 49/80
# 573/573 - 250s - loss: 2.6547e-04 - accuracy: 0.9999 - val_loss: 0.6902 - val_accuracy: 0.9104
# Epoch 50/80
# 573/573 - 248s - loss: 2.5892e-04 - accuracy: 0.9999 - val_loss: 0.6940 - val_accuracy: 0.9104
# Epoch 51/80
# 573/573 - 251s - loss: 1.6039e-04 - accuracy: 0.9999 - val_loss: 0.6930 - val_accuracy: 0.9115
# Epoch 52/80
# 573/573 - 250s - loss: 2.4521e-04 - accuracy: 0.9999 - val_loss: 0.6911 - val_accuracy: 0.9094
# Epoch 53/80
# 573/573 - 249s - loss: 2.2085e-04 - accuracy: 1.0000 - val_loss: 0.6917 - val_accuracy: 0.9109
# Epoch 54/80
# 573/573 - 249s - loss: 2.1137e-04 - accuracy: 0.9999 - val_loss: 0.6923 - val_accuracy: 0.9099
# Train accuracy=1.00000, Validation accuracy=0.91619
# Epoch 1/5
# WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.1665s vs `on_train_batch_end` time: 0.2593s). Check your callbacks.
# 60/60 - 26s - loss: 0.6252 - accuracy: 0.9047
# Epoch 2/5
# 60/60 - 26s - loss: 0.6131 - accuracy: 0.9010
# Epoch 3/5
# 60/60 - 26s - loss: 0.6476 - accuracy: 0.9041
# Epoch 4/5
# 60/60 - 26s - loss: 0.6254 - accuracy: 0.9031
# Epoch 5/5
# 60/60 - 26s - loss: 0.6407 - accuracy: 0.9010
# EfficientNetB5_bicubic224_val_kmean  3
# Epoch 1/80
# 573/573 - 259s - loss: 1.9730 - accuracy: 0.2551 - val_loss: 6.8400 - val_accuracy: 0.0786
# Epoch 2/80
# 573/573 - 256s - loss: 0.9484 - accuracy: 0.6769 - val_loss: 0.8129 - val_accuracy: 0.7475
# Epoch 3/80
# 573/573 - 253s - loss: 0.4283 - accuracy: 0.8648 - val_loss: 0.6264 - val_accuracy: 0.8167
# Epoch 4/80
# 573/573 - 254s - loss: 0.2697 - accuracy: 0.9173 - val_loss: 0.6159 - val_accuracy: 0.8313
# Epoch 5/80
# 573/573 - 254s - loss: 0.1915 - accuracy: 0.9399 - val_loss: 0.5673 - val_accuracy: 0.8470
# Epoch 6/80
# 573/573 - 253s - loss: 0.1429 - accuracy: 0.9545 - val_loss: 0.8371 - val_accuracy: 0.8324
# Epoch 7/80
# 573/573 - 253s - loss: 0.1301 - accuracy: 0.9616 - val_loss: 0.7938 - val_accuracy: 0.8104
# Epoch 8/80
# 573/573 - 255s - loss: 0.1202 - accuracy: 0.9636 - val_loss: 0.5594 - val_accuracy: 0.8408
# Epoch 9/80
# 573/573 - 256s - loss: 0.0838 - accuracy: 0.9744 - val_loss: 0.7692 - val_accuracy: 0.8009
# Epoch 10/80
# 573/573 - 253s - loss: 0.0805 - accuracy: 0.9768 - val_loss: 0.6389 - val_accuracy: 0.8350
# Epoch 11/80
# 573/573 - 254s - loss: 0.0728 - accuracy: 0.9789 - val_loss: 1.0458 - val_accuracy: 0.7795
# Epoch 12/80
# 573/573 - 253s - loss: 0.0758 - accuracy: 0.9772 - val_loss: 0.6611 - val_accuracy: 0.8654
# Epoch 13/80
# 573/573 - 252s - loss: 0.0536 - accuracy: 0.9837 - val_loss: 0.9076 - val_accuracy: 0.7962
# Epoch 14/80
# 573/573 - 253s - loss: 0.0544 - accuracy: 0.9840 - val_loss: 1.3339 - val_accuracy: 0.7569
# Epoch 15/80
# 573/573 - 252s - loss: 0.0654 - accuracy: 0.9814 - val_loss: 0.4944 - val_accuracy: 0.8869
# Epoch 16/80
# 573/573 - 253s - loss: 0.0417 - accuracy: 0.9873 - val_loss: 0.6141 - val_accuracy: 0.8711
# Epoch 17/80
# 573/573 - 253s - loss: 0.0439 - accuracy: 0.9875 - val_loss: 0.5507 - val_accuracy: 0.8696
# Epoch 18/80
# 573/573 - 253s - loss: 0.0468 - accuracy: 0.9860 - val_loss: 0.6594 - val_accuracy: 0.8486
# Epoch 19/80
# 573/573 - 253s - loss: 0.0372 - accuracy: 0.9890 - val_loss: 3.2191 - val_accuracy: 0.5579
# Epoch 20/80

# %%
def train_test_model(i):
    tf.keras.backend.clear_session()
    '''
    I shuffled dataset every time since i wanted to get enoughly distributed models.
    '''
    train_pixel, train_label, train_answer, valid_pixel, valid_label, valid_answer = prepare_datasets(train_raw)
    callbacks1 = [tf.keras.callbacks.EarlyStopping(monitor = 'val_accuracy', patience = 20, restore_best_weights = True), ReduceLROnPlateau(monitor = 'loss', patience = 5)]
    ModelName = 'EfficientNetB5_bicubic224_val_kmean'
    print(ModelName + '  ' + str(i))
    with tf.device('/device:GPU:0'):
        cnn = tf.keras.applications.EfficientNetB5(include_top=False, weights=None, input_tensor=None, input_shape=(N_dim,N_dim,1),pooling=None)
        cnn_mid = layers.GlobalAveragePooling2D()(cnn.output)
        cnn_out = layers.Dense(256, activation = 'relu')(cnn_mid)

        dense_input = layers.Input(shape=(52,))
        dense_mid = layers.Dense(104, activation = 'relu')(dense_input)
        dense_output = layers.Dense(104, activation = 'relu')(dense_mid)
        dense_model = tf.keras.Model(inputs=dense_input, outputs=dense_output)

        concatenated = layers.concatenate([cnn_out, dense_model.output])
        concatenated = layers.Dense(32, activation='relu')(concatenated)
        concat_output = layers.Dense(10, activation='softmax')(concatenated)
        concat_model = tf.keras.models.Model([cnn.input, dense_input], concat_output)
        concat_model.compile(optimizer="adam", loss="categorical_crossentropy", metrics=["accuracy"])
        history = concat_model.fit([train_pixel, train_label], train_answer, validation_data=([valid_pixel, valid_label], valid_answer), epochs=epochs_num, verbose=verbose, callbacks = callbacks1)
    print(
        f"Train accuracy={max(history.history['accuracy']):.5f}, " +
        f"Validation accuracy={max(history.history['val_accuracy']):.5f}"
    )
    with tf.device('/device:GPU:0'):
        concat_model.fit([valid_pixel, valid_label], valid_answer, epochs=5, verbose=verbose)
    concat_model.save(path + ModelName + '_' + str(i) + '.h5')

for i in range(3,5):
    train_test_model(i)
# Out:
# EfficientNetB5_bicubic224_val_kmean  3
# Epoch 1/80
# 573/573 - 257s - loss: 1.6888 - accuracy: 0.3994 - val_loss: 6.0406 - val_accuracy: 0.0686
# Epoch 2/80
# 573/573 - 254s - loss: 0.7882 - accuracy: 0.7467 - val_loss: 0.4887 - val_accuracy: 0.8497
# Epoch 3/80
# 573/573 - 253s - loss: 0.3312 - accuracy: 0.8925 - val_loss: 0.5430 - val_accuracy: 0.8423
# Epoch 4/80
# 573/573 - 253s - loss: 0.2228 - accuracy: 0.9275 - val_loss: 0.7127 - val_accuracy: 0.7905
# Epoch 5/80
# 573/573 - 253s - loss: 0.1549 - accuracy: 0.9508 - val_loss: 0.4687 - val_accuracy: 0.8649
# Epoch 6/80
# 573/573 - 253s - loss: 0.1347 - accuracy: 0.9580 - val_loss: 0.4665 - val_accuracy: 0.8675
# Epoch 7/80
# 573/573 - 252s - loss: 0.1099 - accuracy: 0.9638 - val_loss: 0.4641 - val_accuracy: 0.8753
# Epoch 8/80
# 573/573 - 253s - loss: 0.0867 - accuracy: 0.9712 - val_loss: 0.5696 - val_accuracy: 0.8795
# Epoch 9/80
# 573/573 - 253s - loss: 0.0888 - accuracy: 0.9706 - val_loss: 0.5759 - val_accuracy: 0.8743
# Epoch 10/80
# 573/573 - 253s - loss: 0.0704 - accuracy: 0.9771 - val_loss: 0.6171 - val_accuracy: 0.8680
# Epoch 11/80
# 573/573 - 253s - loss: 0.0615 - accuracy: 0.9808 - val_loss: 0.4728 - val_accuracy: 0.8858
# Epoch 12/80
# 573/573 - 253s - loss: 0.0650 - accuracy: 0.9788 - val_loss: 0.5749 - val_accuracy: 0.8863
# Epoch 13/80
# 573/573 - 251s - loss: 0.0583 - accuracy: 0.9816 - val_loss: 0.5948 - val_accuracy: 0.8743
# Epoch 14/80
# 573/573 - 251s - loss: 0.0538 - accuracy: 0.9836 - val_loss: 0.6657 - val_accuracy: 0.8727
# Epoch 15/80
# 573/573 - 253s - loss: 0.0443 - accuracy: 0.9861 - val_loss: 0.6071 - val_accuracy: 0.8795
# Epoch 16/80
# 573/573 - 252s - loss: 0.0338 - accuracy: 0.9903 - val_loss: 0.6813 - val_accuracy: 0.8800
# Epoch 17/80
# 573/573 - 252s - loss: 0.0485 - accuracy: 0.9850 - val_loss: 1.0791 - val_accuracy: 0.7632
# Epoch 18/80
# 573/573 - 253s - loss: 0.0412 - accuracy: 0.9874 - val_loss: 0.7237 - val_accuracy: 0.8701
# Epoch 19/80
# 573/573 - 254s - loss: 0.0438 - accuracy: 0.9862 - val_loss: 0.4669 - val_accuracy: 0.9109
# Epoch 20/80
# 573/573 - 253s - loss: 0.0308 - accuracy: 0.9899 - val_loss: 0.6990 - val_accuracy: 0.8795
# Epoch 21/80
# 573/573 - 254s - loss: 0.0326 - accuracy: 0.9907 - val_loss: 0.4674 - val_accuracy: 0.8952
# Epoch 22/80
# 573/573 - 253s - loss: 0.0290 - accuracy: 0.9918 - val_loss: 0.5980 - val_accuracy: 0.8690
# Epoch 23/80
# 573/573 - 253s - loss: 0.0342 - accuracy: 0.9897 - val_loss: 0.5875 - val_accuracy: 0.8690
# Epoch 24/80
# 573/573 - 252s - loss: 0.0285 - accuracy: 0.9915 - val_loss: 0.4349 - val_accuracy: 0.9057
# Epoch 25/80
# 573/573 - 253s - loss: 0.0274 - accuracy: 0.9927 - val_loss: 2.2887 - val_accuracy: 0.6281
# Epoch 26/80
# 573/573 - 253s - loss: 0.0246 - accuracy: 0.9937 - val_loss: 0.5198 - val_accuracy: 0.8816
# Epoch 27/80
# 573/573 - 253s - loss: 0.0273 - accuracy: 0.9908 - val_loss: 0.4388 - val_accuracy: 0.9062
# Epoch 28/80
# 573/573 - 252s - loss: 0.0271 - accuracy: 0.9917 - val_loss: 0.6661 - val_accuracy: 0.8696
# Epoch 29/80
# 573/573 - 251s - loss: 0.0174 - accuracy: 0.9942 - val_loss: 0.6082 - val_accuracy: 0.8753
# Epoch 30/80
# 573/573 - 253s - loss: 0.0209 - accuracy: 0.9940 - val_loss: 0.5730 - val_accuracy: 0.9026
# Epoch 31/80
# 573/573 - 254s - loss: 0.0283 - accuracy: 0.9914 - val_loss: 0.4881 - val_accuracy: 0.9005
# Epoch 32/80
# 573/573 - 253s - loss: 0.0180 - accuracy: 0.9948 - val_loss: 0.6062 - val_accuracy: 0.8732
# Epoch 33/80
# 573/573 - 252s - loss: 0.0186 - accuracy: 0.9939 - val_loss: 0.5471 - val_accuracy: 0.9172
# Epoch 34/80
# 573/573 - 253s - loss: 0.0151 - accuracy: 0.9958 - val_loss: 0.6422 - val_accuracy: 0.9041
# Epoch 35/80
# 573/573 - 251s - loss: 0.0235 - accuracy: 0.9933 - val_loss: 0.4950 - val_accuracy: 0.9052
# Epoch 36/80
# 573/573 - 253s - loss: 0.0196 - accuracy: 0.9946 - val_loss: 0.6253 - val_accuracy: 0.8869
# Epoch 37/80
# 573/573 - 252s - loss: 0.0141 - accuracy: 0.9959 - val_loss: 0.5479 - val_accuracy: 0.9047
# Epoch 38/80
# 573/573 - 253s - loss: 0.0170 - accuracy: 0.9943 - val_loss: 0.4669 - val_accuracy: 0.9261
# Epoch 39/80
# 573/573 - 253s - loss: 0.0143 - accuracy: 0.9957 - val_loss: 0.6241 - val_accuracy: 0.9005
# Epoch 40/80
# 573/573 - 253s - loss: 0.0169 - accuracy: 0.9948 - val_loss: 0.6192 - val_accuracy: 0.9125
# Epoch 41/80
# 573/573 - 252s - loss: 0.0125 - accuracy: 0.9957 - val_loss: 0.6714 - val_accuracy: 0.8931
# Epoch 42/80
# 573/573 - 252s - loss: 0.0242 - accuracy: 0.9927 - val_loss: 0.8048 - val_accuracy: 0.8559
# Epoch 43/80
# 573/573 - 252s - loss: 0.0169 - accuracy: 0.9945 - val_loss: 0.5913 - val_accuracy: 0.9094
# Epoch 44/80
# 573/573 - 252s - loss: 0.0128 - accuracy: 0.9964 - val_loss: 0.6737 - val_accuracy: 0.8806
# Epoch 45/80
# 573/573 - 252s - loss: 0.0167 - accuracy: 0.9956 - val_loss: 0.6266 - val_accuracy: 0.8968
# Epoch 46/80
# 573/573 - 253s - loss: 0.0091 - accuracy: 0.9979 - val_loss: 0.5884 - val_accuracy: 0.9146
# Epoch 47/80
# 573/573 - 253s - loss: 0.0178 - accuracy: 0.9953 - val_loss: 0.6574 - val_accuracy: 0.8968
# Epoch 48/80
# 573/573 - 252s - loss: 0.0187 - accuracy: 0.9939 - val_loss: 0.5779 - val_accuracy: 0.8989
# Epoch 49/80
# 573/573 - 253s - loss: 0.0090 - accuracy: 0.9972 - val_loss: 0.7574 - val_accuracy: 0.8884
# Epoch 50/80
# 573/573 - 252s - loss: 0.0246 - accuracy: 0.9935 - val_loss: 0.5172 - val_accuracy: 0.9104
# Epoch 51/80
# 573/573 - 251s - loss: 0.0087 - accuracy: 0.9974 - val_loss: 0.7027 - val_accuracy: 0.8999
# Epoch 52/80
# 573/573 - 253s - loss: 0.0163 - accuracy: 0.9957 - val_loss: 0.5501 - val_accuracy: 0.9015
# Epoch 53/80
# 573/573 - 252s - loss: 0.0098 - accuracy: 0.9975 - val_loss: 0.6900 - val_accuracy: 0.8963
# Epoch 54/80
# 573/573 - 252s - loss: 0.0156 - accuracy: 0.9953 - val_loss: 0.6133 - val_accuracy: 0.8947
# Epoch 55/80
# 573/573 - 252s - loss: 0.0129 - accuracy: 0.9963 - val_loss: 0.5318 - val_accuracy: 0.9047
# Epoch 56/80
# 573/573 - 252s - loss: 0.0077 - accuracy: 0.9978 - val_loss: 0.6498 - val_accuracy: 0.8910
# Epoch 57/80
# 573/573 - 253s - loss: 0.0062 - accuracy: 0.9986 - val_loss: 0.8089 - val_accuracy: 0.8659
# Epoch 58/80
# 573/573 - 253s - loss: 0.0213 - accuracy: 0.9942 - val_loss: 0.7250 - val_accuracy: 0.9052
# Train accuracy=0.99863, Validation accuracy=0.92614
# Epoch 1/5
# WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.1666s vs `on_train_batch_end` time: 0.2810s). Check your callbacks.
# 60/60 - 26s - loss: 0.2611 - accuracy: 0.9282
# Epoch 2/5
# 60/60 - 26s - loss: 0.0314 - accuracy: 0.9900
# Epoch 3/5
# 60/60 - 26s - loss: 0.0076 - accuracy: 0.9990
# Epoch 4/5
# 60/60 - 26s - loss: 0.0051 - accuracy: 0.9990
# Epoch 5/5
# 60/60 - 26s - loss: 0.0021 - accuracy: 0.9995
# EfficientNetB5_bicubic224_val_kmean  4
# Epoch 1/80
# WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.1673s vs `on_train_batch_end` time: 0.2572s). Check your callbacks.
# 573/573 - 254s - loss: 2.3050 - accuracy: 0.1095 - val_loss: 2.3032 - val_accuracy: 0.1126
# Epoch 2/80
# 573/573 - 252s - loss: 2.3001 - accuracy: 0.1139 - val_loss: 2.3043 - val_accuracy: 0.1126
# Epoch 3/80
# 573/573 - 251s - loss: 2.3001 - accuracy: 0.1138 - val_loss: 2.3047 - val_accuracy: 0.1126
# Epoch 4/80
# 573/573 - 251s - loss: 2.3000 - accuracy: 0.1130 - val_loss: 2.3043 - val_accuracy: 0.1126
# Epoch 5/80
# 573/573 - 251s - loss: 2.3000 - accuracy: 0.1140 - val_loss: 2.3045 - val_accuracy: 0.1126
# Epoch 6/80
# 573/573 - 250s - loss: 2.3016 - accuracy: 0.1135 - val_loss: 2.3046 - val_accuracy: 0.1126
# Epoch 7/80
# 573/573 - 250s - loss: 2.2999 - accuracy: 0.1140 - val_loss: 2.3048 - val_accuracy: 0.1126
# Epoch 8/80
# 573/573 - 251s - loss: 2.2999 - accuracy: 0.1140 - val_loss: 2.3043 - val_accuracy: 0.1126
# Epoch 9/80
# 573/573 - 250s - loss: 2.2999 - accuracy: 0.1140 - val_loss: 2.3047 - val_accuracy: 0.1126
# Epoch 10/80
# 573/573 - 251s - loss: 2.2998 - accuracy: 0.1140 - val_loss: 2.3047 - val_accuracy: 0.1126
# Epoch 11/80
# 573/573 - 252s - loss: 2.2998 - accuracy: 0.1140 - val_loss: 2.3047 - val_accuracy: 0.1126
# Epoch 12/80
# 573/573 - 251s - loss: 2.2998 - accuracy: 0.1140 - val_loss: 2.3047 - val_accuracy: 0.1126
# Epoch 13/80
# 573/573 - 251s - loss: 2.2998 - accuracy: 0.1140 - val_loss: 2.3047 - val_accuracy: 0.1126
# Epoch 14/80
# 573/573 - 251s - loss: 2.2998 - accuracy: 0.1140 - val_loss: 2.3047 - val_accuracy: 0.1126
# Epoch 15/80
# 573/573 - 251s - loss: 2.2998 - accuracy: 0.1140 - val_loss: 2.3047 - val_accuracy: 0.1126
# Epoch 16/80
# 573/573 - 251s - loss: 2.2997 - accuracy: 0.1140 - val_loss: 2.3047 - val_accuracy: 0.1126
# Epoch 17/80
# 573/573 - 251s - loss: 2.2997 - accuracy: 0.1140 - val_loss: 2.3047 - val_accuracy: 0.1126
# Epoch 18/80
# 573/573 - 251s - loss: 2.2997 - accuracy: 0.1140 - val_loss: 2.3047 - val_accuracy: 0.1126
# Epoch 19/80
# 573/573 - 251s - loss: 2.2997 - accuracy: 0.1140 - val_loss: 2.3047 - val_accuracy: 0.1126
# Epoch 20/80
# 573/573 - 251s - loss: 2.2997 - accuracy: 0.1140 - val_loss: 2.3047 - val_accuracy: 0.1126
# Epoch 21/80
# 573/573 - 253s - loss: 2.2997 - accuracy: 0.1140 - val_loss: 2.3047 - val_accuracy: 0.1126
# Train accuracy=0.11395, Validation accuracy=0.11262
# Epoch 1/5
# WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.1674s vs `on_train_batch_end` time: 0.2817s). Check your callbacks.
# 60/60 - 26s - loss: 2.3031 - accuracy: 0.1126
# Epoch 2/5
# 60/60 - 26s - loss: 2.3032 - accuracy: 0.1126
# Epoch 3/5
# 60/60 - 26s - loss: 2.3032 - accuracy: 0.1126
# Epoch 4/5
# 60/60 - 26s - loss: 2.3031 - accuracy: 0.1126
# Epoch 5/5
# 60/60 - 26s - loss: 2.3032 - accuracy: 0.1126

# %%
def get_progressbar_str(progress):
    MAX_LEN = 30
    BAR_LEN = int(MAX_LEN * progress)
    return ('Progress:[' + '=' * BAR_LEN +
            ('>' if BAR_LEN < MAX_LEN else '') +
            ' ' * (MAX_LEN - BAR_LEN) +
            '] %.1f%%' % (progress * 100.))

class ComputerVision_Data_test():
    def __init__(self, pixel, label, batch_size):
        self.pixel = pixel
        self.label =  label
        self.batch_size = batch_size
        self.length = math.ceil(len(label) // batch_size)

    def __getitem__(self, idx):
        i = idx * self.batch_size
        if i + self.batch_size > len(self.label):
            pixel = self.pixel[i:]
            label = self.label[i:]
        else:
            pixel = self.pixel[i:i+self.batch_size]
            label = self.label[i:i+self.batch_size]
        with tf.device('/device:GPU:0'):
            pixel = resize(pixel, [224,224], method=tf.image.ResizeMethod.BICUBIC).numpy()
            pixel = pixel / 255.0

        return [pixel, label]

    def __len__(self):
        return self.length


test_dataset = ComputerVision_Data_test(test_pixel, test_label, batch_size = 1000)

batch_idxs = [i for i in range(0, len(test_dataset))]
ModelNames = ['InceptionResnetV2_bicubic224_val_kmean_' + str(i) for i in range(4)] + ['EfficientNetB5_bicubic224_val_kmean_' + str(i) for i in range(4)]
batch_size = test_dataset.batch_size
submission = pd.read_csv(path_submission)
submission_temp = pd.DataFrame(columns = list(range(10)),index = list(range(len(submission)))).fillna(0)
inc = 0
L = len(batch_idxs) * len(ModelNames)
for ModelName in ModelNames:
    tf.keras.backend.clear_session()
    model = tf.keras.models.load_model(path+ModelName+'.h5')
    for batch_idx in batch_idxs:
        target = test_dataset[batch_idx]
        real_idxs = [i for i in range(batch_size * batch_idx, batch_size * batch_idx + len(target[0])) ]
        with tf.device('/device:GPU:0'):
            predicted = model.predict(target)
        for idx_temp, real in enumerate(real_idxs):
            submission_temp.iloc[real,:] += predicted[idx_temp]
        inc += 1
        sys.stderr.write('\r\033[K' + get_progressbar_str(inc/L))
        sys.stderr.flush()
sys.stderr.write('\n')
sys.stderr.flush()
submission.iloc[:,1] = submission_temp.apply(np.argmax,axis=1).apply(int).values
submission.to_csv(path+'submission_ensemble_'+str(len(ModelNames))+'.csv',index = False)
print('Done!')
# Out:
# Progress:[==============================] 100.0%
# Done!

# %%
def get_progressbar_str(progress):
    MAX_LEN = 30
    BAR_LEN = int(MAX_LEN * progress)
    return ('Progress:[' + '=' * BAR_LEN +
            ('>' if BAR_LEN < MAX_LEN else '') +
            ' ' * (MAX_LEN - BAR_LEN) +
            '] %.1f%%' % (progress * 100.))

class ComputerVision_Data_test():
    def __init__(self, pixel, label, batch_size):
        self.pixel = pixel
        self.label =  label
        self.batch_size = batch_size
        self.length = math.ceil(len(label) // batch_size)

    def __getitem__(self, idx):
        i = idx * self.batch_size
        if i + self.batch_size > len(self.label):
            pixel = self.pixel[i:]
            label = self.label[i:]
        else:
            pixel = self.pixel[i:i+self.batch_size]
            label = self.label[i:i+self.batch_size]
        with tf.device('/device:GPU:0'):
            pixel = resize(pixel, [224,224], method=tf.image.ResizeMethod.BICUBIC).numpy()
            pixel = pixel / 255.0

        return [pixel, label]

    def __len__(self):
        return self.length


test_dataset = ComputerVision_Data_test(test_pixel, test_label, batch_size = 1000)

batch_idxs = [i for i in range(0, len(test_dataset))]
ModelNames = ['InceptionResnetV2_bicubic224_val_kmean_' + str(i) for i in [2]] + ['EfficientNetB5_bicubic224_val_kmean_' + str(i) for i in [3]]
batch_size = test_dataset.batch_size
submission = pd.read_csv(path_submission)
submission_temp = pd.DataFrame(columns = list(range(10)),index = list(range(len(submission)))).fillna(0)
inc = 0
L = len(batch_idxs) * len(ModelNames)
for ModelName in ModelNames:
    tf.keras.backend.clear_session()
    model = tf.keras.models.load_model(path+ModelName+'.h5')
    for batch_idx in batch_idxs:
        target = test_dataset[batch_idx]
        real_idxs = [i for i in range(batch_size * batch_idx, batch_size * batch_idx + len(target[0])) ]
        with tf.device('/device:GPU:0'):
            predicted = model.predict(target)
        for idx_temp, real in enumerate(real_idxs):
            submission_temp.iloc[real,:] += predicted[idx_temp]
        inc += 1
        sys.stderr.write('\r\033[K' + get_progressbar_str(inc/L))
        sys.stderr.flush()
sys.stderr.write('\n')
sys.stderr.flush()
submission.iloc[:,1] = submission_temp.apply(np.argmax,axis=1).apply(int).values
submission.to_csv(path+'submission_ensemble_'+str(len(ModelNames))+'.csv',index = False)
print('Done!')
# Out:
# Progress:[==============================] 100.0%
# Done!
