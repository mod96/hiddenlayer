# %%
############################################description############################################
# 문제가 OX, 혹은 4개 보기 중 하나 정답인 객관식인 경우 사용 가능합니다.
# LaTeX 문서 작성 시 띄워쓰기, tab, 줄나눔 등 자유롭게 사용 가능합니다. 코드가 최종적으로 알아서 잡아줍니다.
# 단, 각 형식에 대해 다음은 지켜져야 합니다. (대부분의 b00 파일에 나오는 형식)
# ox: \question, \question[??] 으로 주어지며, 새끼문제가 있으면 \begin{part}~\part~\end{part} 의 꼴을 띄어야 합니다.
#  ox문제의 정답은 \textbf{A:} 뒤에 나와야 합니다.
# 4지선다: \question 으로 주어지며, 새끼문제는 모두  \begin{part}~\part~\end{part} 의 꼴을 띄어야 합니다. (보기는 enumerate,item)
# \question 에 대한 새끼문제는 모두 ox 거나, 모두 4보기 객관식 이어야 합니다.
# 정답은 하나만 있어야 하며, 정답이 모두 기재되지 않은 파일은 오류를 불러옵니다.
# error 구문에서 'A[i]=='$':' 가 보인다면, LaTeX 코드 문제입니다. $ 에 대한 오류가 나야하는 구문이지만 LaTeX 의 어떤 이유로
#  잘못된 $ 를 그냥 스킵해버리면서 멀쩡한 것 처럼 보이는 경우가 있는데, 이건 코드로 못잡습니다. (노가다 ㅊㅊ!)
############################################description############################################
from copy import deepcopy
B=str(input());
B=B.replace('\\','Z')
############################################Z로 바꿔야 전환이 먹힘.
B=B.replace('[1ex]','')
B=B.replace('[2ex]','')
B=B.replace('[3ex]','')
B=B.replace('[4ex]','')
B=B.replace('[5ex]','')
B=B.replace('[6ex]','')
B=B.replace('[7ex]','')
B=B.replace('[8ex]','')
B=B.replace('[9ex]','')
B=B.replace('[10ex]','')
B=B.replace('[11ex]','')
B=B.replace('[12ex]','')
B=B.replace('[13ex]','')
B=B.replace('[14ex]','')
B=B.replace('[15ex]','')
B=B.replace('[16ex]','')
B=B.replace('[17ex]','')
B=B.replace('Z[','$')
B=B.replace('Z]','$')
B=B.replace('Zbegin{equation}','$')
B=B.replace('Zend{equation}','$')
B=B.replace('Zbegin{equation*}','$')
B=B.replace('Zend{equation*}','$')
B=B.replace('Zbegin{eqnarray*}','$')
B=B.replace('Zend{eqnarray*}','$')
B=B.replace('Zquestion[1]','Zquestion ')
B=B.replace('Zquestion[2]','Zquestion ')
B=B.replace('Zquestion[3]','Zquestion ')
B=B.replace('Zquestion[4]','Zquestion ')
B=B.replace('Zquestion[5]','Zquestion ')
B=B.replace('Zquestion[6]','Zquestion ')
B=B.replace('Zquestion[7]','Zquestion ')
B=B.replace('Zquestion[8]','Zquestion ')
B=B.replace('Zquestion[9]','Zquestion ')
B=B.replace('Zquestion[10]','Zquestion ')
B=B.replace('Zquestion[11]','Zquestion ')
B=B.replace('.','. ')
B=B.replace('  ',' ')
############################################
B=B.replace('Z','\\')
B=B.replace('\t','')
############################################문장에서 \\ 제거, 두번 띄어쓰기 제거, 수식에서 띄어쓰기 모두 삭제
A=list(B)
K=False
i=0
while i<len(A)-1:
    if A[i]=='$':
        K=not K
    elif A[i]=='\\' and A[i+1]=='\\' and K==False:
        del A[i]
        del A[i]
        i=i-1
    elif A[i]==' ' and A[i+1]==' ' and K==False:
        del A[i]
        i=i-1
    while K==True:
        i=i+1
        if A[i]=='$':
            K=not K
        elif A[i]==' ' and A[i+1]==' ':
            del A[i]
            i=i-1
        elif A[i]=='\t':
            del A[i]
            i=i-1
    i=i+1
i=0
while i<len(A)-1:
    if A[i]==' ' and A[i+1]==' ':
        del A[i]
        i=i-1
    i=i+1
########################################################################################
B = ''.join(A)
B=B.replace('\\','Z')
B=B.replace('Zpartial',' QWERTY ')
########################################################################################$Zbigcirc$ 뒤에 설명 제거
def trueEraser(x):
    P=deepcopy(x)
    ind1=[0]; ind2=[]
    for i in range(P.count('$Zbigcirc$')):
        ind1.append(P.find('$Zbigcirc$',ind1[i]+1))
        ind2.append(P.find('TFQT',ind1[i+1]))
    del ind1[0]
    if -1 in ind2:
        ind2.remove(-1)
        ind2.append(len(P))
    ind1.reverse()
    ind2.reverse()
    for i in range(len(ind1)):
        P=P[:ind1[i]+11]+P[ind2[i]:]    
    return P
########################################################################################$Ztimes$ 뒤에 설명 제거
def falseEraser(x):
    P=deepcopy(x)
    ind1=[0]; ind2=[]
    for i in range(P.count('$Ztimes$')):
        ind1.append(P.find('$Ztimes$',ind1[i]+1))
        ind2.append(P.find('TFQT',ind1[i+1]))
    del ind1[0]
    if -1 in ind2:
        ind2.remove(-1)
        ind2.append(len(P))
    ind1.reverse()
    ind2.reverse()
    for i in range(len(ind1)):
        P=P[:ind1[i]+9]+P[ind2[i]:]    
    return P
########################################################################################
def gtn1(x):
    Temp2=x[0:x.find('begin{parts}')-1]
    Temp3=x[x.find('begin{parts}')+12:]
    Temp=Temp3.replace('Zpart',' TFQT '+Temp2)
    return Temp
def gtn2(x):
    Temp2=x[0:x.find('begin{parts}')-1]
    Temp3=x[x.find('begin{parts}')+12:]
    Temp=Temp3.replace('Zpart',' MCQT '+Temp2)
    return Temp
def ftn(x):
    if x.find('$Ztimes$')>0 or x.find('$Zbigcirc$')>0:
        if x.find('begin{parts}')>0:
            return trueEraser(falseEraser( gtn1(x)))
        else:
            return trueEraser(falseEraser(' TFQT '+x))
    else:
        if x.find('begin{parts}')>0:
            return gtn2(x)
        else:
            return ' MCQT '+x

def ktn(K,x):
    if x.find('TFQT')>0:
        return K+x
    else:
        y=deepcopy(x)
        for f in range(x.count('MCQT')):
            Temp1=''
            Temp2=''
        
            ind3=[0]
            for h in range(y.count('Zend{enumerate}')):
                ind3.append(y.find('Zend{enumerate}',ind3[h]+1))
            del ind3[0]
        
            ind4=[0]
            for h in range(y.count('MCQT')):
                ind4.append(y.find('MCQT',ind4[h]+1))
            del ind4[0]
            ind4.append(len(y))

            if y.count('MCQT')>1.5:
                for g in range(y.find('Zend{enumerate}')+15,y.find('Zend{enumerate}')+20):
                    Temp2=Temp2+y[g]
            else:
                Temp2=y[y.find('Zend{enumerate}')+15:y.find('Zend{enumerate}')+20]
        
            if y.count('MCQT')>1.5:
                for g in range(y.find('Zbegin{enumerate}')+17,ind4[f+1]-1):
                    Temp1=Temp1+y[g]
            else:
                Temp1=y[y.find('Zbegin{enumerate}')+17:]
                
            ind5=[0];
            for h in range(4):
                ind5.append(Temp1.find('Zitem',ind5[h]+1))
            del ind5[0] 
            
            if Temp2.find('(1)')>0 or Temp2.find('(1) ')>0:
                Temp1=Temp1[:ind5[1]]+' AAAAAAAAAA '+Temp1[ind5[1]+5:]
                ind5.append(Temp1.find('Zend{enumerate}'))
                Temp1=Temp1[:ind5[4]]+' BBBBBBBBBB '+Temp1[ind5[4]:]
            elif Temp2.find('(2)')>0 or Temp2.find('(2) ')>0:
                Temp1=Temp1[:ind5[2]]+' AAAAAAAAAA '+Temp1[ind5[2]+5:]
                ind5.append(Temp1.find('Zend{enumerate}'))
                Temp1=Temp1[:ind5[4]]+' BBBBBBBBBB '+Temp1[ind5[4]:]
            elif Temp2.find('(3)')>0 or Temp2.find('(3) ')>0:
                Temp1=Temp1[:ind5[3]]+' AAAAAAAAAA '+Temp1[ind5[3]+5:]
                ind5.append(Temp1.find('Zend{enumerate}'))
                Temp1=Temp1[:ind5[4]]+' BBBBBBBBBB '+Temp1[ind5[4]:]
            elif Temp2.find('(4)')>0 or Temp2.find('(4) ')>0:
                ind5.append(Temp1.find('Zend{enumerate}'))
                Temp1=Temp1[:ind5[4]]+' AAAAAAAAAA '+Temp1[ind5[4]:]
            else:
                Temp1=Temp1+' XXXXXXXXXXXXXXXXXXXXXX '

        
            Temp1=Temp1[:Temp1.find('Zend{enumerate}')]
            Temp1=Temp1[:Temp1.find('Zitem')]+' DUMMY '+Temp1[Temp1.find('Zitem')+5:]
            Temp1=Temp1.replace('Zitem',' BBBBBBBBBB ')
        
            ind4=[0]
            for h in range(y.count('MCQT')):
                ind4.append(y.find('MCQT',ind4[h]+1))
            del ind4[0]
            ind4.append(len(y))
        
            y=y[:y.find('Zbegin{enumerate}')-1]+' '+Temp1+' '+y[ind4[f+1]:]
    
        return K+y

############################################        
index=[0]
for i in range(B.count('Zquestion')):
    index.append(B.find('Zquestion',index[i]))
    B=B[:index[i+1]]+B[index[i+1]+1:]
del index[0]
index.append(len(B))

K=''
for i in range(len(index)-1):
    Temp=''
    for j in range(index[i]+9,index[i+1]-1):
        Temp=Temp+B[j]
    K=ktn(K,ftn(Temp))

K=K.replace(' QWERTY ','Zpartial ') 
########################################################################################begin{center} ~ end{center} 제거
for i in range(K.count('begin{center}')):
    ind1=K.find('Zbegin{center}')
    ind2=K.find('Zend{center}')
    K=K[:ind1]+K[ind2+12:]
########################################################################################간격 다시 제거
A=list(K)
K=False
i=0
while i<len(A)-1:
    if A[i]=='$':
        K=not K
    elif A[i]=='Z' and A[i+1]=='Z' and K==False:
        del A[i]
        del A[i]
        i=i-1
    elif A[i]==' ' and A[i+1]==' ' and K==False:
        del A[i]
        i=i-1
    i=i+1
i=0
while i<len(A)-1:
    if A[i]==' ' and A[i+1]==' ':
        del A[i]
        i=i-1
    i=i+1
########################################################################################
st=''.join(A)
st=st.replace('$','$$')
st=st.replace('&=&','=')
############################################
st=st.replace('\\','Z')
st=st.replace('Zmathscr{L}','L')
st=st.replace('Zmathscr{H}','H')
############################################
st=st.replace('Zbegin{parts}','')
st=st.replace('Zend{parts}','')
st=st.replace('Zend{parts','')
st=st.replace('Zbegin{enumerate}','')
st=st.replace('Zend{enumerate}','')
st=st.replace('Zend{enumerate','')
############################################
st=st.replace(' BBBBBBBBBB ','\tincorrect\t')
st=st.replace(' AAAAAAAAAA ','\tcorrect\t')
st=st.replace(' DUMMY ','\t')
st=st.replace('_','{}_')
st=st.replace('Zmathbbm','Zmathbb')
st=st.replace('MCQT','\nMC\t')
st=st.replace('MCQT ','\nMC\t')
st=st.replace('TFQT','\nMC\t')
st=st.replace('TFQT ','\nMC\t')
############################################
st=st.replace('Ztextbf{A:}','')
st=st.replace('$$Ztimes$$','\t'+'true'+'\t'+'incorrect'+'\t'+'false'+'\t'+'correct'+'\t'+'pass'+'\t'+'incorrect')
st=st.replace('$$Zbigcirc$$','\t'+'true'+'\t'+'correct'+'\t'+'false'+'\t'+'incorrect'+'\t'+'pass'+'\t'+'incorrect')
st=st.replace('. $$','.$$')
st=st.replace('.$$','$$.')
st=st.replace('.','. ')
st=st.replace('Zbbpsi','ZPsi')
st=st.replace('Zbbeta','Zeta')
st=st.replace('Z','\\')
########################################################################################
print('='*20,'Starts From Here','='*20)
print(st)
# Out:
# \question Consider doubly coupled harmonic oscillator which have both ends connected to the walls. The oscillator consists of two point masses of identical mass $m$ that are connected in series with springs. The positions of the left particle and the right one are $x_1$ and $x_2$, respectively. Note that the coordinate $x_1$ ($x_2$) is chosen so that the restoring force due to the left (right) spring on the left (right) massive particle becomes $0$ at $x_1=0$ ($x_2=0$). The spring constants of the springs at both ends are $k$ and that of the spring in-between is $\kappa$.  We define $  \mathbbm{x}=\begin{pmatrix}{x_{1}}\\{x_{2}}\end{pmatrix} $ and $ \mathbb{\Omega}^2 =  \begin{pmatrix} a&-b\\ -b&a \end{pmatrix}. $  \begin{parts} \part  The equation of motion for particle 1 is \\ $m\ddot{x}_{1} = -k x_{1}-\kappa(x_{1}-x_{2})$. \\ $\bigcirc$  \part  The equation of motion for particle 2 is \\ $m\ddot{x}_{2} = -k x_{2} -\kappa(x_{2}+x_{1})$. \\ $\times$ \\ $m\ddot{x}_{2} = -k x_{2} -\kappa(x_{2}-x_{1})$.   \part The coupled equations can be written in the form\\ $\ddot{\mathbbm{x}}+\mathbb{\Omega}^2 \mathbbm{x}=\mathbb{0}, $\\  where    $ a=\frac{k+2\kappa}{m},\quad b=\frac{\kappa}{m}. $ \\ $\times$ \\ $ a=\frac{k+\kappa}{m},\quad b=\frac{\kappa}{m}. $  \part $\mathbb{\Omega}^2$ is antisymmetric. \\ $\times$ \\ $\mathbb{\Omega}^2$ is real and symmetric.  \part The trial solution\\ $\mathbbm{x}=e^{-i\omega_k t}\bbpsi_k$ \\ can be used to solve this problem, where $\bbpsi_k$ is independent of time. \\ $\bigcirc$  \part The trial solution\\ $\mathbbm{x}=e^{-i\omega_k t}\bbpsi_k$ \\ is consistent with the separation of variables usually employed to solve the partial differential equation. \\ $\bigcirc$   \part $\mathbb{\Omega}^2$ is diagonalizable: There exists a similarity transformation matrix $\mathbb{\Lambda}$ such that\\ $\mathbb{\Omega}^2_D = \mathbb{\Lambda}\mathbb{\Omega}^2\mathbb{\Lambda}^\dagger= \begin{pmatrix} \omega_1^2&0\\ 0&\omega_2^2 \end{pmatrix}.$ \\ $\bigcirc$  \part  The unitrary transformation matrix $\mathbb{\Lambda}$ and its inverse are given by $ \mathbb{\Lambda}=\begin{pmatrix} 	\bbpsi_1& 	\bbpsi_2\end{pmatrix} 	$, \\ $\mathbb{\Lambda}^{-1}=\mathbb{\Lambda}^\dagger= \begin{pmatrix} 	\bbpsi_1^\dagger\\  	\bbpsi_2^\dagger\end{pmatrix}$. Here, these matrices diagonalize $\mathbb{\Omega}^2$ as \\	$\mathbb{\Omega}^2_D = \mathbb{\Lambda}\mathbb{\Omega}^2\mathbb{\Lambda}^\dagger= \begin{pmatrix} \omega_1^2&0\\ 0&\omega_2^2 \end{pmatrix}.$ \\ $\times$ \\ $ \mathbb{\Lambda}= 	\begin{pmatrix} 	\bbpsi_1^\dagger\\  	\bbpsi_2^\dagger\end{pmatrix}$, \\ $\mathbb{\Lambda}^{-1}=\mathbb{\Lambda}^\dagger= 	\begin{pmatrix} 	\bbpsi_1& 	\bbpsi_2\end{pmatrix}. $  \part  $\mathbb{\Omega}^2$ is anti-Hermitian. \\ $\times$ \\ $\mathbb{\Omega}^2$ is Hermitian.   \part  The secular equation for the eigenvalue problem is\\ $|\mathbb{\Omega}^2-\omega^2\mathbbm{1}| =1$. \\ $\times$ \\ $|\mathbb{\Omega}^2-\omega^2\mathbbm{1}| =0$.    \part    $ |\mathbb{\Omega}^2-\omega^2\mathbbm{1}|= (a-\omega^2-b)(a-\omega^2+b) .$ \\ $\bigcirc$   \part The normal frequencies are $\omega_1^2=a-b=\frac{k}{m}$  and $\omega_2^2=a+b=\frac{k+2\kappa}{m}$. \\ $\bigcirc$  \part The eigenvector $\bbpsi_1=\begin{pmatrix}\alpha_1\\\beta_1\end{pmatrix}$ for the normal frequency $\omega_1^2=\frac{k}{m}$  satisfies the equation\\ $ \begin{pmatrix} -1&1\\ 1&-1 \end{pmatrix}\bbpsi_1=0. $ \\ $\bigcirc$  \part The eigenvector $\bbpsi_2=\begin{pmatrix}\alpha_2\\\beta_2\end{pmatrix}$ for the normal frequency $\omega_2^2=\frac{k+2\kappa}{m}$  satisfies the equation\\ $ \begin{pmatrix} 1&1\\ 1&1 \end{pmatrix}\bbpsi_2=0. $ \\ $\bigcirc$  \part In general, the eigenvector  $\bbpsi_i=\begin{pmatrix}\alpha_i\\\beta_i\end{pmatrix}$ with unit normalization can be found as \\ $\bbpsi_i=\frac{1}{\alpha_i\alpha_i^*+\beta_i\beta_i^*}\begin{pmatrix}\alpha_i^*\\\beta_i^*\end{pmatrix}$. \\ $\times$ \\ $\bbpsi_i=\frac{1}{\sqrt{\alpha_i\alpha_i^*+\beta_i\beta_i^*}}\begin{pmatrix}\alpha_i \\\ ...
# ==================== Starts From Here ====================
#
# MC	 Consider doubly coupled harmonic oscillator which have both ends connected to the walls.  The oscillator consists of two point masses of identical mass $$m$$ that are connected in series with springs.  The positions of the left particle and the right one are $$x{}_1$$ and $$x{}_2$$, respectively.  Note that the coordinate $$x{}_1$$ ($$x{}_2$$) is chosen so that the restoring force due to the left (right) spring on the left (right) massive particle becomes $$0$$ at $$x{}_1=0$$ ($$x{}_2=0$$).  The spring constants of the springs at both ends are $$k$$ and that of the spring in-between is $$\kappa$$.  We define $$ \mathbb{x}=\begin{pmatrix}{x{}_{1}}\\{x{}_{2}}\end{pmatrix} $$ and $$ \mathbb{\Omega}^2 = \begin{pmatrix} a&-b\\ -b&a \end{pmatrix}$$.  The equation of motion for particle 1 is $$m\ddot{x}{}_{1} = -k x{}_{1}-\kappa(x{}_{1}-x{}_{2})$$.  	true	correct	false	incorrect	pass	incorrect
# MC	 Consider doubly coupled harmonic oscillator which have both ends connected to the walls.  The oscillator consists of two point masses of identical mass $$m$$ that are connected in series with springs.  The positions of the left particle and the right one are $$x{}_1$$ and $$x{}_2$$, respectively.  Note that the coordinate $$x{}_1$$ ($$x{}_2$$) is chosen so that the restoring force due to the left (right) spring on the left (right) massive particle becomes $$0$$ at $$x{}_1=0$$ ($$x{}_2=0$$).  The spring constants of the springs at both ends are $$k$$ and that of the spring in-between is $$\kappa$$.  We define $$ \mathbb{x}=\begin{pmatrix}{x{}_{1}}\\{x{}_{2}}\end{pmatrix} $$ and $$ \mathbb{\Omega}^2 = \begin{pmatrix} a&-b\\ -b&a \end{pmatrix}$$.  The equation of motion for particle 2 is $$m\ddot{x}{}_{2} = -k x{}_{2} -\kappa(x{}_{2}+x{}_{1})$$.  	true	incorrect	false	correct	pass	incorrect
# MC	 Consider doubly coupled harmonic oscillator which have both ends connected to the walls.  The oscillator consists of two point masses of identical mass $$m$$ that are connected in series with springs.  The positions of the left particle and the right one are $$x{}_1$$ and $$x{}_2$$, respectively.  Note that the coordinate $$x{}_1$$ ($$x{}_2$$) is chosen so that the restoring force due to the left (right) spring on the left (right) massive particle becomes $$0$$ at $$x{}_1=0$$ ($$x{}_2=0$$).  The spring constants of the springs at both ends are $$k$$ and that of the spring in-between is $$\kappa$$.  We define $$ \mathbb{x}=\begin{pmatrix}{x{}_{1}}\\{x{}_{2}}\end{pmatrix} $$ and $$ \mathbb{\Omega}^2 = \begin{pmatrix} a&-b\\ -b&a \end{pmatrix}$$.  The coupled equations can be written in the form $$\ddot{\mathbb{x}}+\mathbb{\Omega}^2 \mathbb{x}=\mathbb{0}, $$ where $$ a=\frac{k+2\kappa}{m},\quad b=\frac{\kappa}{m}$$.  	true	incorrect	false	correct	pass	incorrect
# MC	 Consider doubly coupled harmonic oscillator which have both ends connected to the walls.  The oscillator consists of two point masses of identical mass $$m$$ that are connected in series with springs.  The positions of the left particle and the right one are $$x{}_1$$ and $$x{}_2$$, respectively.  Note that the coordinate $$x{}_1$$ ($$x{}_2$$) is chosen so that the restoring force due to the left (right) spring on the left (right) massive particle becomes $$0$$ at $$x{}_1=0$$ ($$x{}_2=0$$).  The spring constants of the springs at both ends are $$k$$ and that of the spring in-between is $$\kappa$$.  We define $$ \mathbb{x}=\begin{pmatrix}{x{}_{1}}\\{x{}_{2}}\end{pmatrix} $$ and $$ \mathbb{\Omega}^2 = \begin{pmatrix} a&-b\\ -b&a \end{pmatrix}$$.  $$\mathbb{\Omega}^2$$ is antisymmetric.  	true	incorrect	false	correct	pass	incorrect
# MC	 Consider doubly coupled harmonic oscillator which have both ends connected to the walls.  The oscillator consists of two point masses of identical mass $$m$$ that are connected in series with springs.  The positions of the left particle and the right one are $$x{}_1$$ and $$x{}_2$$, respectively.  Note that the coordinate $$x{}_1$$ ($$x{}_2$$) is chosen so that the restoring force due to the left (right) spring on the left (right) massive particle becomes $$0$$ at $$x{}_1=0$$ ($$x{}_2=0$$).  The spring constants of the springs at both ends are $$k$$ and that of the spring in-between is $$\kappa$$.  We define $$ \mathbb{x}=\begin{pmatrix}{x{}_{1}}\\{x{}_{2}}\end{pmatrix} $$ and $$ \mathbb{\Omega}^2 = \begin{pmatrix} a&-b\\ -b&a \end{pmatrix}$$.  The trial solution $$\mathbb{x}=e^{-i\omega{}_k t}\Psi{}_k$$ can be used to solve this problem, where $$\Psi{}_k$$ is independent of time.  	true	correct	false	incorrect	pass	incorrect
# MC	 Consider doubly coupled harmonic oscillator which have both ends connected to the walls.  The oscillator consists of two point masses of identical mass $$m$$ that are connected in series with springs.  The positions of the left particle and the right one are $$x{}_1$$ and $$x{}_2$$, respectively.  Note that the coordinate $$x{}_1$$ ($$x{}_2$$) is chosen so that the restoring force due to the left (right) spring on the left (right) massive particle becomes $$0$$ at $$x{}_1=0$$ ($$x{}_2=0$$).  The spring constants of the springs at both ends are $$k$$ and that of the spring in-between is $$\kappa$$.  We define $$ \mathbb{x}=\begin{pmatrix}{x{}_{1}}\\{x{}_{2}}\end{pmatrix} $$ and $$ \mathbb{\Omega}^2 = \begin{pmatrix} a&-b\\ -b&a \end{pmatrix}$$.  The trial solution $$\mathbb{x}=e^{-i\omega{}_k t}\Psi{}_k$$ is consistent with the separation of variables usually employed to solve the partial differential equation.  	true	correct	false	incorrect	pass	incorrect
# MC	 Consider doubly coupled harmonic oscillator which have both ends connected to the walls.  The oscillator consists of two point masses of identical mass $$m$$ that are connected in series with springs.  The positions of the left particle and the right one are $$x{}_1$$ and $$x{}_2$$, respectively.  Note that the coordinate $$x{}_1$$ ($$x{}_2$$) is chosen so that the restoring force due to the left (right) spring on the left (right) massive particle becomes $$0$$ at $$x{}_1=0$$ ($$x{}_2=0$$).  The spring constants of the springs at both ends are $$k$$ and that of the spring in-between is $$\kappa$$.  We define $$ \mathbb{x}=\begin{pmatrix}{x{}_{1}}\\{x{}_{2}}\end{pmatrix} $$ and $$ \mathbb{\Omega}^2 = \begin{pmatrix} a&-b\\ -b&a \end{pmatrix}$$.  $$\mathbb{\Omega}^2$$ is diagonalizable: There exists a similarity transformation matrix $$\mathbb{\Lambda}$$ such that $$\mathbb{\Omega}^2{}_D = \mathbb{\Lambda}\mathbb{\Omega}^2\mathbb{\Lambda}^\dagger= \begin{pmatrix} \omega{}_1^2&0\\ 0&\omega{}_2^2 \end{pmatrix}$$.  	true	correct	false	incorrect	pass	incorrect
# MC	 Consider doubly coupled harmonic oscillator which have both ends connected to the walls.  The oscillator consists of two point masses of identical mass $$m$$ that are connected in series with springs.  The positions of the left particle and the right one are $$x{}_1$$ and $$x{}_2$$, respectively.  Note that the coordinate $$x{}_1$$ ($$x{}_2$$) is chosen so that the restoring force due to the left (right) spring on the left (right) massive particle becomes $$0$$ at $$x{}_1=0$$ ($$x{}_2=0$$).  The spring constants of the springs at both ends are $$k$$ and that of the spring in-between is $$\kappa$$.  We define $$ \mathbb{x}=\begin{pmatrix}{x{}_{1}}\\{x{}_{2}}\end{pmatrix} $$ and $$ \mathbb{\Omega}^2 = \begin{pmatrix} a&-b\\ -b&a \end{pmatrix}$$.  The unitrary transformation matrix $$\mathbb{\Lambda}$$ and its inverse are given by $$ \mathbb{\Lambda}=\begin{pmatrix} \Psi{}_1& \Psi{}_2\end{pmatrix} $$, $$\mathbb{\Lambda}^{-1}=\mathbb{\Lambda}^\dagger= \begin{pmatrix} \Psi{}_1^\dagger\\ \Psi{}_2^\dagger\end{pmatrix}$$.  Here, these matrices diagonalize $$\mathbb{\Omega}^2$$ as $$\mathbb{\Omega}^2{}_D = \mathbb{\Lambda}\mathbb{\Omega}^2\mathbb{\Lambda}^\dagger= \begin{pmatrix} \omega{}_1^2&0\\ 0&\omega{}_2^2 \end{pmatrix}$$.  	true	incorrect	false	correct	pass	incorrect
# MC	 Consider doubly coupled harmonic oscillator which have both ends connected to the walls.  The oscillator consists of two point masses of identical mass $$m$$ that are connected in series with springs.  The positions of the left particle and the right one are $$x{}_1$$ and $$x{}_2$$, respectively.  Note that the coordinate $$x{}_1$$ ($$x{}_2$$) is chosen so that the restoring force due to the left (right) spring on the left (right) massive particle becomes $$0$$ at $$x{}_1=0$$ ($$x{}_2=0$$).  The spring constants of the springs at both ends are $$k$$ and that of the spring in-between is $$\kappa$$.  We define $$ \mathbb{x}=\begin{pmatrix}{x{}_{1}}\\{x{}_{2}}\end{pmatrix} $$ and $$ \mathbb{\Omega}^2 = \begin{pmatrix} a&-b\\ -b&a \end{pmatrix}$$.  $$\mathbb{\Omega}^2$$ is anti-Hermitian.  	true	incorrect	false	correct	pass	incorrect
# MC	 Consider doubly coupled harmonic oscillator which have both ends connected to the walls.  The oscillator consists of two point masses of identical mass $$m$$ that are connected in series with springs.  The positions of the left particle and the right one are $$x{}_1$$ and $$x{}_2$$, respectively.  Note that the coordinate $$x{}_1$$ ($$x{}_2$$) is chosen so that the restoring force due to the left (right) spring on the left (right) massive particle becomes $$0$$ at $$x{}_1=0$$ ($$x{}_2=0$$).  The spring constants of the springs at both ends are $$k$$ and that of the spring in-between is $$\kappa$$.  We define $$ \mathbb{x}=\begin{pmatrix}{x{}_{1}}\\{x{}_{2}}\end{pmatrix} $$ and $$ \mathbb{\Omega}^2 = \begin{pmatrix} a&-b\\ -b&a \end{pmatrix}$$.  The secular equation for the eigenvalue problem is $$|\mathbb{\Omega}^2-\omega^2\mathbb{1}| =1$$.  	true	incorrect	false	correct	pass	incorrect
# MC	 Consider doubly coupled harmonic oscillator which have both ends connected to the walls.  The oscillator consists of two point masses of identical mass $$m$$ that are connected in series with springs.  The positions of the left particle and the right one are $$x{}_1$$ and $$x{}_2$$, respectively.  Note that the coordinate $$x{}_1$$ ($$x{}_2$$) is chosen so that the restoring force due to the left (right) spring on the left (right) massive particle becomes $$0$$ at $$x{}_1=0$$ ($$x{}_2=0$$).  The spring constants of the springs at both ends are $$k$$ and that of the spring in-between is $$\kappa$$.  We define $$ \mathbb{x}=\begin{pmatrix}{x{}_{1}}\\{x{}_{2}}\end{pmatrix} $$ and $$ \mathbb{\Omega}^2 = \begin{pmatrix} a&-b\\ -b&a \end{pmatrix}$$.  $$ |\mathbb{\Omega}^2-\omega^2\mathbb{1}|= (a-\omega^2-b)(a-\omega^2+b) $$.  	true	correct	false	incorrect	pass	incorrect
# MC	 Consider doubly coupled harmonic oscillator which have both ends connected to the walls.  The oscillator consists of two point masses of identical mass $$m$$ that are connected in series with springs.  The positions of the left particle and the right one are $$x{}_1$$ and $$x{}_2$$, respectively.  Note that the coordinate $$x{}_1$$ ($$x{}_2$$) is chosen so that the restoring force due to the left (right) spring on the left (right) massive particle becomes $$0$$ at $$x{}_1=0$$ ($$x{}_2=0$$).  The spring constants of the springs at both ends are $$k$$ and that of the spring in-between is $$\kappa$$.  We define $$ \mathbb{x}=\begin{pmatrix}{x{}_{1}}\\{x{}_{2}}\end{pmatrix} $$ and $$ \mathbb{\Omega}^2 = \begin{pmatrix} a&-b\\ -b&a \end{pmatrix}$$.  The normal frequencies are $$\omega{}_1^2=a-b=\frac{k}{m}$$ and $$\omega{}_2^2=a+b=\frac{k+2\kappa}{m}$$.  	true	correct	false	incorrect	pass	incorrect
# MC	 Consider doubly coupled harmonic oscillator which have both ends connected to the walls.  The oscillator consists of two point masses of identical mass $$m$$ that are connected in series with springs.  The positions of the left particle and the right one are $$x{}_1$$ and $$x{}_2$$, respectively.  Note that the coordinate $$x{}_1$$ ($$x{}_2$$) is chosen so that the restoring force due to the left (right) spring on the left (right) massive particle becomes $$0$$ at $$x{}_1=0$$ ($$x{}_2=0$$).  The spring constants of the springs at both ends are $$k$$ and that of the spring in-between is $$\kappa$$.  We define $$ \mathbb{x}=\begin{pmatrix}{x{}_{1}}\\{x{}_{2}}\end{pmatrix} $$ and $$ \mathbb{\Omega}^2 = \begin{pmatrix} a&-b\\ -b&a \end{pmatrix}$$.  The eigenvector $$\Psi{}_1=\begin{pmatrix}\alpha{}_1\\\beta{}_1\end{pmatrix}$$ for the normal frequency $$\omega{}_1^2=\frac{k}{m}$$ satisfies the equation $$ \begin{pmatrix} -1&1\\ 1&-1 \end{pmatrix}\Psi{}_1=0$$.  	true	correct	false	incorrect	pass	incorrect
# MC	 Consider doubly coupled harmonic oscillator which have both ends connected to the walls.  The oscillator consists of two point masses of identical mass $$m$$ that are connected in series with springs.  The positions of the left particle and the right one are $$x{}_1$$ and $$x{}_2$$, respectively.  Note that the coordinate $$x{}_1$$ ($$x{}_2$$) is chosen so that the restoring force due to the left (right) spring on the left (right) massive particle becomes $$0$$ at $$x{}_1=0$$ ($$x{}_2=0$$).  The spring constants of the springs at both ends are $$k$$ and that of the spring in-between is $$\kappa$$.  We define $$ \mathbb{x}=\begin{pmatrix}{x{}_{1}}\\{x{}_{2}}\end{pmatrix} $$ and $$ \mathbb{\Omega}^2 = \begin{pmatrix} a&-b\\ -b&a \end{pmatrix}$$.  The eigenvector $$\Psi{}_2=\begin{pmatrix}\alpha{}_2\\\beta{}_2\end{pmatrix}$$ for the normal frequency $$\omega{}_2^2=\frac{k+2\kappa}{m}$$ satisfies the equation $$ \begin{pmatrix} 1&1\\ 1&1 \end{pmatrix}\Psi{}_2=0$$.  	true	correct	false	incorrect	pass	incorrect
# MC	 Consider doubly coupled harmonic oscillator which have both ends connected to the walls.  The oscillator consists of two point masses of identical mass $$m$$ that are connected in series with springs.  The positions of the left particle and the right one are $$x{}_1$$ and $$x{}_2$$, respectively.  Note that the coordinate $$x{}_1$$ ($$x{}_2$$) is chosen so that the restoring force due to the left (right) spring on the left (right) massive particle becomes $$0$$ at $$x{}_1=0$$ ($$x{}_2=0$$).  The spring constants of the springs at both ends are $$k$$ and that of the spring in-between is $$\kappa$$.  We define $$ \mathbb{x}=\begin{pmatrix}{x{}_{1}}\\{x{}_{2}}\end{pmatrix} $$ and $$ \mathbb{\Omega}^2 = \begin{pmatrix} a&-b\\ -b&a \end{pmatrix}$$.  In general, the eigenvector $$\Psi{}_i=\begin{pmatrix}\alpha{}_i\\\beta{}_i\end{pmatrix}$$ with unit normalization can be found as $$\Psi{}_i=\frac{1}{\alpha{}_i\alpha{}_i^*+\beta{}_i\beta{}_i^*}\begin{pmatrix}\alpha{}_i^*\\\beta{}_i^*\end{pmatrix}$$.  	true	incorrect	false	correct	pass	incorrect
# MC	 Consider doubly coupled harmonic oscillator which have both ends connected to the walls.  The oscillator consists of two point masses of identical mass $$m$$ that are connected in series with springs.  The positions of the left particle and the right one are $$x{}_1$$ and $$x{}_2$$, respectively.  Note that the coordinate $$x{}_1$$ ($$x{}_2$$) is chosen so that the restoring force due to the left (right) spring on the left (right) massive particle becomes $$0$$ at $$x{}_1=0$$ ($$x{}_2=0$$).  The spring constants of the springs at both ends are $$k$$ and that of the spring in-between is $$\kappa$$.  We define $$ \mathbb{x}=\begin{pmatrix}{x{}_{1}}\\{x{}_{2}}\end{pmatrix} $$ and $$ \mathbb{\Omega}^2 = \begin{pmatrix} a&-b\\ -b&a \end{pmatrix}$$.  The eigenvector with unit normalization for the frequency $$\omega{}_1^2 = a-b=\frac{k}{m}$$ is $$\Psi{}_1= \frac{1}{\sqrt{2}} \begin{pmatrix} -1\\ 1 \end{pmatrix}$$.  	true	incorrect	false	correct	pass	incorrect
# MC	 Consider doubly coupled harmonic oscillator which have both ends connected to the walls.  The oscillator consists of two point masses of identical mass $$m$$ that are connected in series with springs.  The positions of the left particle and the right one are $$x{}_1$$ and $$x{}_2$$, respectively.  Note that the coordinate $$x{}_1$$ ($$x{}_2$$) is chosen so that the restoring force due to the left (right) spring on the left (right) massive particle becomes $$0$$ at $$x{}_1=0$$ ($$x{}_2=0$$).  The spring constants of the springs at both ends are $$k$$ and that of the spring in-between is $$\kappa$$.  We define $$ \mathbb{x}=\begin{pmatrix}{x{}_{1}}\\{x{}_{2}}\end{pmatrix} $$ and $$ \mathbb{\Omega}^2 = \begin{pmatrix} a&-b\\ -b&a \end{pmatrix}$$.  The eigenvector with unit normalization for the frequency $$\omega{}_2^2 = a+b=\frac{k+2\kappa}{m}$$ is $$\Psi{}_2= \frac{1}{\sqrt{2}}\begin{pmatrix} 1\\ 1 \end{pmatrix}$$.  	true	incorrect	false	correct	pass	incorrect
# MC	 Let $$\Psi{}_i$$ is the unit eigenvector for an $$2\times 2$$ square Hermitian matrix$$. \Psi{}_i^\dagger\Psi{}_j=\delta{}_{ij}$$.  	true	correct	false	incorrect	pass	incorrect
# MC	 Let $$\Psi{}_i$$ is the unit eigenvector for an $$2\times 2$$ square Hermitian matrix$$. \Psi{}_i\otimes\Psi{}_j^\dagger=\mathbb{1}$$.  	true	incorrect	false	correct	pass	incorrect
# MC	 Let $$\Psi{}_i$$ is the unit eigenvector for an $$2\times 2$$ square Hermitian matrix$$. \textrm{Tr}[\Psi{}_i\otimes\Psi{}_j^\dagger]=\delta{}_{ij}$$.  	true	correct	false	incorrect	pass	incorrect
# MC	 Let $$\Psi{}_i$$ is the unit eigenvector for an $$2\times 2$$ square Hermitian matrix$$. \mathfrak{Det}[\Psi{}_i~\Psi{}_j]=\pm\epsilon{}_{ij}$$.  	true	correct	false	incorrect	pass	incorrect
# MC	 Suppose that we have found the column eigenvectors $$\Psi{}_i$$ for an $$n\times n$$ square Hermitian matrix $$\mathbb{A}$$.  The matrix that diagonalizes $$\mathbb{A}$$ is $$\mathbb{\Lambda}$$: $$\mathbb{A}{}_D=\mathbb{\Lambda}\mathbb{A}\mathbb{\Lambda}^\dagger$$$$. \mathbb{\Lambda}=(\Psi{}_1\,\Psi{}_2\,\cdots \Psi{}_n)$$.  	true	incorrect	false	correct	pass	incorrect
# MC	 Suppose that we have found the column eigenvectors $$\Psi{}_i$$ for an $$n\times n$$ square Hermitian matrix $$\mathbb{A}$$.  The matrix that diagonalizes $$\mathbb{A}$$ is $$\mathbb{\Lambda}$$: $$\mathbb{A}{}_D=\mathbb{\Lambda}\mathbb{A}\mathbb{\Lambda}^\dagger$$.  The $$i$$th row of $$\mathbb{\Lambda}$$ is $$\Psi{}_i^\dagger$$.  	true	correct	false	incorrect	pass	incorrect
# MC	 Suppose that we have found the column eigenvectors $$\Psi{}_i$$ for an $$n\times n$$ square Hermitian matrix $$\mathbb{A}$$.  The matrix that diagonalizes $$\mathbb{A}$$ is $$\mathbb{\Lambda}$$: $$\mathbb{A}{}_D=\mathbb{\Lambda}\mathbb{A}\mathbb{\Lambda}^\dagger$$.  The $$i$$th column of $$\mathbb{\Lambda}^\dagger$$ is $$\Psi{}_i$$.  	true	correct	false	incorrect	pass	incorrect
# MC	 Suppose that we have found the column eigenvectors $$\Psi{}_i$$ for an $$n\times n$$ square Hermitian matrix $$\mathbb{A}$$.  The matrix that diagonalizes $$\mathbb{A}$$ is $$\mathbb{\Lambda}$$: $$\mathbb{A}{}_D=\mathbb{\Lambda}\mathbb{A}\mathbb{\Lambda}^\dagger$$$$. \mathbb{\Lambda}$$ is Hermitian.  	true	incorrect	false	correct	pass	incorrect
# MC	 Suppose that we have found the column eigenvectors $$\Psi{}_i$$ for an $$n\times n$$ square Hermitian matrix $$\mathbb{A}$$.  The matrix that diagonalizes $$\mathbb{A}$$ is $$\mathbb{\Lambda}$$: $$\mathbb{A}{}_D=\mathbb{\Lambda}\mathbb{A}\mathbb{\Lambda}^\dagger$$$$. [\mathbb{\Lambda}\Psi{}_i]{}_j=\delta{}_{ij}$$, where $$j$$ stands for the row index of the matrix in the brackets.  	true	correct	false	incorrect	pass	incorrect
# MC	 The eigenvectors of $$\mathbb{\Omega}^2$$ are $$\Psi{}_1= \frac{1}{\sqrt{2}} \begin{pmatrix} 1\\ 1 \end{pmatrix}$$, $$\Psi{}_2= \frac{1}{\sqrt{2}} \begin{pmatrix} -1\\ 1 \end{pmatrix}$$.  The eigenvalue for $$\Psi{}_i$$ is $$\omega{}_i^2$$, where $$\omega{}_1^2=\frac{k}{m}$$ and $$\omega{}_2^2=\frac{k+2\kappa}{m}$$.  The normal mode $$\eta$$ is defined by $$ \eta=\mathbb{\Lambda} \mathbb{x}$$.  	true	correct	false	incorrect	pass	incorrect
# MC	 The eigenvectors of $$\mathbb{\Omega}^2$$ are $$\Psi{}_1= \frac{1}{\sqrt{2}} \begin{pmatrix} 1\\ 1 \end{pmatrix}$$, $$\Psi{}_2= \frac{1}{\sqrt{2}} \begin{pmatrix} -1\\ 1 \end{pmatrix}$$.  The eigenvalue for $$\Psi{}_i$$ is $$\omega{}_i^2$$, where $$\omega{}_1^2=\frac{k}{m}$$ and $$\omega{}_2^2=\frac{k+2\kappa}{m}$$$$. \mathbb{\Omega}^2{}_D= \mathbb{\Lambda}^\dagger\mathbb{\Omega}^2\mathbb{\Lambda} = \begin{pmatrix} \omega{}_1^2&0\\ 0&\omega{}_2^2 \end{pmatrix}$$.  	true	incorrect	false	correct	pass	incorrect
# MC	 The eigenvectors of $$\mathbb{\Omega}^2$$ are $$\Psi{}_1= \frac{1}{\sqrt{2}} \begin{pmatrix} 1\\ 1 \end{pmatrix}$$, $$\Psi{}_2= \frac{1}{\sqrt{2}} \begin{pmatrix} -1\\ 1 \end{pmatrix}$$.  The eigenvalue for $$\Psi{}_i$$ is $$\omega{}_i^2$$, where $$\omega{}_1^2=\frac{k}{m}$$ and $$\omega{}_2^2=\frac{k+2\kappa}{m}$$.  The equation of motion $$\ddot{\mathbb{x}}+\mathbb{\Omega}^2 \mathbb{x}=\mathbb{0}, $$ reduces into $$\ddot{\eta}=\mathbb{\Omega}^2{}_D \eta$$.  	true	correct	false	incorrect	pass	incorrect
# MC	 The eigenvectors of $$\mathbb{\Omega}^2$$ are $$\Psi{}_1= \frac{1}{\sqrt{2}} \begin{pmatrix} 1\\ 1 \end{pmatrix}$$, $$\Psi{}_2= \frac{1}{\sqrt{2}} \begin{pmatrix} -1\\ 1 \end{pmatrix}$$.  The eigenvalue for $$\Psi{}_i$$ is $$\omega{}_i^2$$, where $$\omega{}_1^2=\frac{k}{m}$$ and $$\omega{}_2^2=\frac{k+2\kappa}{m}$$.  Every normal coordinate $$\eta{}_i$$ is decoupled from the other coordinate: $$\ddot{\eta}{}_i+\omega{}_i^2\eta{}_i=0$$.  	true	correct	false	incorrect	pass	incorrect
# MC	 The eigenvectors of $$\mathbb{\Omega}^2$$ are $$\Psi{}_1= \frac{1}{\sqrt{2}} \begin{pmatrix} 1\\ 1 \end{pmatrix}$$, $$\Psi{}_2= \frac{1}{\sqrt{2}} \begin{pmatrix} -1\\ 1 \end{pmatrix}$$.  The eigenvalue for $$\Psi{}_i$$ is $$\omega{}_i^2$$, where $$\omega{}_1^2=\frac{k}{m}$$ and $$\omega{}_2^2=\frac{k+2\kappa}{m}$$$$. \eta=\begin{pmatrix}\eta{}_1\\ \eta{}_2\end{pmatrix}=\mathbb{\Lambda}^\dagger \mathbb{x}=\frac{1}{\sqrt{2}} \begin{pmatrix}x{}_1-x{}_2\\ x{}_1+x{}_2\end{pmatrix}$$ 	true	correct	false	incorrect	pass	incorrect
# MC	 The eigenvectors of $$\mathbb{\Omega}^2$$ are $$\Psi{}_1= \frac{1}{\sqrt{2}} \begin{pmatrix} 1\\ 1 \end{pmatrix}$$, $$\Psi{}_2= \frac{1}{\sqrt{2}} \begin{pmatrix} -1\\ 1 \end{pmatrix}$$.  The eigenvalue for $$\Psi{}_i$$ is $$\omega{}_i^2$$, where $$\omega{}_1^2=\frac{k}{m}$$ and $$\omega{}_2^2=\frac{k+2\kappa}{m}$$$$. \begin{pmatrix}x{}_1\\ x{}_2\end{pmatrix}=\mathbb{x}=\mathbb{\Lambda}^\dagger\eta =\frac{1}{\sqrt{2}} \begin{pmatrix}\eta{}_1-\eta{}_2\\ \eta{}_1+\eta{}_2\end{pmatrix} $$.  	true	correct	false	incorrect	pass	incorrect
# MC	 The eigenvectors of $$\mathbb{\Omega}^2$$ are $$\Psi{}_1= \frac{1}{\sqrt{2}} \begin{pmatrix} 1\\ 1 \end{pmatrix}$$, $$\Psi{}_2= \frac{1}{\sqrt{2}} \begin{pmatrix} -1\\ 1 \end{pmatrix}$$.  The eigenvalue for $$\Psi{}_i$$ is $$\omega{}_i^2$$, where $$\omega{}_1^2=\frac{k}{m}$$ and $$\omega{}_2^2=\frac{k+2\kappa}{m}$$.  The general solution for $$\eta{}_1$$ is $$\eta{}_1(t)=\alpha{}_1\cos\sqrt{\frac{k}{m}}t+\beta{}_1\sin\sqrt{\frac{k}{m}}t$$, where $$\alpha{}_1$$, $$\beta{}_1$$ are constants.  	true	correct	false	incorrect	pass	incorrect
# MC	 The eigenvectors of $$\mathbb{\Omega}^2$$ are $$\Psi{}_1= \frac{1}{\sqrt{2}} \begin{pmatrix} 1\\ 1 \end{pmatrix}$$, $$\Psi{}_2= \frac{1}{\sqrt{2}} \begin{pmatrix} -1\\ 1 \end{pmatrix}$$.  The eigenvalue for $$\Psi{}_i$$ is $$\omega{}_i^2$$, where $$\omega{}_1^2=\frac{k}{m}$$ and $$\omega{}_2^2=\frac{k+2\kappa}{m}$$.  The general solution for $$\eta{}_2$$ is $$\eta{}_2(t)=\alpha{}_2\cos\sqrt{\frac{k+2\kappa}{m}}t+\beta{}_2\sin\sqrt{\frac{k+2\kappa}{m}}t$$, where $$\alpha{}_2$$, $$\beta{}_2$$ are constants.  	true	correct	false	incorrect	pass	incorrect
# MC	 The eigenvectors of $$\mathbb{\Omega}^2$$ are $$\Psi{}_1= \frac{1}{\sqrt{2}} \begin{pmatrix} 1\\ 1 \end{pmatrix}$$, $$\Psi{}_2= \frac{1}{\sqrt{2}} \begin{pmatrix} -1\\ 1 \end{pmatrix}$$.  The eigenvalue for $$\Psi{}_i$$ is $$\omega{}_i^2$$, where $$\omega{}_1^2=\frac{k}{m}$$ and $$\omega{}_2^2=\frac{k+2\kappa}{m}$$$$. \eta{}_1$$ ($$\eta{}_2$$) represents the antisymmetric (symmetric) contribution to the relative motion of 1 and 2.  	true	incorrect	false	correct	pass	incorrect
# MC	 The eigenvectors of $$\mathbb{\Omega}^2$$ are $$\Psi{}_1= \frac{1}{\sqrt{2}} \begin{pmatrix} 1\\ 1 \end{pmatrix}$$, $$\Psi{}_2= \frac{1}{\sqrt{2}} \begin{pmatrix} -1\\ 1 \end{pmatrix}$$.  The eigenvalue for $$\Psi{}_i$$ is $$\omega{}_i^2$$, where $$\omega{}_1^2=\frac{k}{m}$$ and $$\omega{}_2^2=\frac{k+2\kappa}{m}$$$$. \omega{}_2>\omega{}_1$$ because the antisymmetric contribution involves all three springs.  	true	correct	false	incorrect	pass	incorrect
# MC	 The eigenvectors of $$\mathbb{\Omega}^2$$ are $$\Psi{}_1= \frac{1}{\sqrt{2}} \begin{pmatrix} 1\\ 1 \end{pmatrix}$$, $$\Psi{}_2= \frac{1}{\sqrt{2}} \begin{pmatrix} -1\\ 1 \end{pmatrix}$$.  The eigenvalue for $$\Psi{}_i$$ is $$\omega{}_i^2$$, where $$\omega{}_1^2=\frac{k}{m}$$ and $$\omega{}_2^2=\frac{k+2\kappa}{m}$$$$. \omega{}_1<\omega{}_2$$ because the middle spring does not exert any force in the symmetric contribution.  	true	correct	false	incorrect	pass	incorrect
# MC	 The eigenvectors of $$\mathbb{\Omega}^2$$ are $$\Psi{}_1= \frac{1}{\sqrt{2}} \begin{pmatrix} 1\\ 1 \end{pmatrix}$$, $$\Psi{}_2= \frac{1}{\sqrt{2}} \begin{pmatrix} -1\\ 1 \end{pmatrix}$$.  The eigenvalue for $$\Psi{}_i$$ is $$\omega{}_i^2$$, where $$\omega{}_1^2=\frac{k}{m}$$ and $$\omega{}_2^2=\frac{k+2\kappa}{m}$$.  The number of coordinates is the same as the number of normal frequencies with multiplicities.  	true	correct	false	incorrect	pass	incorrect
# MC	 The eigenvectors of $$\mathbb{\Omega}^2$$ are $$\Psi{}_1= \frac{1}{\sqrt{2}} \begin{pmatrix} 1\\ 1 \end{pmatrix}$$, $$\Psi{}_2= \frac{1}{\sqrt{2}} \begin{pmatrix} -1\\ 1 \end{pmatrix}$$.  The eigenvalue for $$\Psi{}_i$$ is $$\omega{}_i^2$$, where $$\omega{}_1^2=\frac{k}{m}$$ and $$\omega{}_2^2=\frac{k+2\kappa}{m}$$.  The number of normal frequencies including multiplicities may not be the same as the number of linearly independent eigenvectors.  	true	incorrect	false	correct	pass	incorrect
# MC	 Consider the coupled oscillator $$\ddot{\mathbb{x}}+\mathbb{\Omega}^2 \mathbb{x}=\mathbb{0}, $$ where $$ \mathbb{x}=\begin{pmatrix}{x{}_{1}}\\{x{}_{2}}\end{pmatrix} $$ and $$ \mathbb{\Omega}^2 = \begin{pmatrix} \frac{k+2\kappa}{m}&- \frac{\kappa}{m}\\ - \frac{\kappa}{m}&\frac{k+2\kappa}{m} \end{pmatrix}$$.  The eigenvectors of $$\mathbb{\Omega}^2$$ are $$\Psi{}_1= \frac{1}{\sqrt{2}} \begin{pmatrix} 1\\ 1 \end{pmatrix}$$, $$\Psi{}_2= \frac{1}{\sqrt{2}} \begin{pmatrix} -1\\ 1 \end{pmatrix}$$.  The eigenvalue for $$\Psi{}_i$$ is $$\omega{}_i^2$$, where $$\omega{}_1^2=\frac{k}{m}$$ and $$\omega{}_2^2=\frac{k+2\kappa}{m}$$.  The initial conditions are given by $$ \mathbb{x}(0)=\begin{pmatrix}{-D}\\{D}\end{pmatrix} $$ and $$ \dot{\mathbb{x}}(0)=\begin{pmatrix}{0}\\{0}\end{pmatrix} $$.  The initial conditions for the normal coordinates are $$\eta(0)=\mathbb{\Lambda}\mathbb{x}(0)=\begin{pmatrix}{0}\\{\sqrt{2}D}\end{pmatrix}$$ and $$\dot{\eta(0)}=\mathbb{\Lambda}\dot{\mathbb{x}}(0)=\begin{pmatrix}{0}\\{0}\end{pmatrix}$$.  	true	correct	false	incorrect	pass	incorrect
# MC	 Consider the coupled oscillator $$\ddot{\mathbb{x}}+\mathbb{\Omega}^2 \mathbb{x}=\mathbb{0}, $$ where $$ \mathbb{x}=\begin{pmatrix}{x{}_{1}}\\{x{}_{2}}\end{pmatrix} $$ and $$ \mathbb{\Omega}^2 = \begin{pmatrix} \frac{k+2\kappa}{m}&- \frac{\kappa}{m}\\ - \frac{\kappa}{m}&\frac{k+2\kappa}{m} \end{pmatrix}$$.  The eigenvectors of $$\mathbb{\Omega}^2$$ are $$\Psi{}_1= \frac{1}{\sqrt{2}} \begin{pmatrix} 1\\ 1 \end{pmatrix}$$, $$\Psi{}_2= \frac{1}{\sqrt{2}} \begin{pmatrix} -1\\ 1 \end{pmatrix}$$.  The eigenvalue for $$\Psi{}_i$$ is $$\omega{}_i^2$$, where $$\omega{}_1^2=\frac{k}{m}$$ and $$\omega{}_2^2=\frac{k+2\kappa}{m}$$.  The initial conditions are given by $$ \mathbb{x}(0)=\begin{pmatrix}{-D}\\{D}\end{pmatrix} $$ and $$ \dot{\mathbb{x}}(0)=\begin{pmatrix}{0}\\{0}\end{pmatrix} $$.  The normal coordinates are $$\eta(t)=\mathbb{\Lambda}\mathbb{x}(t)=\begin{pmatrix}{0}\\{\sqrt{2}D\cos\sqrt{\frac{k }{m}}t}\end{pmatrix}$$.  	true	incorrect	false	correct	pass	incorrect
# MC	 Consider the coupled oscillator $$\ddot{\mathbb{x}}+\mathbb{\Omega}^2 \mathbb{x}=\mathbb{0}, $$ where $$ \mathbb{x}=\begin{pmatrix}{x{}_{1}}\\{x{}_{2}}\end{pmatrix} $$ and $$ \mathbb{\Omega}^2 = \begin{pmatrix} \frac{k+2\kappa}{m}&- \frac{\kappa}{m}\\ - \frac{\kappa}{m}&\frac{k+2\kappa}{m} \end{pmatrix}$$.  The eigenvectors of $$\mathbb{\Omega}^2$$ are $$\Psi{}_1= \frac{1}{\sqrt{2}} \begin{pmatrix} 1\\ 1 \end{pmatrix}$$, $$\Psi{}_2= \frac{1}{\sqrt{2}} \begin{pmatrix} -1\\ 1 \end{pmatrix}$$.  The eigenvalue for $$\Psi{}_i$$ is $$\omega{}_i^2$$, where $$\omega{}_1^2=\frac{k}{m}$$ and $$\omega{}_2^2=\frac{k+2\kappa}{m}$$.  The initial conditions are given by $$ \mathbb{x}(0)=\begin{pmatrix}{-D}\\{D}\end{pmatrix} $$ and $$ \dot{\mathbb{x}}(0)=\begin{pmatrix}{0}\\{0}\end{pmatrix} $$.  The solution is $$\mathbb{x}(t)=\mathbb{\Lambda}^\dagger\eta(t) =\begin{pmatrix}{1}\\{1}\end{pmatrix}D\cos\sqrt{\frac{k+2\kappa}{m}}t$$.  	true	incorrect	false	correct	pass	incorrect
# MC	 Let us consider a system of $$n$$ particles.  We denote $$(x{}_{{k}},\,y{}_{{k}},\,z{}_{{k}})$$ by the spatial coordinates of the $$k$$th particle in the Cartesian coordinate system.  We assume that there are $$3n$$ degrees of freedom and, therefore, there are $$N=3n$$ real valued generalized coordinates $$q{}_{1},\cdots,q{}_{N}$$.  We assume that coordinates do not have any explicit time dependence so that \begin{equation*} \frac{\partial x{}_{k}}{\partial t}= \frac{\partial y{}_{k}}{\partial t}= \frac{\partial z{}_{k}}{\partial t}= \frac{\partial q{}_{k}}{\partial t}\equiv0.  \end{equation*} We assume that the system has a stable equilibrium state.  We choose the reference point (origin) of the generalized coordinates at this equilibrium point $$\mathbb{q}=\mathbb{0}$$.  The total kinetic energy $$T$$ of the system is $$ T = \frac{1}{2} \sum{}_{k=1}^{n} m{}_{k} ( \dot{x}^{2}{}_{k} +\dot{y}^{2}{}_{k} +\dot{z}^{2}{}_{k}), $$ where $$m{}_k$$ is the mass of the $$k$$th particle.  	true	correct	false	incorrect	pass	incorrect
# MC	 Let us consider a system of $$n$$ particles.  We denote $$(x{}_{{k}},\,y{}_{{k}},\,z{}_{{k}})$$ by the spatial coordinates of the $$k$$th particle in the Cartesian coordinate system.  We assume that there are $$3n$$ degrees of freedom and, therefore, there are $$N=3n$$ real valued generalized coordinates $$q{}_{1},\cdots,q{}_{N}$$.  We assume that coordinates do not have any explicit time dependence so that \begin{equation*} \frac{\partial x{}_{k}}{\partial t}= \frac{\partial y{}_{k}}{\partial t}= \frac{\partial z{}_{k}}{\partial t}= \frac{\partial q{}_{k}}{\partial t}\equiv0.  \end{equation*} We assume that the system has a stable equilibrium state.  We choose the reference point (origin) of the generalized coordinates at this equilibrium point $$\mathbb{q}=\mathbb{0}$$.  The total kinetic energy $$T$$ of the system is $$ T =\frac{1}{2} \sum{}_{i=1}^{N}\sum{}_{j=1}^{N} M{}_{ij}\dot{q}{}_{i}\dot{q}{}_{j}, $$ where $$M{}_{ij}$$ is the $$ij$$ element of the $$N\times N$$ mass matrix $$\mathbb{M}$$.  	true	correct	false	incorrect	pass	incorrect
# MC	 Let us consider a system of $$n$$ particles.  We denote $$(x{}_{{k}},\,y{}_{{k}},\,z{}_{{k}})$$ by the spatial coordinates of the $$k$$th particle in the Cartesian coordinate system.  We assume that there are $$3n$$ degrees of freedom and, therefore, there are $$N=3n$$ real valued generalized coordinates $$q{}_{1},\cdots,q{}_{N}$$.  We assume that coordinates do not have any explicit time dependence so that \begin{equation*} \frac{\partial x{}_{k}}{\partial t}= \frac{\partial y{}_{k}}{\partial t}= \frac{\partial z{}_{k}}{\partial t}= \frac{\partial q{}_{k}}{\partial t}\equiv0.  \end{equation*} We assume that the system has a stable equilibrium state.  We choose the reference point (origin) of the generalized coordinates at this equilibrium point $$\mathbb{q}=\mathbb{0}$$.  The $$ij$$ element of the mass matrix $$\mathbb{M}$$ is $$M{}_{ij}= \sum{}_{k=1}^{n} m{}_{k}\bigg( \frac{\partial x{}_{k}}{\partial q{}_{i}}\frac{\partial x{}_{k}}{\partial q{}_{j}}\bigg)^2$$.  	true	incorrect	false	correct	pass	incorrect
# MC	 Let us consider a system of $$n$$ particles.  We denote $$(x{}_{{k}},\,y{}_{{k}},\,z{}_{{k}})$$ by the spatial coordinates of the $$k$$th particle in the Cartesian coordinate system.  We assume that there are $$3n$$ degrees of freedom and, therefore, there are $$N=3n$$ real valued generalized coordinates $$q{}_{1},\cdots,q{}_{N}$$.  We assume that coordinates do not have any explicit time dependence so that \begin{equation*} \frac{\partial x{}_{k}}{\partial t}= \frac{\partial y{}_{k}}{\partial t}= \frac{\partial z{}_{k}}{\partial t}= \frac{\partial q{}_{k}}{\partial t}\equiv0.  \end{equation*} We assume that the system has a stable equilibrium state.  We choose the reference point (origin) of the generalized coordinates at this equilibrium point $$\mathbb{q}=\mathbb{0}$$.  The total kinetic energy of the system can be expressed as $$T=\frac{1}{2}\dot{\mathbb{q}}^T\mathbb{M}\dot{\mathbb{q}}$$.  	true	correct	false	incorrect	pass	incorrect
# MC	 Let us consider a system of $$n$$ particles.  We denote $$(x{}_{{k}},\,y{}_{{k}},\,z{}_{{k}})$$ by the spatial coordinates of the $$k$$th particle in the Cartesian coordinate system.  We assume that there are $$3n$$ degrees of freedom and, therefore, there are $$N=3n$$ real valued generalized coordinates $$q{}_{1},\cdots,q{}_{N}$$.  We assume that coordinates do not have any explicit time dependence so that \begin{equation*} \frac{\partial x{}_{k}}{\partial t}= \frac{\partial y{}_{k}}{\partial t}= \frac{\partial z{}_{k}}{\partial t}= \frac{\partial q{}_{k}}{\partial t}\equiv0.  \end{equation*} We assume that the system has a stable equilibrium state.  We choose the reference point (origin) of the generalized coordinates at this equilibrium point $$\mathbb{q}=\mathbb{0}$$.  The potential energy can be approximated as $$U=\frac{1}{2}\mathbb{q}^T\mathbb{A}\mathbb{q}$$, where the $$ij$$ element of the potential energy tensor $$\mathbb{A}$$ is $$A{}_{ij} \equiv \frac{\partial ^{2} U}{\partial q{}_{i} \partial q{}_{j}}\bigg|{}_{\mathbb{q}=\mathbb{0}}$$.  	true	correct	false	incorrect	pass	incorrect
# MC	 Let us consider a system of $$n$$ particles.  We denote $$(x{}_{{k}},\,y{}_{{k}},\,z{}_{{k}})$$ by the spatial coordinates of the $$k$$th particle in the Cartesian coordinate system.  We assume that there are $$3n$$ degrees of freedom and, therefore, there are $$N=3n$$ real valued generalized coordinates $$q{}_{1},\cdots,q{}_{N}$$.  We assume that coordinates do not have any explicit time dependence so that \begin{equation*} \frac{\partial x{}_{k}}{\partial t}= \frac{\partial y{}_{k}}{\partial t}= \frac{\partial z{}_{k}}{\partial t}= \frac{\partial q{}_{k}}{\partial t}\equiv0.  \end{equation*} We assume that the system has a stable equilibrium state.  We choose the reference point (origin) of the generalized coordinates at this equilibrium point $$\mathbb{q}=\mathbb{0}$$.  The Lagrangian is $$L =\frac{1}{2} ( \dot{\mathbb{q}}^{\dagger}\mathbb{M}\dot{\mathbb{q}} - \mathbb{q}^{\dagger}\mathbb{A}\mathbb{q})$$.  	true	correct	false	incorrect	pass	incorrect
# MC	 Let us consider a system of $$n$$ particles.  We denote $$(x{}_{{k}},\,y{}_{{k}},\,z{}_{{k}})$$ by the spatial coordinates of the $$k$$th particle in the Cartesian coordinate system.  We assume that there are $$3n$$ degrees of freedom and, therefore, there are $$N=3n$$ real valued generalized coordinates $$q{}_{1},\cdots,q{}_{N}$$.  We assume that coordinates do not have any explicit time dependence so that \begin{equation*} \frac{\partial x{}_{k}}{\partial t}= \frac{\partial y{}_{k}}{\partial t}= \frac{\partial z{}_{k}}{\partial t}= \frac{\partial q{}_{k}}{\partial t}\equiv0.  \end{equation*} We assume that the system has a stable equilibrium state.  We choose the reference point (origin) of the generalized coordinates at this equilibrium point $$\mathbb{q}=\mathbb{0}$$.  Both $$\mathbb{M}$$ and $$\mathbb{A}$$ are real and symmetric.  	true	correct	false	incorrect	pass	incorrect
# MC	 Let us consider a system of $$n$$ particles.  We denote $$(x{}_{{k}},\,y{}_{{k}},\,z{}_{{k}})$$ by the spatial coordinates of the $$k$$th particle in the Cartesian coordinate system.  We assume that there are $$3n$$ degrees of freedom and, therefore, there are $$N=3n$$ real valued generalized coordinates $$q{}_{1},\cdots,q{}_{N}$$.  We assume that coordinates do not have any explicit time dependence so that \begin{equation*} \frac{\partial x{}_{k}}{\partial t}= \frac{\partial y{}_{k}}{\partial t}= \frac{\partial z{}_{k}}{\partial t}= \frac{\partial q{}_{k}}{\partial t}\equiv0.  \end{equation*} We assume that the system has a stable equilibrium state.  We choose the reference point (origin) of the generalized coordinates at this equilibrium point $$\mathbb{q}=\mathbb{0}$$.  Both $$\mathbb{M}$$ and $$\mathbb{A}$$ are unitary.  	true	incorrect	false	correct	pass	incorrect
# MC	 Let us consider a system of $$n$$ particles.  We denote $$(x{}_{{k}},\,y{}_{{k}},\,z{}_{{k}})$$ by the spatial coordinates of the $$k$$th particle in the Cartesian coordinate system.  We assume that there are $$3n$$ degrees of freedom and, therefore, there are $$N=3n$$ real valued generalized coordinates $$q{}_{1},\cdots,q{}_{N}$$.  We assume that coordinates do not have any explicit time dependence so that \begin{equation*} \frac{\partial x{}_{k}}{\partial t}= \frac{\partial y{}_{k}}{\partial t}= \frac{\partial z{}_{k}}{\partial t}= \frac{\partial q{}_{k}}{\partial t}\equiv0.  \end{equation*} We assume that the system has a stable equilibrium state.  We choose the reference point (origin) of the generalized coordinates at this equilibrium point $$\mathbb{q}=\mathbb{0}$$.  Since $$U$$ is independent of the velocity, $$\frac{\partial L}{\partial \dot{q}{}_i}=0$$ and the canonical momentum $$p{}_i=M{}_{ij}\dot{q}{}_j$$ that is conjugate to the momentum $$q{}_j$$.  	true	incorrect	false	correct	pass	incorrect
# MC	 Let us consider a system of $$n$$ particles.  We denote $$(x{}_{{k}},\,y{}_{{k}},\,z{}_{{k}})$$ by the spatial coordinates of the $$k$$th particle in the Cartesian coordinate system.  We assume that there are $$3n$$ degrees of freedom and, therefore, there are $$N=3n$$ real valued generalized coordinates $$q{}_{1},\cdots,q{}_{N}$$.  We assume that coordinates do not have any explicit time dependence so that \begin{equation*} \frac{\partial x{}_{k}}{\partial t}= \frac{\partial y{}_{k}}{\partial t}= \frac{\partial z{}_{k}}{\partial t}= \frac{\partial q{}_{k}}{\partial t}\equiv0.  \end{equation*} We assume that the system has a stable equilibrium state.  We choose the reference point (origin) of the generalized coordinates at this equilibrium point $$\mathbb{q}=\mathbb{0}$$.  The Euler-Lagrange equation for the generalized coordinate $$q{}_j$$ is $$ \frac{\partial L}{\partial q{}_i}=M{}_{ij}\ddot{q}{}_j$$.  	true	incorrect	false	correct	pass	incorrect
# MC	 Let us consider a system of $$n$$ particles.  We denote $$(x{}_{{k}},\,y{}_{{k}},\,z{}_{{k}})$$ by the spatial coordinates of the $$k$$th particle in the Cartesian coordinate system.  We assume that there are $$3n$$ degrees of freedom and, therefore, there are $$N=3n$$ real valued generalized coordinates $$q{}_{1},\cdots,q{}_{N}$$.  We assume that coordinates do not have any explicit time dependence so that \begin{equation*} \frac{\partial x{}_{k}}{\partial t}= \frac{\partial y{}_{k}}{\partial t}= \frac{\partial z{}_{k}}{\partial t}= \frac{\partial q{}_{k}}{\partial t}\equiv0.  \end{equation*} We assume that the system has a stable equilibrium state.  We choose the reference point (origin) of the generalized coordinates at this equilibrium point $$\mathbb{q}=\mathbb{0}$$.  The Euler-Lagrange equation states that $$\ddot{\mathbb{q}}=\mathbb{0}$$ because $$\frac{\partial L}{\partial q{}_i}=0$$ at the equilibrium point $$\mathbb{q}=\mathbb{0}$$.  	true	correct	false	incorrect	pass	incorrect
# MC	 Consider a system of $$n$$ particles that has a stable equilibrium state.  We choose the reference point (origin) of the generalized coordinates $$\mathbb{q}=\begin{pmatrix}{q{}_{1}}\\{\vdots}\\{q{}_{N}}\end{pmatrix} $$ at this equilibrium point.  The mass matrix and the potential energy tensor are $$\mathbb{M}$$ and $$\mathbb{A}$$, respectively.  The Euler-Lagrange equations are coupled as $$\mathbb{M}\ddot{\mathbb{q}} +\mathbb{A}\mathbb{q} =\mathbb{0}$$.  	true	correct	false	incorrect	pass	incorrect
# MC	 Consider a system of $$n$$ particles that has a stable equilibrium state.  We choose the reference point (origin) of the generalized coordinates $$\mathbb{q}=\begin{pmatrix}{q{}_{1}}\\{\vdots}\\{q{}_{N}}\end{pmatrix} $$ at this equilibrium point.  The mass matrix and the potential energy tensor are $$\mathbb{M}$$ and $$\mathbb{A}$$, respectively.  The equation of motion is decoupled $$\ddot{\eta} = \mathbb{\Omega}{}_D^2{\eta}$$.  	true	incorrect	false	correct	pass	incorrect
# MC	 Consider a system of $$n$$ particles that has a stable equilibrium state.  We choose the reference point (origin) of the generalized coordinates $$\mathbb{q}=\begin{pmatrix}{q{}_{1}}\\{\vdots}\\{q{}_{N}}\end{pmatrix} $$ at this equilibrium point.  The mass matrix and the potential energy tensor are $$\mathbb{M}$$ and $$\mathbb{A}$$, respectively.  The trial solution, $$\mathbb{q} =e^{-i\omega t}\Psi$$, is consistent with the separation of variables.  Here, the eigenvector $$\Psi$$ depends on time.  	true	incorrect	false	correct	pass	incorrect
# MC	 Consider a system of $$n$$ particles that has a stable equilibrium state.  We choose the reference point (origin) of the generalized coordinates $$\mathbb{q}=\begin{pmatrix}{q{}_{1}}\\{\vdots}\\{q{}_{N}}\end{pmatrix} $$ at this equilibrium point.  The mass matrix and the potential energy tensor are $$\mathbb{M}$$ and $$\mathbb{A}$$, respectively.  The eigenvector $$\Psi$$ is a time-independent complex column vector $$ \Psi=\begin{pmatrix}\psi{}_{1}\\\vdots\\\psi{}_{N}\end{pmatrix}$$.  	true	correct	false	incorrect	pass	incorrect
# MC	 Consider a system of $$n$$ particles that has a stable equilibrium state.  We choose the reference point (origin) of the generalized coordinates $$\mathbb{q}=\begin{pmatrix}{q{}_{1}}\\{\vdots}\\{q{}_{N}}\end{pmatrix} $$ at this equilibrium point.  The mass matrix and the potential energy tensor are $$\mathbb{M}$$ and $$\mathbb{A}$$, respectively.  The eigenvalue equation is $$\mathbb{A}\Psi=\omega^2 \mathbb{M}\Psi$$.  	true	correct	false	incorrect	pass	incorrect
# MC	 Consider a system of $$n$$ particles that has a stable equilibrium state.  We choose the reference point (origin) of the generalized coordinates $$\mathbb{q}=\begin{pmatrix}{q{}_{1}}\\{\vdots}\\{q{}_{N}}\end{pmatrix} $$ at this equilibrium point.  The mass matrix and the potential energy tensor are $$\mathbb{M}$$ and $$\mathbb{A}$$, respectively.  According to the fundamental theorem for algebra, there are $$N$$ complex eigenvalues $$\omega^2{}_k$$ for $$k=1$$, 2, $$\cdots$$, $$N$$ with multiplicity.  The imaginary part of an eigenvalue does not vanish.  	true	incorrect	false	correct	pass	incorrect
# MC	 Consider a system of $$n$$ particles that has a stable equilibrium state.  We choose the reference point (origin) of the generalized coordinates $$\mathbb{q}=\begin{pmatrix}{q{}_{1}}\\{\vdots}\\{q{}_{N}}\end{pmatrix} $$ at this equilibrium point.  The mass matrix and the potential energy tensor are $$\mathbb{M}$$ and $$\mathbb{A}$$, respectively$$. (\omega^{*2}{}_{j} -\omega^{2}{}_{i})\Psi^{\dagger}{}_{j}\mathbb{M}\Psi{}_{i} =0$$.  	true	correct	false	incorrect	pass	incorrect
# MC	 Consider a system of $$n$$ particles that has a stable equilibrium state.  We choose the reference point (origin) of the generalized coordinates $$\mathbb{q}=\begin{pmatrix}{q{}_{1}}\\{\vdots}\\{q{}_{N}}\end{pmatrix} $$ at this equilibrium point.  The mass matrix and the potential energy tensor are $$\mathbb{M}$$ and $$\mathbb{A}$$, respectively.  Every eigenvalue is real because both $$\mathbb{A}$$ and $$\mathbb{M}$$ are Hermitian.  	true	correct	false	incorrect	pass	incorrect
# ...
# MC	 Let us consider three coupled harmonic oscillators.  which have both ends connected to the walls.  The three particles are of equal mass $$m$$.  They are connected in series with the identical springs of spring constant $$k$$$$. x{}_i$$ for $$i=$$1, 2, 3 are the horizontal displacement of the $$i$$th particle from the equilibrium position.  We assume that the particles move only along the horizontal axis.  The eigenvalues for $$\tfrac{1}{m}\mathbb{A}$$ and the corresponding eigenvectors are $$\omega{}_1^2=(2-\sqrt{2})\omega{}_0^2, \quad \Psi{}_1= \begin{pmatrix} \frac{1}{2}\\\frac{1}{\sqrt{2}}\\\frac{1}{2} \end{pmatrix},$$ $$\omega{}_2^2=2\omega{}_0^2, \quad \Psi{}_2= \begin{pmatrix} -\frac{1}{\sqrt{2}}\\0\\ \frac{1}{\sqrt{2}} \end{pmatrix}$$ $$\omega{}_3^2=(2+\sqrt{2})\omega{}_0^2, \quad \Psi{}_3= \begin{pmatrix} \frac{1}{2} \\-\frac{1}{\sqrt{2}}\\\frac{1}{2} \end{pmatrix}$$, where $$\omega{}_0^2=\tfrac{k}{m}$$.  There are no degenerate eigenvectors.  	true	correct	false	incorrect	pass	incorrect
# MC	 Let us consider three coupled harmonic oscillators.  which have both ends connected to the walls.  The three particles are of equal mass $$m$$.  They are connected in series with the identical springs of spring constant $$k$$$$. x{}_i$$ for $$i=$$1, 2, 3 are the horizontal displacement of the $$i$$th particle from the equilibrium position.  We assume that the particles move only along the horizontal axis.  The eigenvalues for $$\tfrac{1}{m}\mathbb{A}$$ and the corresponding eigenvectors are $$\omega{}_1^2=(2-\sqrt{2})\omega{}_0^2, \quad \Psi{}_1= \begin{pmatrix} \frac{1}{2}\\\frac{1}{\sqrt{2}}\\\frac{1}{2} \end{pmatrix},$$ $$\omega{}_2^2=2\omega{}_0^2, \quad \Psi{}_2= \begin{pmatrix} -\frac{1}{\sqrt{2}}\\0\\ \frac{1}{\sqrt{2}} \end{pmatrix}$$ $$\omega{}_3^2=(2+\sqrt{2})\omega{}_0^2, \quad \Psi{}_3= \begin{pmatrix} \frac{1}{2} \\-\frac{1}{\sqrt{2}}\\\frac{1}{2} \end{pmatrix}$$, where $$\omega{}_0^2=\tfrac{k}{m}$$$$. \eta=\mathbb{\Lambda}\mathbb{q}$$ 	true	correct	false	incorrect	pass	incorrect
# MC	 Let us consider three coupled harmonic oscillators.  which have both ends connected to the walls.  The three particles are of equal mass $$m$$.  They are connected in series with the identical springs of spring constant $$k$$$$. x{}_i$$ for $$i=$$1, 2, 3 are the horizontal displacement of the $$i$$th particle from the equilibrium position.  We assume that the particles move only along the horizontal axis.  The eigenvalues for $$\tfrac{1}{m}\mathbb{A}$$ and the corresponding eigenvectors are $$\omega{}_1^2=(2-\sqrt{2})\omega{}_0^2, \quad \Psi{}_1= \begin{pmatrix} \frac{1}{2}\\\frac{1}{\sqrt{2}}\\\frac{1}{2} \end{pmatrix},$$ $$\omega{}_2^2=2\omega{}_0^2, \quad \Psi{}_2= \begin{pmatrix} -\frac{1}{\sqrt{2}}\\0\\ \frac{1}{\sqrt{2}} \end{pmatrix}$$ $$\omega{}_3^2=(2+\sqrt{2})\omega{}_0^2, \quad \Psi{}_3= \begin{pmatrix} \frac{1}{2} \\-\frac{1}{\sqrt{2}}\\\frac{1}{2} \end{pmatrix}$$, where $$\omega{}_0^2=\tfrac{k}{m}$$$$.  \eta= \begin{pmatrix} \frac{1}{2}&\frac{1}{\sqrt{2}}&\frac{1}{2} \\ \frac{1}{\sqrt{2}}&0&-\frac{1}{\sqrt{2}}\\ \frac{1}{2}&-\frac{1}{\sqrt{2}}&\frac{1}{2} \end{pmatrix} \begin{pmatrix} x{}_1\\x{}_2\\x{}_3 \end{pmatrix} $$.  	true	incorrect	false	correct	pass	incorrect
# MC	 Consider two beads of equal mass $$m$$ loaded on a uniform string with the identical spacing $$d$$.  We consider the vertical motion only.  We denote $$q{}_i$$ by the vertical displacement of the $$i$$th bead from the equilibrium point.  The angle from the horizontal axis to the $$i$$th segment of the string counterclockwise is $$\theta{}_i$$.  We define $$q{}_0$$ and $$q{}_3$$ be the positions of the walls.  Since the total kinetic energy of the system is $$ T=\frac{1}{2}m\sum{}_{k=0}^3 \dot{q}{}_k^2=\frac{1}{2}m\sum{}_{k=1}^2 \dot{q}{}_k^2, $$ The mass matrix $$\mathbb{M}$$ is $$\mathbb{M} = \begin{pmatrix}{m}&{0}\\{0}&{m}\end{pmatrix}$$.  	true	correct	false	incorrect	pass	incorrect
# MC	 Consider two beads of equal mass $$m$$ loaded on a uniform string with the identical spacing $$d$$.  We consider the vertical motion only.  We denote $$q{}_i$$ by the vertical displacement of the $$i$$th bead from the equilibrium point.  The angle from the horizontal axis to the $$i$$th segment of the string counterclockwise is $$\theta{}_i$$.  We define $$q{}_0$$ and $$q{}_3$$ be the positions of the walls.  The potential energy is $$U(q{}_{1},q{}_{2}) = \frac{\tau}{2d}\sum{}_{i=1}^{2} ( q{}_{i} -q{}_{i-1})^{2}$$.  	true	incorrect	false	correct	pass	incorrect
# MC	 Consider two beads of equal mass $$m$$ loaded on a uniform string with the identical spacing $$d$$.  We consider the vertical motion only.  We denote $$q{}_i$$ by the vertical displacement of the $$i$$th bead from the equilibrium point.  The angle from the horizontal axis to the $$i$$th segment of the string counterclockwise is $$\theta{}_i$$.  We define $$q{}_0$$ and $$q{}_3$$ be the positions of the walls.  The eigenvalues for $$\tfrac{1}{m}\mathbb{A}$$ and the corresponding eigenvectors are $$\omega{}_{1}^{2} = \frac{\tau}{md}, \quad \Psi{}_{1} = \frac{1}{\sqrt{2}}\begin{pmatrix}{\phantom{-}1}\\{\phantom{-}1}\end{pmatrix},$$ $$ \omega{}_{2}^{2} = \frac{3\tau}{md}, \quad \Psi{}_{2} = \frac{1}{\sqrt{2}}\begin{pmatrix}{-1}\\{\phantom{-}1}\end{pmatrix}$$.  	true	correct	false	incorrect	pass	incorrect
# MC	 Consider two beads of equal mass $$m$$ loaded on a uniform string with the identical spacing $$d$$.  We consider the vertical motion only.  We denote $$q{}_i$$ by the vertical displacement of the $$i$$th bead from the equilibrium point.  The angle from the horizontal axis to the $$i$$th segment of the string counterclockwise is $$\theta{}_i$$.  We define $$q{}_0$$ and $$q{}_3$$ be the positions of the walls$$. \ddot{\eta} = \mathbb{\Omega}{}_D^2{\eta}$$ 	true	incorrect	false	correct	pass	incorrect
# MC	 Consider a string with tension $$\tau$$ loaded with $$n$$ beads of mass $$m$$ with the identical spacing $$d$$.  This can be described by the generalized coordinates: $$ \mathbb{q}=\begin{pmatrix}q{}_1\\\vdots\\q{}_n\end{pmatrix}, $$ where the endpoints are fixed: $$q{}_0=q{}_{n+1}=0$$ and $$\dot{q}{}_0=\dot{q}{}_{n+1}=0$$.  The potential energy of the system is $$U = \frac{\tau}{2d}\sum{}_{i=1}^{n+1} ( q{}_{i} -q{}_{i-1})^{2}$$.  	true	correct	false	incorrect	pass	incorrect
# MC	 Consider a string with tension $$\tau$$ loaded with $$n$$ beads of mass $$m$$ with the identical spacing $$d$$.  This can be described by the generalized coordinates: $$ \mathbb{q}=\begin{pmatrix}q{}_1\\\vdots\\q{}_n\end{pmatrix}, $$ where the endpoints are fixed: $$q{}_0=q{}_{n+1}=0$$ and $$\dot{q}{}_0=\dot{q}{}_{n+1}=0$$.  The vertical force on the $$i$$th bead is $$F{}_{i} = \frac{\tau}{d} ( q{}_{i} - q{}_{i-1}) + \frac{\tau}{d} ( q{}_{i} - q{}_{i+1})$$.  	true	incorrect	false	correct	pass	incorrect
# MC	 Consider a string with tension $$\tau$$ loaded with $$n$$ beads of mass $$m$$ with the identical spacing $$d$$.  This can be described by the generalized coordinates: $$ \mathbb{q}=\begin{pmatrix}q{}_1\\\vdots\\q{}_n\end{pmatrix}, $$ where the endpoints are fixed: $$q{}_0=q{}_{n+1}=0$$ and $$\dot{q}{}_0=\dot{q}{}_{n+1}=0$$.  The potential energy tensor $$\mathbb{A}$$ is $$ \frac{\tau}{d}\begin{pmatrix} 1 &-1 & 0 & & \\ -1 &1 &-1 &0 &\cdots \\ 0 &-1 &\ddots&\ddots&\ddots \\ \vdots&0 &\ddots& &&\\ & &\ddots&\ddots&\ddots&\ddots&\ddots&\vdots\\ & & &\ddots&-1&1&-1&0\\ & & & &0&-1&1&-1\\ & & & &\cdots&0&-1&1 \end{pmatrix}$$.  	true	incorrect	false	correct	pass	incorrect
# MC	 Consider a string with tension $$\tau$$ loaded with $$n$$ beads of mass $$m$$ with the identical spacing $$d$$.  This can be described by the generalized coordinates: $$ \mathbb{q}=\begin{pmatrix}q{}_1\\\vdots\\q{}_n\end{pmatrix}, $$ where the endpoints are fixed: $$q{}_0=q{}_{n+1}=0$$ and $$\dot{q}{}_0=\dot{q}{}_{n+1}=0$$.  The Lagrangian of the system is $$ L = \frac{1}{2} \sum{}_{i=1}^{n+1} \left[ m\dot{q}{}_{i}^{2} - \frac{\tau}{2d} (q{}_{i} -q{}_{i-1})^{2} \right]$$$$.  =\frac{1}{2} m\dot{\mathbb{q}}^\dagger \dot{\mathbb{q}} - \frac{1}{2} \mathbb{q}^\dagger\mathbb{A}\mathbb{q}$$.  	true	correct	false	incorrect	pass	incorrect
# MC	 Consider a string with tension $$\tau$$ loaded with $$n$$ beads of mass $$m$$ with the identical spacing $$d$$.  This can be described by the generalized coordinates: $$ \mathbb{q}=\begin{pmatrix}q{}_1\\\vdots\\q{}_n\end{pmatrix}, $$ where the endpoints are fixed: $$q{}_0=q{}_{n+1}=0$$ and $$\dot{q}{}_0=\dot{q}{}_{n+1}=0$$.  The Euler-Lagrange equations are $$\ddot{q}{}_{k} - \frac{\tau}{md}(q{}_{k-1} - 2q{}_{k} +q{}_{k+1})=0, $$ for $$k=1,\,2,\,\cdots,\,n$$.  They are equivalent to $$ m\ddot{\mathbb{q}} + \mathbb{A}\mathbb{q} = 0$$.  	true	correct	false	incorrect	pass	incorrect
# MC	 Consider a string with tension $$\tau$$ loaded with $$n$$ beads of mass $$m$$ with the identical spacing $$d$$.  This can be described by the generalized coordinates: $$ \mathbb{q}=\begin{pmatrix}q{}_1\\\vdots\\q{}_n\end{pmatrix}, $$ where the endpoints are fixed: $$q{}_0=q{}_{n+1}=0$$ and $$\dot{q}{}_0=\dot{q}{}_{n+1}=0$$.  As an application of the separation of variables, we introduce a trial solution $$\mathbb{q}(t) = e^{-i\omega t}\Psi$$ to solve the equation of motion.  Here, $$ \Psi= \begin{pmatrix} e^{i\gamma}\\e^{i2\gamma}\\\vdots\\e^{in\gamma}\end{pmatrix} $$ depends on the position identifier $$k=1$$, $$\cdots,$$ $$n$$.  	true	correct	false	incorrect	pass	incorrect
# MC	 Consider a string with tension $$\tau$$ loaded with $$n$$ beads of mass $$m$$ with the identical spacing $$d$$.  This can be described by the generalized coordinates: $$ \mathbb{q}=\begin{pmatrix}q{}_1\\\vdots\\q{}_n\end{pmatrix}, $$ where the endpoints are fixed: $$q{}_0=q{}_{n+1}=0$$ and $$\dot{q}{}_0=\dot{q}{}_{n+1}=0$$.  The trial solution $$\mathbb{q}(t) = e^{-i\omega t}\Psi$$ with $$ \Psi= \begin{pmatrix} e^{i\gamma}\\e^{i2\gamma}\\\vdots\\e^{in\gamma}\end{pmatrix} $$ is equivalent to $$q{}_{k}(t) = e^{i(\gamma k - \omega t)}$$.  	true	correct	false	incorrect	pass	incorrect
# MC	 Consider a string with tension $$\tau$$ loaded with $$n$$ beads of mass $$m$$ with the identical spacing $$d$$.  This can be described by the generalized coordinates: $$ \mathbb{q}=\begin{pmatrix}q{}_1\\\vdots\\q{}_n\end{pmatrix}, $$ where the endpoints are fixed: $$q{}_0=q{}_{n+1}=0$$ and $$\dot{q}{}_0=\dot{q}{}_{n+1}=0$$.  The equation of motion reduces into $$ \left[-\omega^{2} -\frac{\tau}{md}(e^{-i\gamma}+2+e^{i\gamma})\right] e^{-i\omega t } \Psi = 0$$.  	true	incorrect	false	correct	pass	incorrect
# MC	 Consider a string with tension $$\tau$$ loaded with $$n$$ beads of mass $$m$$ with the identical spacing $$d$$.  This can be described by the generalized coordinates: $$ \mathbb{q}=\begin{pmatrix}q{}_1\\\vdots\\q{}_n\end{pmatrix}, $$ where the endpoints are fixed: $$q{}_0=q{}_{n+1}=0$$ and $$\dot{q}{}_0=\dot{q}{}_{n+1}=0$$$$. \omega = \pm 2\sqrt{\frac{\tau}{md}}\sin{\frac{\gamma}{2}} $$ is an approximation for a small $$\gamma$$.  	true	incorrect	false	correct	pass	incorrect
# MC	 Consider a string with tension $$\tau$$ loaded with $$n$$ beads of mass $$m$$ with the identical spacing $$d$$.  This can be described by the generalized coordinates: $$ \mathbb{q}=\begin{pmatrix}q{}_1\\\vdots\\q{}_n\end{pmatrix}, $$ where the endpoints are fixed: $$q{}_0=q{}_{n+1}=0$$ and $$\dot{q}{}_0=\dot{q}{}_{n+1}=0$$$$. \gamma=\frac{r\pi}{n+1}$$ for $$r=1$$, $$\cdots$$, $$n+1$$.  	true	incorrect	false	correct	pass	incorrect
# MC	 Consider a string with tension $$\tau$$ loaded with $$n$$ beads of mass $$m$$ with the identical spacing $$d$$.  This can be described by the generalized coordinates: $$ \mathbb{q}=\begin{pmatrix}q{}_1\\\vdots\\q{}_n\end{pmatrix}, $$ where the endpoints are fixed: $$q{}_0=q{}_{n+1}=0$$ and $$\dot{q}{}_0=\dot{q}{}_{n+1}=0$$$$. \omega{}_r=2\sqrt{\frac{\tau}{md}}\sin{\frac{r\pi}{2(n+1)}}$$ is allowed for any $$\gamma{}_s$$.  	true	incorrect	false	correct	pass	incorrect
# MC	 Consider a string with tension $$\tau$$ loaded with $$n$$ beads of mass $$m$$ with the identical spacing $$d$$.  This can be described by the generalized coordinates: $$ \mathbb{q}=\begin{pmatrix}q{}_1\\\vdots\\q{}_n\end{pmatrix}, $$ where the endpoints are fixed: $$q{}_0=q{}_{n+1}=0$$ and $$\dot{q}{}_0=\dot{q}{}_{n+1}=0$$$$. \beta{}_r=\left[\sum{}_{k=1}^n \sin^2\frac{kr\pi}{n+1}\right]^{-\frac{1}{2}}=\frac{2}{\sqrt{n+1}}$$.  	true	incorrect	false	correct	pass	incorrect
# MC	 Consider a string with tension $$\tau$$ loaded with $$n$$ beads of mass $$m$$ with the identical spacing $$d$$.  This can be described by the generalized coordinates: $$ \mathbb{q}=\begin{pmatrix}q{}_1\\\vdots\\q{}_n\end{pmatrix}, $$ where the endpoints are fixed: $$q{}_0=q{}_{n+1}=0$$ and $$\dot{q}{}_0=\dot{q}{}_{n+1}=0$$$$. \eta{}_r(t) =(\mathbb{\Lambda} \mathbb{q}){}_r =\left[ \begin{pmatrix} \Psi{}_1^\dagger\\ \Psi{}_2^\dagger\\ \vdots\\ \Psi{}_n^\dagger \end{pmatrix} \mathbb{q} \right]{}_r=\Psi{}_r^\dagger\mathbb{q}$$ $$=\sqrt{\frac{2}{n+1}}\sum{}_{k=1}^n q{}_k(t)\sin\frac{kr\pi}{n+1}$$.  	true	correct	false	incorrect	pass	incorrect
# MC	 We evaluate $$ \sum{}_{k=1}^{n} \sin\frac{kr\pi}{n+1}\sin\frac{ks\pi}{n+1}$$.  $$\sin kx \sin ky = \frac{1}{2} [\cos k(x - y) - \cos k(x + y)]$$ 	true	correct	false	incorrect	pass	incorrect
# MC	 We evaluate $$ \sum{}_{k=1}^{n} \sin\frac{kr\pi}{n+1}\sin\frac{ks\pi}{n+1}$$.  $$\frac{e^{ina}-1}{e^{ia}-1} =\frac{\sin\frac{na}{2}}{\sin \frac{a}{2}}$$.  	true	incorrect	false	correct	pass	incorrect
# MC	 We evaluate $$ \sum{}_{k=1}^{n} \sin\frac{kr\pi}{n+1}\sin\frac{ks\pi}{n+1}$$.  $$\sum{}_{k=0}^n\cos ka =\textrm{Re} \sum{}_{k=0}^n e^{ika} $$ $$ =\frac{\cos \frac{na}{2}\sin\frac{ n a}{2}}{\sin\frac{a}{2}}$$.  	true	incorrect	false	correct	pass	incorrect
# MC	 We evaluate $$ \sum{}_{k=1}^{n} \sin\frac{kr\pi}{n+1}\sin\frac{ks\pi}{n+1}$$.  The orthogonality of the eigenvectors guarantees that $$\sum{}_{k=0}^n \sin\frac{kr\pi}{n+1}\sin\frac{ks\pi}{n+1}=0$$ for $$r\neq s$$ and $$r$$ and $$s$$ are 0, 1, $$\cdots$$, $$n$$.  	true	correct	false	incorrect	pass	incorrect
# MC	 We evaluate $$ \sum{}_{k=1}^{n} \sin\frac{kr\pi}{n+1}\sin\frac{ks\pi}{n+1}$$.  $$\sum{}_{k=0}^n \sin\frac{kr\pi}{n+1}\sin\frac{ks\pi}{n+1}$$ $$= \frac{1}{2}\Big[ \frac{\cos \frac{n(r-s)\pi}{ n+1 }\sin\frac{(r-s)\pi}{2}}{\sin\frac{n(r-s)\pi}{ n+1 }} - \frac{\cos \frac{n(r+s)\pi}{ n+1 }\sin\frac{(r+s)\pi}{2}}{\sin\frac{n(r+s)\pi}{ n+1 }} \Big]$$.  	true	incorrect	false	correct	pass	incorrect
# MC	 We evaluate $$ \sum{}_{k=1}^{n} \sin\frac{kr\pi}{n+1}\sin\frac{ks\pi}{n+1}$$.  $$\lim{}_{r\to s}\frac{\cos \frac{n(r-s)\pi}{2(n+1)}\sin\frac{(r-s)\pi}{2}}{\sin\frac{n(r-s)\pi}{2(n+1)}}$$ $$= \frac{\frac{d}{dx}\sin\frac{\pi x}{2}}{\frac{d}{dx}\sin\frac{n \pi x}{2(n+1)}} $$ $$= n+1 $$.  	true	correct	false	incorrect	pass	incorrect
# MC	 We evaluate $$ \sum{}_{k=1}^{n} \sin\frac{kr\pi}{n+1}\sin\frac{ks\pi}{n+1}$$.  $$\sum{}_{k=0}^n \left(\sin\frac{kr\pi}{n+1}\sin\frac{ks\pi}{n+1}\right)^2$$ $$=\frac{n+1}{2}$$.  	true	correct	false	incorrect	pass	incorrect
